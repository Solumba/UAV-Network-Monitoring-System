# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np
import time
import csv
import os
import time
from datetime import datetime
from neo4j import GraphDatabase
from pymongo import MongoClient

# Neo4j configuration
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "Shady5000$")

# %%
class UAVNetworkSimulation:

    def __init__(self, uri, auth):
        self.driver = GraphDatabase.driver(uri, auth=auth)

    def close(self):
        self.driver.close()
    
    def create_initial_graph(self, num_uavs, connection_range, ground_station_pos, backbone_range):
        #Create undirected graph
        G = nx.Graph()

        # Define typical throughput and latency ranges (for example purposes)
        typical_throughput = (50, 100)  # Mbps
        typical_latency = (10, 50)     # Milliseconds
        typical_battery = (100,100) # %

        # Add UAV nodes with properties
        for i in range(num_uavs):
            throughput = random.randint(*typical_throughput)
            latency = random.randint(*typical_latency)
            battery = random.randint(*typical_battery)
            G.add_node(i, pos=(random.randint(0, 100), random.randint(0, 100)),
                       throughput=throughput, latency=latency, battery=battery)

        # Add The Backbone UAV
        backbone_uav_id = num_uavs
        G.add_node(backbone_uav_id, pos=(random.randint(0, 100), random.randint(0, 100)), is_backbone=True,
                       throughput=throughput, latency=latency, battery=battery)

        # Connect Backbone UAV to other UAVs Based on Euclidean Distance
        for i in range(num_uavs):
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        # Add and connect the Ground Station To The Backbone Only
        ground_station_id = num_uavs + 1
        G.add_node(ground_station_id, pos=ground_station_pos, is_ground_station=True, throughput=throughput, latency=latency, battery=battery)
        G.add_edge(backbone_uav_id, ground_station_id)

        # Add edges between UAVs within connection range
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        return G
    
    # Upload Current Graph To Neo4j
    def upload_to_neo4j(self, G):
        with self.driver.session() as session:
            # Clear existing data
            session.run("MATCH (n) DETACH DELETE n")

            # Add nodes
            for node in G.nodes:
                is_backbone = G.nodes[node].get('is_backbone', False)
                is_ground_station = G.nodes[node].get('is_ground_station', False)
                is_attack_node = G.nodes[node].get('is_attack_node', False)

                if is_backbone:
                    session.run(f"""
                        CREATE (b:BackboneUAV {{id: $id, pos: $pos, uavType: $uavType,
                            throughput: $throughput, latency: $latency, battery: $battery  + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "Backbone UAV", throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])
                elif is_ground_station:
                    session.run(f"""
                        CREATE (g:GroundStation {{id: $id, pos: $pos, gsName: $GS, battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], GS = "Ground Station", battery=G.nodes[node]['battery'])
                else:
                    session.run(f"""
                        CREATE (u:UAV {{id: $id, pos: $pos, uavType: $uavType, uavName: $uavName,
                            throughput: $throughput + 'mb/s', latency: $latency + 'ms', battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "UAV", uavName = "UAV"  + str(node), throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])

            # Add relationships
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)

    # Draw Graph
    def draw_graph(self, G):
        pos = nx.get_node_attributes(G, 'pos')

        # Labelling Each Type Of Node
        labels = {}
        for node in G.nodes:
            if G.nodes[node].get('is_backbone', False):
                labels[node] = 'Backbone UAV'
            elif G.nodes[node].get('is_ground_station', False):
                labels[node] = 'Ground Station'
            elif G.nodes[node].get('is_attack_node', False):
                labels[node] = 'Attack Node'
            else:
                labels[node] = f'UAV{node}'

        # Differentiate node types
        regular_nodes = [node for node in G.nodes if not G.nodes[node].get('is_backbone', False) and not G.nodes[node].get('is_ground_station', False)]
        backbone_nodes = [node for node in G.nodes if G.nodes[node].get('is_backbone', False)]
        ground_station_nodes = [node for node in G.nodes if G.nodes[node].get('is_ground_station', False)]
        attacking_nodes = [node for node in G.nodes if G.nodes[node].get('is_attack_node', False)]

        # Draw regular UAV nodes
        nx.draw_networkx_nodes(G, pos, nodelist=regular_nodes, node_color='green', node_size=300, label='UAV')
        
        # Draw backbone UAV node
        nx.draw_networkx_nodes(G, pos, nodelist=backbone_nodes, node_color='lightgreen', node_size=500, label='Backbone UAV')

        # Draw ground station node
        nx.draw_networkx_nodes(G, pos, nodelist=ground_station_nodes, node_color='lightblue', node_size=500, label='Ground Station')

        nx.draw_networkx_nodes(G, pos, nodelist=attacking_nodes, node_color='red', node_size=500, label='Attack Node')

        # Draw edges
        nx.draw_networkx_edges(G, pos, edge_color='gray')

        # Draw custom labels
        nx.draw_networkx_labels(G, pos, labels)

        plt.title("Multilayer UAV Network")
        plt.legend()
        plt.show()
        
    def update_uav_positions(self, G, move_range):
        
        # Update the positions of UAVs randomly within a given range.
    
        for node in G.nodes:
            if 'is_backbone' not in G.nodes[node] and 'is_ground_station' not in G.nodes[node]:
                current_pos = G.nodes[node]['pos']
                new_pos = (current_pos[0] + random.uniform(-move_range, move_range), 
                           current_pos[1] + random.uniform(-move_range, move_range))
                G.nodes[node]['pos'] = new_pos
        return G

    def update_network_connections(self, G, connection_range, backbone_range):
        
        # Update the network connections based on new positions and connection range.
        # Excluding backbone UAV and ground station
        num_uavs = len(G.nodes) - 2  
        backbone_uav_id = num_uavs

        # Update connections for regular UAVs
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                if G.has_edge(i, j):
                    G.remove_edge(i, j)
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        # Update connections for the Backbone UAV
        for i in range(num_uavs):
            if G.has_edge(i, backbone_uav_id):
                G.remove_edge(i, backbone_uav_id)
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        return G

    def update_neo4j_database(self, G):
        
        # Update the Neo4j database with the new positions and connections.
        
        with self.driver.session() as session:
            # Update positions
            for node in G.nodes:
                pos = G.nodes[node]['pos']
                session.run("""
                    MATCH (n)
                    WHERE n.id = $id
                    SET n.pos = $pos
                    """, id=node, pos=pos)

            # Update relationships
            session.run("MATCH (n)-[r:COMMUNICATES_WITH]->() DELETE r")
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)
    
    def generate_network_traffic(self, G, num_packets):
        
        # Generate network traffic considering the throughput of UAVs.
        
        packets = []
        for _ in range(num_packets):
            # Exclude backbone and ground station
            source = random.randint(0, len(G.nodes) - 3)  
            target = random.randint(0, len(G.nodes) - 3)
            
            # Packet size should not exceed the throughput of the source UAV
            max_packet_size = G.nodes[source]['throughput']
            size = random.randint(1, max_packet_size)

            packets.append({'source': source, 'target': target, 'size': size})
        return packets
    
    def route_packets(self, G, packets):
        
        # Determine the path for each packet and calculate cumulative latency.
        
        for packet in packets:
            source = packet['source']
            target = packet['target']
            if nx.has_path(G, source, target):
                path = nx.shortest_path(G, source, target)
                packet['path'] = path
                packet['delivered'] = True

                # Calculate cumulative latency
                total_latency = sum(G.nodes[node]['latency'] for node in path)
                packet['total_latency'] = total_latency
            else:
                packet['path'] = []
                packet['delivered'] = False
                packet['total_latency'] = None
        return packets


    def add_attack_node(self, G, target_ids, num_uavs, attack_node_pos=(random.randint(0, 100), random.randint(0, 100))):
        
        # Calculate a new ID for the attack node by taking the maximum current ID + 1
        
        attack_node_id = max(G.nodes()) + 1
        attk_battery = (100,100)
        battery = random.randint(*attk_battery)
        
        # Add the attack node with specified properties
        G.add_node(attack_node_id, pos=attack_node_pos, nodeName="Attack Node", is_attack_node=True, throughput=1000, latency=1, battery=battery)

        # Directly connect the attack node to the target node
        for target_id in target_ids:
            if target_id in G.nodes():
                G.add_edge(attack_node_id, target_id, weight=5)  # Weight can be adjusted or calculated based on actual metrics

        return attack_node_id

    def upload_attack_node_to_neo4j(self, G, attack_node_id, target_ids):
        
        with self.driver.session() as session:
            # Retrieve node data from the graph
            attack_node = G.nodes[attack_node_id]
            
            # Create the attack node in Neo4j
            session.run("""
                CREATE (a:AttackNode {
                    id: $id, 
                    pos: $pos,
                    nodeName: $nodeName,
                    throughput: $throughput, 
                    latency: $latency, 
                    battery: $battery, 
                    is_attack_node: $is_attack_node
                })
                """, id=attack_node_id, 
                    pos=str(attack_node['pos']),
                    nodeName=attack_node['nodeName'],
                    throughput=attack_node['throughput'], 
                    latency=attack_node['latency'], 
                    battery=attack_node['battery'], 
                    is_attack_node=True)

            # Create a relationship from the attack node to the target UAV
            for target_id in target_ids:
                if target_id in G.nodes():
                    session.run("""
                        MATCH (a:AttackNode {id: $attack_id}), (u:UAV {id: $target_id})
                        CREATE (a)-[:ATTACKS]->(u)
                        """, attack_id=attack_node_id, target_id=target_id)

    def update_network_metrics(self, G):
        
        for node in G.nodes():
            # Randomly increase latency by up to 10ms and decrease throughput by up to 10 Mbps
            G.nodes[node]['latency'] = max(1, G.nodes[node]['latency'] + random.randint(-5, 5))
            G.nodes[node]['throughput'] = max(1, G.nodes[node]['throughput'] + random.randint(-10, 10))

    def update_network_ddos_metrics(self, G):
        
        for node in G.nodes():
            # Randomly increase latency by up to 10ms and decrease throughput by up to 10 Mbps
            G.nodes[node]['latency'] += random.randint(1, 5)
            G.nodes[node]['throughput'] = max(1, G.nodes[node]['throughput'] - random.randint(1, 10))

    def run_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets):
    
        # Run the simulation for a specified period of time.
        results = []    
        start_time = time.time()
        iteration = 0
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            
            # Update UAV positions
            self.update_uav_positions(G, move_range)

            # Update network connections
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G) 

            # Update Neo4j database and redraw the graph
            # self.update_neo4j_database(G)
            # self.draw_graph(G)

            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)
            # Capture and record metrics for each node
            current_time = time.time() - start_time
            for node_id in G.nodes():
                results.append({
                    'time': current_time,
                    'node_id': node_id,
                    'latency': G.nodes[node_id]['latency'],
                    'throughput': G.nodes[node_id]['throughput']
                })
            print(results)

            # Log the routed packets information
            for i, packet in enumerate(routed_packets):
                print(f"  Packet {i}: Source: {packet['source']}, Target: {packet['target']}, "
                      f"Size: {packet['size']}, Delivered: {packet['delivered']}, "
                      f"Path: {packet['path']}, Total Latency: {packet['total_latency']}")

            # Wait for the next update
            time.sleep(update_interval)
            iteration += 1
        return results

    def simulate_ddos_attack(self, G, attack_node_id, target_ids, increase_factor, decrease_factor):
        for target_id in target_ids:
            if target_id in G.nodes():
                G.nodes[target_id]['latency'] = int(G.nodes[target_id]['latency'] * increase_factor)
                G.nodes[target_id]['throughput'] = int(G.nodes[target_id]['throughput'] * decrease_factor)
                G.nodes[target_id]['battery'] = int(G.nodes[target_id]['battery'] * decrease_factor)
                # Apply effects to neighboring nodes, ensuring integer operations
                for neighbor in G.neighbors(target_id):
                    G.nodes[neighbor]['latency'] = int(G.nodes[neighbor]['latency'] * (increase_factor - 0.1))
                    G.nodes[neighbor]['throughput'] = int(G.nodes[neighbor]['throughput'] * (decrease_factor + 0.1))
                    # G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))
                    if 'battery' in G.nodes[neighbor]:
                        G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))


    def run_ddos_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids):
        # Setup MongoDB connection
        client = MongoClient('mongodb://localhost:27017/')  # Adjust the connection URL if necessary
        db = client['ddos_simulation']
        collection = db['metrics']

        start_time = time.time()
        iteration = 0

        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")

            # Simulation updates
            self.update_uav_positions(G, move_range)
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G)

            # Trigger DDoS attack
            if iteration == 1:
                self.simulate_ddos_attack(G, attack_node_id, target_ids, 0.5, 0.5)

            # Traffic generation and routing
            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)

            # Capture and log metrics
            current_metrics = [
                {
                    'node': node,
                    'time': time.time() - start_time,
                    'latency': G.nodes[node]['latency'],
                    'throughput': G.nodes[node]['throughput'],
                    'battery': G.nodes[node]['battery']
                }
                for node in G.nodes()
            ]
            
            # Insert metrics into MongoDB
            collection.insert_many(current_metrics)

            # Print packet info
            for i, packet in enumerate(routed_packets):
                print(f"Packet {i}: Source: {packet['source']}, Target: {packet['target']}, Size: {packet['size']}, Delivered: {packet['delivered']}, Path: {packet['path']}, Total Latency: {packet['total_latency']}")

            # Delay for next update
            time.sleep(update_interval)
            iteration += 1

        print("Metrics have been saved to MongoDB.")
        return current_metrics


    def plot_time_series(self, results):
        import matplotlib.pyplot as plt

        # Filter results for a specific node for clarity, e.g., node 0
        node_results = [res for res in results if res['node_id'] == 0]
        times = [res['time'] for res in node_results]
        latencies = [res['latency'] for res in node_results]
        throughputs = [res['throughput'] for res in node_results]

        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(times, latencies, marker='o', color='r')
        plt.title('Latency Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Latency (ms)')

        plt.subplot(1, 2, 2)
        plt.plot(times, throughputs, marker='o', color='b')
        plt.title('Throughput Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Throughput (Mbps)')

        plt.tight_layout()
        plt.show()
    
    def analyze_network(self, G):
        # Calculate basic properties
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()
        sparsity = nx.density(G)  # Density close to 0 indicates a sparse graph
        
        # Centrality measures
        degree_centrality = nx.degree_centrality(G)  # Normalized to (n-1)
        closeness_centrality = nx.closeness_centrality(G)
        betweenness_centrality = nx.betweenness_centrality(G)
        
        # Identifying the most central node
        most_central_node = max(degree_centrality, key=degree_centrality.get)
        
        # Network robustness (using node connectivity)
        connectivity = nx.node_connectivity(G)
        
        # Plotting
        pos = nx.spring_layout(G)  # positions for all nodes
        plt.figure(figsize=(8, 8))
        nx.draw_networkx_nodes(G, pos, node_size=700)
        nx.draw_networkx_edges(G, pos, width=6)
        nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
        plt.axis("off")
        plt.show()

        return {
            "Number of Nodes": num_nodes,
            "Number of Edges": num_edges,
            "Sparsity": sparsity,
            "Degree Centrality": degree_centrality,
            "Closeness Centrality": closeness_centrality,
            "Betweenness Centrality": betweenness_centrality,
            "Most Central Node": most_central_node,
            "Connectivity": connectivity
        }

# %% [markdown]
# Here we create the original graph and assign standard through put and latency values to each UAV. More nodes can be added to the network by parsing a new value to the "num_uavs" parameters below. Connections between nodes are based on node range and Euclidean distance.

# %%
"""Creating The Network First"""
# Simulation Parameters
num_uavs = 10
connection_range = 30
ground_station_pos = (50, 50)
backbone_range = 50
num_packets = 10

total_time = 60  # Total time to run the simulation in seconds
update_interval = 5  # Time interval between updates in seconds
move_range = 5

# Initialize Simulation
simulation = UAVNetworkSimulation(URI, AUTH)

# Create and Setup UAV Network
uav_network = simulation.create_initial_graph(num_uavs, connection_range, ground_station_pos, backbone_range)

# Upload to Neo4j
simulation.upload_to_neo4j(uav_network)

# Draw Initial Graph
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

# %% [markdown]
# We run our movement simulation code, in the process UAVs can make new communications as they are currently routing fictional packets. We log the results below immediately and generate data based on our routing logic. Perform descriptive statistics.

# %%
"""Routing Simulation"""
# Run the Simulation
results = simulation.run_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets)

# Update network connections
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# Update Neo4j Database with the new positions and connections
simulation.update_neo4j_database(uav_network)

# Now draw the graph to visualize the updated network
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

simulation.plot_time_series(results)

# %% [markdown]
# Adding The Attack Node.

# %%
#Add Attack Node
# Initialize the simulation object and create the initial UAV network
simulation = UAVNetworkSimulation(URI, AUTH)
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# # Upload the initial UAV network to Neo4j
simulation.upload_to_neo4j(uav_network)

# Target UAV ID for the DDoS attack
target_uav_ids = [5, 7] # Example: Target UAV ID that you want to attack

# Add the attack node and connect it to the target UAV
attack_node_id = simulation.add_attack_node(uav_network, target_uav_ids, num_uavs)
simulation.upload_attack_node_to_neo4j(uav_network, attack_node_id, target_uav_ids)

# Optionally, visualize the updated network to confirm the addition and connection of the attack node
simulation.draw_graph(uav_network)

# Close the Neo4j connection at the end of the session
simulation.close()

# %%
"""DDoS Simulation"""
# Initialize your network G here
target_nodes = [5, 7]  # Target node IDs that will be affected by the DDoS attack
# Assuming you have an attack node and some target nodes
attack_node_id = simulation.add_attack_node(uav_network, target_nodes, num_uavs)  # ID of your attack node

total_time = 120  # For example, run the simulation for 120 seconds
update_interval = 5
move_range = 10
connection_range = 30
backbone_range = 50
num_packets = 10
target_ids = [5, 7]  # Targeting nodes 5 and 7 for the DDoS attack

# Run the DDoS simulation
simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)
# Out:
# Iteration 0:
# Packet 0: Source: 1, Target: 4, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 6, Target: 7, Size: 60, Delivered: True, Path: [6, 7], Total Latency: 35
# Packet 2: Source: 3, Target: 2, Size: 59, Delivered: True, Path: [3, 11, 2], Total Latency: 115
# Packet 3: Source: 3, Target: 1, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 0, Size: 72, Delivered: True, Path: [7, 11, 0], Total Latency: 68
# Packet 5: Source: 10, Target: 1, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 7, Size: 38, Delivered: True, Path: [2, 11, 7], Total Latency: 88
# Packet 7: Source: 3, Target: 6, Size: 20, Delivered: True, Path: [3, 6], Total Latency: 62
# Packet 8: Source: 5, Target: 9, Size: 63, Delivered: True, Path: [5, 12, 7, 9], Total Latency: 66
# Packet 9: Source: 10, Target: 7, Size: 24, Delivered: True, Path: [10, 7], Total Latency: 49
# Iteration 1:
# Packet 0: Source: 3, Target: 6, Size: 24, Delivered: True, Path: [3, 6], Total Latency: 25
# Packet 1: Source: 5, Target: 3, Size: 16, Delivered: True, Path: [5, 12, 7, 3], Total Latency: 32
# Packet 2: Source: 7, Target: 0, Size: 29, Delivered: True, Path: [7, 11, 0], Total Latency: 38
# Packet 3: Source: 0, Target: 1, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 1, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 0, Target: 4, Size: 13, Delivered: True, Path: [0, 11, 4], Total Latency: 44
# Packet 6: Source: 3, Target: 10, Size: 32, Delivered: True, Path: [3, 10], Total Latency: 32
# Packet 7: Source: 9, Target: 4, Size: 25, Delivered: True, Path: [9, 4], Total Latency: 36
# Packet 8: Source: 2, Target: 0, Size: 86, Delivered: True, Path: [2, 11, 0], Total Latency: 70
# Packet 9: Source: 10, Target: 1, Size: 28, Delivered: False, Path: [], Total Latency: None
# Iteration 2:
# Packet 0: Source: 4, Target: 2, Size: 21, Delivered: True, Path: [4, 11, 2], Total Latency: 57
# Packet 1: Source: 0, Target: 9, Size: 47, Delivered: True, Path: [0, 11, 9], Total Latency: 58
# Packet 2: Source: 6, Target: 6, Size: 37, Delivered: True, Path: [6], Total Latency: 9
# Packet 3: Source: 6, Target: 6, Size: 18, Delivered: True, Path: [6], Total Latency: 9
# Packet 4: Source: 5, Target: 7, Size: 23, Delivered: True, Path: [5, 12, 7], Total Latency: 14
# Packet 5: Source: 5, Target: 6, Size: 22, Delivered: True, Path: [5, 12, 7, 6], Total Latency: 23
# Packet 6: Source: 9, Target: 8, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 5, Target: 0, Size: 21, Delivered: True, Path: [5, 12, 7, 11, 0], Total Latency: 47
# Packet 8: Source: 5, Target: 9, Size: 8, Delivered: True, Path: [5, 12, 7, 11, 9], Total Latency: 48
# Packet 9: Source: 1, Target: 8, Size: 8, Delivered: False, Path: [], Total Latency: None
# Iteration 3:
# Packet 0: Source: 1, Target: 2, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 1, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 3, Target: 0, Size: 35, Delivered: True, Path: [3, 11, 0], Total Latency: 62
# Packet 3: Source: 10, Target: 7, Size: 18, Delivered: True, Path: [10, 7], Total Latency: 14
# Packet 4: Source: 5, Target: 6, Size: 12, Delivered: True, Path: [5, 12, 7, 6], Total Latency: 20
# Packet 5: Source: 7, Target: 2, Size: 6, Delivered: True, Path: [7, 11, 2], Total Latency: 45
# Packet 6: Source: 9, Target: 10, Size: 25, Delivered: True, Path: [9, 11, 10], Total Latency: 49
# Packet 7: Source: 10, Target: 2, Size: 9, Delivered: True, Path: [10, 11, 2], Total Latency: 57
# Packet 8: Source: 1, Target: 4, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 5, Size: 31, Delivered: True, Path: [4, 2, 5], Total Latency: 46
# Iteration 4:
# Packet 0: Source: 0, Target: 1, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 0, Target: 7, Size: 25, Delivered: True, Path: [0, 11, 7], Total Latency: 45
# Packet 2: Source: 5, Target: 2, Size: 27, Delivered: True, Path: [5, 12, 7, 11, 2], Total Latency: 61
# Packet 3: Source: 5, Target: 9, Size: 26, Delivered: True, Path: [5, 12, 7, 11, 9], Total Latency: 54
# Packet 4: Source: 8, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 10, Target: 10, Size: 29, Delivered: True, Path: [10], Total Latency: 15
# Packet 6: Source: 9, Target: 2, Size: 6, Delivered: True, Path: [9, 4, 2], Total Latency: 69
# Packet 7: Source: 8, Target: 0, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 0, Size: 17, Delivered: True, Path: [0], Total Latency: 28
# Packet 9: Source: 8, Target: 3, Size: 32, Delivered: False, Path: [], Total Latency: None
# Iteration 5:
# Packet 0: Source: 2, Target: 7, Size: 77, Delivered: True, Path: [2, 11, 7], Total Latency: 44
# Packet 1: Source: 5, Target: 4, Size: 7, Delivered: True, Path: [5, 12, 7, 11, 4], Total Latency: 30
# Packet 2: Source: 4, Target: 4, Size: 34, Delivered: True, Path: [4], Total Latency: 9
# Packet 3: Source: 6, Target: 3, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 6, Size: 10, Delivered: True, Path: [0, 11, 6], Total Latency: 48
# Packet 5: Source: 7, Target: 5, Size: 30, Delivered: True, Path: [7, 12, 5], Total Latency: 14
# Packet 6: Source: 8, Target: 4, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 5, Target: 6, Size: 11, Delivered: True, Path: [5, 12, 7, 6], Total Latency: 31
# Packet 8: Source: 7, Target: 1, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 7, Target: 9, Size: 18, Delivered: True, Path: [7, 11, 9], Total Latency: 32
# Iteration 6:
# Packet 0: Source: 0, Target: 5, Size: 1, Delivered: True, Path: [0, 11, 2, 5], Total Latency: 67
# Packet 1: Source: 5, Target: 2, Size: 3, Delivered: True, Path: [5, 2], Total Latency: 40
# Packet 2: Source: 4, Target: 5, Size: 32, Delivered: True, Path: [4, 2, 5], Total Latency: 49
# Packet 3: Source: 10, Target: 2, Size: 3, Delivered: True, Path: [10, 11, 2], Total Latency: 54
# Packet 4: Source: 5, Target: 1, Size: 28, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 4, Size: 19, Delivered: True, Path: [7, 11, 4], Total Latency: 25
# Packet 6: Source: 7, Target: 0, Size: 2, Delivered: True, Path: [7, 11, 0], Total Latency: 36
# Packet 7: Source: 8, Target: 5, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 6, Size: 22, Delivered: True, Path: [0, 11, 6], Total Latency: 40
# Packet 9: Source: 1, Target: 1, Size: 29, Delivered: True, Path: [1], Total Latency: 39
# Iteration 7:
# Packet 0: Source: 10, Target: 0, Size: 6, Delivered: True, Path: [10, 11, 0], Total Latency: 44
# Packet 1: Source: 8, Target: 8, Size: 13, Delivered: True, Path: [8], Total Latency: 5
# Packet 2: Source: 3, Target: 10, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 3, Size: 28, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 9, Size: 22, Delivered: True, Path: [0, 11, 9], Total Latency: 41
# Packet 5: Source: 1, Target: 3, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 8, Target: 4, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 6, Target: 10, Size: 10, Delivered: True, Path: [6, 10], Total Latency: 30
# Packet 8: Source: 2, Target: 2, Size: 74, Delivered: True, Path: [2], Total Latency: 37
# Packet 9: Source: 9, Target: 8, Size: 49, Delivered: False, Path: [], Total Latency: None
# Iteration 8:
# Packet 0: Source: 1, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 8, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 3, Target: 8, Size: 44, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 10, Target: 9, Size: 14, Delivered: True, Path: [10, 11, 9], Total Latency: 41
# Packet 4: Source: 1, Target: 10, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 0, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 8, Target: 1, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 10, Target: 6, Size: 23, Delivered: True, Path: [10, 6], Total Latency: 31
# Packet 8: Source: 5, Target: 1, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 0, Target: 4, Size: 6, Delivered: False, Path: [], Total Latency: None
# Iteration 9:
# Packet 0: Source: 9, Target: 4, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 0, Size: 53, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 10, Target: 6, Size: 9, Delivered: True, Path: [10, 6], Total Latency: 37
# Packet 3: Source: 1, Target: 7, Size: 30, Delivered: True, Path: [1, 6, 7], Total Latency: 80
# Packet 4: Source: 2, Target: 7, Size: 21, Delivered: True, Path: [2, 11, 7], Total Latency: 57
# Packet 5: Source: 7, Target: 6, Size: 23, Delivered: True, Path: [7, 6], Total Latency: 38
# Packet 6: Source: 1, Target: 4, Size: 36, Delivered: True, Path: [1, 6, 11, 4], Total Latency: 74
# Packet 7: Source: 3, Target: 6, Size: 34, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 8, Size: 4, Delivered: True, Path: [5, 8], Total Latency: 5
# Packet 9: Source: 0, Target: 2, Size: 7, Delivered: False, Path: [], Total Latency: None
# Iteration 10:
# Packet 0: Source: 1, Target: 4, Size: 21, Delivered: True, Path: [1, 11, 4], Total Latency: 50
# Packet 1: Source: 6, Target: 1, Size: 5, Delivered: True, Path: [6, 1], Total Latency: 58
# Packet 2: Source: 5, Target: 0, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 9, Target: 3, Size: 29, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 1, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 0, Size: 41, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 8, Target: 5, Size: 14, Delivered: True, Path: [8, 5], Total Latency: 5
# Packet 7: Source: 7, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 9, Target: 3, Size: 54, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 3, Target: 1, Size: 37, Delivered: False, Path: [], Total Latency: None
# Iteration 11:
# Packet 0: Source: 8, Target: 5, Size: 51, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 5, Target: 10, Size: 17, Delivered: True, Path: [5, 12, 7, 10], Total Latency: 75
# Packet 2: Source: 1, Target: 2, Size: 33, Delivered: True, Path: [1, 11, 2], Total Latency: 78
# Packet 3: Source: 9, Target: 3, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 1, Target: 1, Size: 5, Delivered: True, Path: [1], Total Latency: 37
# Packet 5: Source: 7, Target: 3, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 1, Target: 7, Size: 56, Delivered: True, Path: [1, 6, 7], Total Latency: 81
# Packet 7: Source: 7, Target: 4, Size: 31, Delivered: True, Path: [7, 6, 11, 4], Total Latency: 51
# Packet 8: Source: 10, Target: 8, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 3, Target: 9, Size: 1, Delivered: False, Path: [], Total Latency: None
# Iteration 12:
# Packet 0: Source: 9, Target: 1, Size: 21, Delivered: True, Path: [9, 11, 1], Total Latency: 68
# Packet 1: Source: 2, Target: 5, Size: 2, Delivered: True, Path: [2, 11, 6, 7, 12, 5], Total Latency: 123
# Packet 2: Source: 9, Target: 0, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 5, Target: 2, Size: 40, Delivered: True, Path: [5, 12, 7, 6, 11, 2], Total Latency: 123
# Packet 4: Source: 8, Target: 1, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 7, Size: 44, Delivered: True, Path: [1, 6, 7], Total Latency: 82
# Packet 6: Source: 5, Target: 4, Size: 27, Delivered: True, Path: [5, 12, 7, 6, 11, 4], Total Latency: 87
# Packet 7: Source: 9, Target: 0, Size: 34, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 3, Size: 8, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 6, Target: 6, Size: 20, Delivered: True, Path: [6], Total Latency: 19
# Iteration 13:
# Packet 0: Source: 3, Target: 2, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 4, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 6, Target: 5, Size: 1, Delivered: True, Path: [6, 7, 12, 5], Total Latency: 83
# Packet 4: Source: 1, Target: 6, Size: 58, Delivered: True, Path: [1, 6], Total Latency: 52
# Packet 5: Source: 6, Target: 5, Size: 19, Delivered: True, Path: [6, 7, 12, 5], Total Latency: 83
# Packet 6: Source: 5, Target: 4, Size: 40, Delivered: True, Path: [5, 12, 7, 6, 11, 4], Total Latency: 87
# Packet 7: Source: 0, Target: 1, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 10, Target: 10, Size: 14, Delivered: True, Path: [10], Total Latency: 22
# Packet 9: Source: 2, Target: 10, Size: 48, Delivered: True, Path: [2, 11, 10], Total Latency: 63
# Iteration 14:
# Packet 0: Source: 9, Target: 2, Size: 24, Delivered: True, Path: [9, 11, 2], Total Latency: 71
# Packet 1: Source: 1, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 9, Size: 15, Delivered: True, Path: [7, 6, 11, 9], Total Latency: 72
# Packet 3: Source: 4, Target: 5, Size: 4, Delivered: True, Path: [4, 1, 6, 7, 12, 5], Total Latency: 123
# Packet 4: Source: 8, Target: 1, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 2, Target: 9, Size: 9, Delivered: True, Path: [2, 11, 9], Total Latency: 71
# Packet 6: Source: 9, Target: 3, Size: 33, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 0, Target: 1, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 1, Target: 0, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 0, Size: 42, Delivered: False, Path: [], Total Latency: None
# Iteration 15:
# Packet 0: Source: 9, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 6, Size: 8, Delivered: True, Path: [7, 6], Total Latency: 42
# Packet 2: Source: 8, Target: 3, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 4, Target: 2, Size: 10, Delivered: True, Path: [4, 11, 2], Total Latency: 53
# Packet 4: Source: 0, Target: 9, Size: 8, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 8, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 10, Target: 10, Size: 33, Delivered: True, Path: [10], Total Latency: 22
# Packet 7: Source: 9, Target: 9, Size: 31, Delivered: True, Path: [9], Total Latency: 22
# Packet 8: Source: 4, Target: 7, Size: 10, Delivered: True, Path: [4, 11, 6, 7], Total Latency: 49
# Packet 9: Source: 4, Target: 3, Size: 9, Delivered: False, Path: [], Total Latency: None
# Iteration 16:
# Packet 0: Source: 6, Target: 8, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 1, Target: 5, Size: 40, Delivered: True, Path: [1, 11, 6, 7, 12, 5], Total Latency: 116
# Packet 2: Source: 10, Target: 6, Size: 14, Delivered: True, Path: [10, 6], Total Latency: 33
# Packet 3: Source: 5, Target: 10, Size: 44, Delivered: True, Path: [5, 12, 7, 10], Total Latency: 80
# Packet 4: Source: 4, Target: 3, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 6, Target: 9, Size: 6, Delivered: True, Path: [6, 11, 9], Total Latency: 37
# Packet 6: Source: 5, Target: 6, Size: 32, Delivered: True, Path: [5, 12, 7, 6], Total Latency: 77
# Packet 7: Source: 4, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 6, Size: 29, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 3, Target: 3, Size: 46, Delivered: True, Path: [3], Total Latency: 27
# Iteration 17:
# Packet 0: Source: 2, Target: 6, Size: 38, Delivered: True, Path: [2, 11, 6], Total Latency: 62
# Packet 1: Source: 7, Target: 0, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 4, Size: 25, Delivered: True, Path: [7, 6, 11, 4], Total Latency: 39
# Packet 3: Source: 1, Target: 0, Size: 23, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 2, Size: 8, Delivered: True, Path: [7, 6, 11, 2], Total Latency: 87
# Packet 5: Source: 5, Target: 0, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 5, Target: 5, Size: 15, Delivered: True, Path: [5], Total Latency: 14
# Packet 7: Source: 3, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 6, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 3, Size: 16, Delivered: False, Path: [], Total Latency: None
# Iteration 18:
# Packet 0: Source: 3, Target: 2, Size: 51, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 3, Target: 9, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 10, Target: 9, Size: 12, Delivered: True, Path: [10, 11, 9], Total Latency: 38
# Packet 3: Source: 0, Target: 9, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 5, Size: 34, Delivered: True, Path: [7, 12, 5], Total Latency: 59
# Packet 5: Source: 6, Target: 2, Size: 7, Delivered: True, Path: [6, 11, 9, 2], Total Latency: 75
# Packet 6: Source: 6, Target: 8, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 7, Size: 46, Delivered: True, Path: [1, 6, 10, 7], Total Latency: 105
# Packet 8: Source: 6, Target: 4, Size: 2, Delivered: True, Path: [6, 1, 4], Total Latency: 57
# Packet 9: Source: 6, Target: 8, Size: 14, Delivered: False, Path: [], Total Latency: None
# Iteration 19:
# Packet 0: Source: 2, Target: 1, Size: 30, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 3, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 8, Size: 20, Delivered: True, Path: [8], Total Latency: 4
# Packet 3: Source: 2, Target: 4, Size: 75, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 7, Size: 5, Delivered: True, Path: [5, 12, 7], Total Latency: 56
# Packet 5: Source: 10, Target: 6, Size: 27, Delivered: True, Path: [10, 6], Total Latency: 39
# Packet 6: Source: 4, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 3, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 6, Target: 2, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 10, Target: 5, Size: 17, Delivered: True, Path: [10, 7, 12, 5], Total Latency: 84
# Iteration 20:
# Packet 0: Source: 5, Target: 2, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 0, Target: 2, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 1, Target: 8, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 8, Target: 9, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 4, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 2, Target: 6, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 1, Size: 55, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 7, Target: 5, Size: 8, Delivered: True, Path: [7, 12, 5], Total Latency: 45
# Packet 8: Source: 3, Target: 0, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 7, Target: 5, Size: 17, Delivered: True, Path: [7, 12, 5], Total Latency: 45
# Iteration 21:
# Packet 0: Source: 7, Target: 2, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 10, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 9, Target: 2, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 1, Size: 29, Delivered: True, Path: [1], Total Latency: 44
# Packet 4: Source: 3, Target: 3, Size: 1, Delivered: True, Path: [3], Total Latency: 33
# Packet 5: Source: 4, Target: 3, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 1, Target: 6, Size: 42, Delivered: True, Path: [1, 11, 6], Total Latency: 55
# Packet 7: Source: 7, Target: 1, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 0, Size: 9, Delivered: True, Path: [0], Total Latency: 9
# Packet 9: Source: 2, Target: 3, Size: 42, Delivered: False, Path: [], Total Latency: None
# Iteration 22:
# Packet 0: Source: 10, Target: 10, Size: 29, Delivered: True, Path: [10], Total Latency: 23
# Packet 1: Source: 6, Target: 5, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 10, Target: 4, Size: 27, Delivered: True, Path: [10, 11, 4], Total Latency: 34
# Packet 3: Source: 2, Target: 8, Size: 8, Delivered: True, Path: [2, 8], Total Latency: 53
# Packet 4: Source: 5, Target: 2, Size: 53, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 6, Target: 8, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 9, Target: 1, Size: 11, Delivered: True, Path: [9, 11, 1], Total Latency: 69
# Packet 7: Source: 8, Target: 7, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 7, Target: 1, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 5, Target: 4, Size: 6, Delivered: False, Path: [], Total Latency: None
# Iteration 23:
# Packet 0: Source: 0, Target: 0, Size: 4, Delivered: True, Path: [0], Total Latency: 9
# Packet 1: Source: 4, Target: 8, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 6, Size: 26, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 2, Target: 2, Size: 19, Delivered: True, Path: [2], Total Latency: 51
# Packet 4: Source: 9, Target: 5, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 0, Target: 10, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 0, Target: 0, Size: 9, Delivered: True, Path: [0], Total Latency: 9
# Packet 7: Source: 3, Target: 1, Size: 40, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 8, Target: 10, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 10, Target: 4, Size: 13, Delivered: True, Path: [10, 11, 4], Total Latency: 27
# Metrics have been saved to MongoDB.
# [{'node': 0,
#   'time': 115.33997797966003,
#   'latency': 9,
#   'throughput': 10,
#   'battery': 100,
#   '_id': ObjectId('662afeaea6dcc637a0eb5200')},
#  {'node': 1,
#   'time': 115.33997797966003,
#   'latency': 46,
#   'throughput': 43,
#   'battery': 100,
#   '_id': ObjectId('662afeaea6dcc637a0eb5201')},
#  {'node': 2,
#   'time': 115.33997797966003,
#   'latency': 51,
#   'throughput': 79,
#   'battery': 100,
#   '_id': ObjectId('662afeaea6dcc637a0eb5202')},
#  {'node': 3,
#   'time': 115.33997797966003,
#   'latency': 31,
#   'throughput': 58,
#   'battery': 60,
#   '_id': ObjectId('662afeaea6dcc637a0eb5203')},
#  {'node': 4,
#   'time': 115.33997797966003,
#   'latency': 1,
#   'throughput': 1,
#   'battery': 60,
#   '_id': ObjectId('662afeaea6dcc637a0eb5204')},
#  {'node': 5,
#   'time': 115.33997797966003,
#   'latency': 13,
#   'throughput': 64,
#   'battery': 50,
#   '_id': ObjectId('662afeaea6dcc637a0eb5205')},
#  {'node': 6,
#   'time': 115.33997797966003,
#   'latency': 10,
#   'throughput': 22,
#   'battery': 60,
#   '_id': ObjectId('662afeaea6dcc637a0eb5206')},
#  {'node': 7,
#   'time': 115.33997797966003,
#   'latency': 25,
#   'throughput': 28,
#   'battery': 50,
#   '_id': ObjectId('662afeaea6dcc637a0eb5207')},
#  {'node': 8,
#   'time': 115.33997797966003,
#   'latency': 1,
#   'throughput': 27,
#   'battery': 100,
#   '_id': ObjectId('662afeaea6dcc637a0eb5208')},
#  {'node': 9,
#   'time': 115.33997797966003,
#   'latency': 19,
#   'throughput': 45,
#   'battery': 100,
#   '_id': ObjectId('662afeaea6dcc637a0eb5209')},
#  {'node': 10,
#   'time': 115.33997797966003,
#   'latency': 18,
#   'throughput': 37,
#   'battery': 60,
#   '_id': ObjectId('662afeaea6dcc637a0eb520a')},
#  {'node': 11,
#   'time': 115.33997797966003,
#   'latency': 8,
#   'throughput': 35,
#   'battery': 60,
#   '_id': ObjectId('662afeaea6dcc637a0eb520b')},
#  {'node': 12,
#   'time': 115.33997797966003,
#   'latency': 19,
#   'throughput': 303,
#   'battery': 36,
#   '_id': ObjectId('662afeaea6dcc637a0eb520c')}]

# %% [markdown]
# Descriptive Statistics, Performing Correlation Analysis On the Dataset and plotting correlation matrix.

# %%
import matplotlib.pyplot as plt
metrics = simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)

def plot_network_metrics(metrics):
    # Assuming metrics is a list of tuples (node_id, time, latency, throughput, battery)
    # Filter by node_id for node 5 and node 7
    times_5 = [m[1] for m in metrics if m[0] == 5]
    latencies_5 = [m[2] for m in metrics if m[0] == 5]
    throughputs_5 = [m[3] for m in metrics if m[0] == 5]

    times_7 = [m[1] for m in metrics if m[0] == 7]
    latencies_7 = [m[2] for m in metrics if m[0] == 7]
    throughputs_7 = [m[3] for m in metrics if m[0] == 7]

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times_5, latencies_5, label='Latency UAV 5')
    plt.plot(times_7, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times_5, throughputs_5, label='Throughput UAV 5')
    plt.plot(times_7, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()
    
if metrics:
    plot_network_metrics(metrics)
else:
    print("No data was returned from the simulation.")
# Example usage:
# metrics = [(5, 1.0, 50, 100), (7, 1.0, 70, 90), (5, 2.0, 55, 95), (7, 2.0, 75, 85)]
# plot_network_metrics(metrics)

# %%
"""Pearson's Correlation"""

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data provided
data = [
    {'time': 0.001983642578125, 'node_id': 0, 'latency': 16, 'throughput': 71},
    {'time': 0.001983642578125, 'node_id': 1, 'latency': 41, 'throughput': 54},
    {'time': 0.001983642578125, 'node_id': 2, 'latency': 32, 'throughput': 76},
    {'time': 0.001983642578125, 'node_id': 3, 'latency': 7, 'throughput': 52},
    {'time': 0.001983642578125, 'node_id': 4, 'latency': 18, 'throughput': 53},
    {'time': 0.001983642578125, 'node_id': 5, 'latency': 17, 'throughput': 65},
    {'time': 0.001983642578125, 'node_id': 6, 'latency': 16, 'throughput': 84},
    {'time': 0.001983642578125, 'node_id': 7, 'latency': 40, 'throughput': 55},
    {'time': 0.001983642578125, 'node_id': 8, 'latency': 37, 'throughput': 68},
    {'time': 0.001983642578125, 'node_id': 9, 'latency': 39, 'throughput': 77},
    {'time': 0.001983642578125, 'node_id': 10, 'latency': 36, 'throughput': 86},
    {'time': 0.001983642578125, 'node_id': 11, 'latency': 39, 'throughput': 94},
    {'time': 5.015164613723755, 'node_id': 0, 'latency': 17, 'throughput': 78},
    # Assuming the rest of the data points are appended here in the same format...
]

# Converting data into a pandas DataFrame
df = pd.DataFrame(data)

# Calculating the correlation between latency and throughput
correlation_matrix = df[['latency', 'throughput']].corr()
print(correlation_matrix)


# Plotting a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
heatmap.set_title('Correlation Heatmap between Latency and Throughput', pad=12)
plt.show()

# %%
def plot_network_metrics_from_csv(file_path):
    # Load data from CSV
    df = pd.read_csv(file_path)
    
    # Filter data for specific nodes
    node_5_df = df[df['Node'] == 5]
    node_7_df = df[df['Node'] == 7]
    
    # Extract times, latencies, and throughputs
    times_5 = node_5_df['Time']
    latencies_5 = node_5_df['Latency']
    throughputs_5 = node_5_df['Throughput']

    times_7 = node_7_df['Time']
    latencies_7 = node_7_df['Latency']
    throughputs_7 = node_7_df['Throughput']

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times_5, latencies_5, label='Latency UAV 5')
    plt.plot(times_7, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times_5, throughputs_5, label='Throughput UAV 5')
    plt.plot(times_7, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
file_path = 'simulation_results\ddos_simulation_20240423_012712.csv'
plot_network_metrics_from_csv(file_path)

# %%
simulation.analyze_network(uav_network)

# %%
from pymongo import MongoClient

def get_database():
    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = "mongodb://localhost:27017"
    
    # Create a connection using MongoClient
    client = MongoClient(CONNECTION_STRING)

    print("Connecting to MongoDB...")
    db = client.your_database
    collection = db.your_collection
    print("Connected to MongoDB.")

    print("Inserting data...")
    collection.insert_one({"key": "value"})
    print("Data inserted.")

db = get_database()
# Out:
# Connecting to MongoDB...
# Connected to MongoDB.
# Inserting data...
# Data inserted.

# %%
from pymongo import MongoClient

def get_database():
    # Provide the mongodb atlas url to connect python to mongodb using pymongo
    CONNECTION_STRING = "mongodb://localhost:27017"
    
    # Create a connection using MongoClient
    client = MongoClient(CONNECTION_STRING)
    
    # Create the database for our example (we will use the same database throughout the tutorial)
    return client['uav_network_simulation']

db = get_database()

metrics = simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)

def save_metrics_to_mongodb(db, metrics):
    # Access the collection in the database
    metrics_collection = db.metrics
    
    # Insert the metrics
    metrics_collection.insert_many(metrics)

save_metrics_to_mongodb(db, metrics)
# Out:
# Iteration 0:
# Packet 0: Source: 3, Target: 8, Size: 45, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 8, Size: 1, Delivered: True, Path: [8], Total Latency: 21
# Packet 2: Source: 2, Target: 7, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 6, Size: 70, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 7, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 8, Size: 47, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 4, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 6, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 1, Target: 9, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 10, Target: 10, Size: 49, Delivered: True, Path: [10], Total Latency: 13
# Iteration 1:
# Packet 0: Source: 0, Target: 10, Size: 19, Delivered: True, Path: [0, 11, 10], Total Latency: 37
# Packet 1: Source: 3, Target: 5, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 6, Target: 1, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 2, Target: 4, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 1, Target: 10, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 5, Target: 7, Size: 7, Delivered: True, Path: [5, 12, 7], Total Latency: 14
# Packet 6: Source: 3, Target: 10, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 3, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 8, Size: 60, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 5, Target: 10, Size: 4, Delivered: False, Path: [], Total Latency: None
# Iteration 2:
# Packet 0: Source: 2, Target: 9, Size: 5, Delivered: True, Path: [2, 9], Total Latency: 80
# Packet 1: Source: 0, Target: 6, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 3, Target: 4, Size: 95, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 8, Target: 6, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 1, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 3, Target: 7, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 3, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 10, Size: 28, Delivered: True, Path: [2, 10], Total Latency: 56
# Packet 8: Source: 3, Target: 4, Size: 54, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 9, Target: 5, Size: 79, Delivered: False, Path: [], Total Latency: None
# Iteration 3:
# Packet 0: Source: 2, Target: 7, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 4, Target: 10, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 1, Size: 62, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 3, Size: 67, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 6, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 6, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 1, Size: 39, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 6, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 2, Target: 8, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 7, Target: 9, Size: 22, Delivered: False, Path: [], Total Latency: None
# Iteration 4:
# Packet 0: Source: 3, Target: 3, Size: 13, Delivered: True, Path: [3], Total Latency: 20
# Packet 1: Source: 10, Target: 5, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 4, Target: 7, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 10, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 8, Target: 0, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 8, Target: 0, Size: 22, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 7, Target: 9, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 4, Target: 4, Size: 2, Delivered: True, Path: [4], Total Latency: 25
# Packet 8: Source: 7, Target: 2, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 7, Size: 2, Delivered: False, Path: [], Total Latency: None
# Iteration 5:
# Packet 0: Source: 7, Target: 10, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 10, Target: 7, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 5, Target: 10, Size: 22, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 2, Target: 2, Size: 7, Delivered: True, Path: [2], Total Latency: 55
# Packet 4: Source: 7, Target: 6, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 5, Target: 1, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 6, Target: 2, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 3, Size: 41, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 4, Target: 7, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 6, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
# Iteration 6:
# Packet 0: Source: 4, Target: 6, Size: 1, Delivered: True, Path: [4, 6], Total Latency: 34
# Packet 1: Source: 5, Target: 9, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 1, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 7, Size: 9, Delivered: True, Path: [7], Total Latency: 5
# Packet 4: Source: 2, Target: 4, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 10, Size: 52, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 8, Target: 1, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 1, Size: 2, Delivered: True, Path: [1], Total Latency: 38
# Packet 8: Source: 0, Target: 7, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 0, Target: 10, Size: 21, Delivered: True, Path: [0, 11, 10], Total Latency: 36
# Iteration 7:
# Packet 0: Source: 8, Target: 6, Size: 77, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 6, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 5, Target: 3, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 0, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 7, Size: 10, Delivered: True, Path: [5, 12, 7], Total Latency: 19
# Packet 5: Source: 8, Target: 3, Size: 75, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 8, Target: 4, Size: 23, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 5, Target: 1, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 9, Target: 5, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 7, Target: 3, Size: 5, Delivered: False, Path: [], Total Latency: None
# Iteration 8:
# Packet 0: Source: 6, Target: 5, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 2, Target: 6, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 4, Target: 7, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 0, Size: 61, Delivered: True, Path: [0], Total Latency: 18
# Packet 4: Source: 8, Target: 3, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 4, Size: 29, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 0, Target: 7, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 5, Target: 3, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 9, Size: 88, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 10, Target: 8, Size: 30, Delivered: False, Path: [], Total Latency: None
# Iteration 9:
# Packet 0: Source: 7, Target: 9, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 1, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 2, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 10, Target: 6, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 8, Size: 101, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 3, Target: 1, Size: 126, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 3, Target: 8, Size: 96, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 8, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 10, Target: 1, Size: 48, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 2, Target: 10, Size: 5, Delivered: True, Path: [2, 10], Total Latency: 56
# Iteration 10:
# Packet 0: Source: 0, Target: 9, Size: 28, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 8, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 2, Target: 8, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 5, Target: 4, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 4, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 10, Target: 1, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 1, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 6, Target: 10, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 10, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 3, Size: 20, Delivered: False, Path: [], Total Latency: None
# Iteration 11:
# Packet 0: Source: 6, Target: 0, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 8, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 9, Target: 9, Size: 63, Delivered: True, Path: [9], Total Latency: 22
# Packet 3: Source: 3, Target: 1, Size: 84, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 1, Target: 0, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 3, Target: 1, Size: 122, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 3, Target: 5, Size: 76, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 4, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 10, Target: 9, Size: 52, Delivered: True, Path: [10, 9], Total Latency: 25
# Iteration 12:
# Packet 0: Source: 5, Target: 5, Size: 13, Delivered: True, Path: [5], Total Latency: 9
# Packet 1: Source: 2, Target: 9, Size: 11, Delivered: True, Path: [2, 9], Total Latency: 71
# Packet 2: Source: 3, Target: 9, Size: 77, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 8, Target: 2, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 6, Target: 5, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 0, Target: 5, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 0, Target: 8, Size: 62, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 0, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 8, Target: 10, Size: 26, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 6, Target: 4, Size: 19, Delivered: True, Path: [6, 4], Total Latency: 31
# Iteration 13:
# Packet 0: Source: 8, Target: 2, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 3, Target: 2, Size: 18, Delivered: True, Path: [3, 10, 2], Total Latency: 76
# Packet 2: Source: 3, Target: 6, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 2, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 8, Target: 10, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 3, Target: 3, Size: 2, Delivered: True, Path: [3], Total Latency: 22
# Packet 6: Source: 10, Target: 3, Size: 19, Delivered: True, Path: [10, 3], Total Latency: 24
# Packet 7: Source: 7, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 2, Size: 13, Delivered: True, Path: [0, 11, 2], Total Latency: 68
# Packet 9: Source: 7, Target: 2, Size: 5, Delivered: False, Path: [], Total Latency: None
# Iteration 14:
# Packet 0: Source: 0, Target: 5, Size: 31, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 1, Target: 1, Size: 17, Delivered: True, Path: [1], Total Latency: 37
# Packet 2: Source: 0, Target: 10, Size: 46, Delivered: True, Path: [0, 11, 10], Total Latency: 20
# Packet 3: Source: 5, Target: 1, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 4, Target: 10, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 0, Target: 0, Size: 8, Delivered: True, Path: [0], Total Latency: 9
# Packet 6: Source: 2, Target: 0, Size: 8, Delivered: True, Path: [2, 11, 0], Total Latency: 67
# Packet 7: Source: 3, Target: 5, Size: 83, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 1, Size: 22, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 2, Target: 8, Size: 6, Delivered: False, Path: [], Total Latency: None
# Iteration 15:
# Packet 0: Source: 5, Target: 1, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 0, Target: 7, Size: 18, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 2, Target: 4, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 6, Target: 7, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 1, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 8, Target: 5, Size: 78, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 5, Target: 10, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 7, Target: 10, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 7, Target: 8, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 9, Target: 9, Size: 54, Delivered: True, Path: [9], Total Latency: 18
# Iteration 16:
# Packet 0: Source: 0, Target: 1, Size: 31, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 1, Size: 45, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 0, Target: 10, Size: 69, Delivered: True, Path: [0, 11, 10], Total Latency: 12
# Packet 3: Source: 7, Target: 9, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 9, Size: 47, Delivered: True, Path: [3, 10, 11, 2, 9], Total Latency: 105
# Packet 5: Source: 5, Target: 5, Size: 6, Delivered: True, Path: [5], Total Latency: 5
# Packet 6: Source: 6, Target: 5, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 0, Target: 1, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 8, Target: 7, Size: 60, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 1, Size: 9, Delivered: False, Path: [], Total Latency: None
# Iteration 17:
# Packet 0: Source: 10, Target: 10, Size: 21, Delivered: True, Path: [10], Total Latency: 6
# Packet 1: Source: 9, Target: 0, Size: 24, Delivered: True, Path: [9, 0], Total Latency: 33
# Packet 2: Source: 9, Target: 8, Size: 23, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 4, Target: 6, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 5, Size: 3, Delivered: True, Path: [5], Total Latency: 10
# Packet 5: Source: 1, Target: 4, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 6, Target: 3, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 10, Target: 0, Size: 71, Delivered: True, Path: [10, 11, 0], Total Latency: 15
# Packet 8: Source: 1, Target: 7, Size: 44, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 3, Target: 10, Size: 132, Delivered: True, Path: [3, 10], Total Latency: 27
# Iteration 18:
# Packet 0: Source: 7, Target: 6, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 3, Target: 9, Size: 67, Delivered: True, Path: [3, 11, 2, 9], Total Latency: 101
# Packet 2: Source: 4, Target: 7, Size: 26, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 9, Target: 3, Size: 37, Delivered: True, Path: [9, 2, 11, 3], Total Latency: 101
# Packet 4: Source: 4, Target: 4, Size: 26, Delivered: True, Path: [4], Total Latency: 27
# Packet 5: Source: 9, Target: 7, Size: 26, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 0, Target: 9, Size: 51, Delivered: True, Path: [0, 2, 9], Total Latency: 81
# Packet 7: Source: 1, Target: 5, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 6, Size: 52, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 3, Size: 3, Delivered: False, Path: [], Total Latency: None
# Iteration 19:
# Packet 0: Source: 8, Target: 7, Size: 62, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 3, Target: 10, Size: 11, Delivered: True, Path: [3, 10], Total Latency: 26
# Packet 2: Source: 4, Target: 8, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 2, Target: 4, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 3, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 8, Target: 9, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 1, Target: 8, Size: 34, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 9, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 0, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 5, Size: 13, Delivered: False, Path: [], Total Latency: None
# Iteration 20:
# Packet 0: Source: 5, Target: 6, Size: 34, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 0, Target: 8, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 6, Target: 10, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 9, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 2, Target: 3, Size: 18, Delivered: True, Path: [2, 11, 3], Total Latency: 97
# Packet 5: Source: 9, Target: 7, Size: 67, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 6, Target: 7, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 8, Target: 5, Size: 75, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 2, Target: 5, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 5, Target: 8, Size: 15, Delivered: False, Path: [], Total Latency: None
# Iteration 21:
# Packet 0: Source: 2, Target: 8, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 10, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 6, Target: 4, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 3, Target: 0, Size: 77, Delivered: True, Path: [3, 11, 0], Total Latency: 48
# Packet 4: Source: 9, Target: 3, Size: 68, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 3, Target: 4, Size: 22, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 4, Target: 0, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 9, Target: 10, Size: 56, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 7, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 8, Size: 89, Delivered: True, Path: [8], Total Latency: 34
# Iteration 22:
# Packet 0: Source: 3, Target: 4, Size: 138, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 1, Target: 10, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 10, Target: 8, Size: 8, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 3, Target: 1, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 8, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 2, Target: 1, Size: 22, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 9, Target: 1, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 0, Target: 5, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 4, Target: 3, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 0, Target: 3, Size: 38, Delivered: True, Path: [0, 10, 3], Total Latency: 36
# Iteration 23:
# Packet 0: Source: 0, Target: 1, Size: 40, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 4, Target: 10, Size: 42, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 1, Target: 2, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 5, Target: 4, Size: 8, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 6, Target: 2, Size: 53, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 2, Target: 9, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 7, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 0, Target: 6, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 7, Target: 9, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 6, Target: 0, Size: 28, Delivered: False, Path: [], Total Latency: None
# Metrics saved to simulation_results/ddos_simulation_20240426_014618.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 24
#      21     # Insert the metrics
#      22     metrics_collection.insert_many(metrics)
# ---> 24 save_metrics_to_mongodb(db, metrics)
#
# Cell In[10], line 22, in save_metrics_to_mongodb(db, metrics)
#      19 metrics_collection = db.metrics
#      21 # Insert the metrics
# ---> 22 metrics_collection.insert_many(metrics)
#
# File c:\Users\Solomon\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\Solomon\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py:741, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     739 write_concern = self._write_concern_for(session)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
# --> 741 blk.ops = list(gen())
#     742 blk.execute(write_concern, session, _Op.INSERT)
#     743 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\Solomon\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\collection.py:732, in Collection.insert_many.<locals>.gen()
#     730 """A generator that validates documents and handles _ids."""
#     731 for document in documents:
# --> 732     common.validate_is_document_type("document", document)
#     733     if not isinstance(document, RawBSONDocument):
#     734         if "_id" not in document:
#
# File c:\Users\Solomon\AppData\Local\Programs\Python\Python310\lib\site-packages\pymongo\common.py:549, in validate_is_document_type(option, value)
#     547 """Validate the type of method arguments that expect a MongoDB document."""
#     548 if not isinstance(value, (abc.MutableMapping, RawBSONDocument)):
# --> 549     raise TypeError(
#     550         f"{option} must be an instance of dict, bson.son.SON, "
#     551         "bson.raw_bson.RawBSONDocument, or "
#     552         "a type that inherits from "
#     553         "collections.MutableMapping"
#     554     )
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping
