# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
import numpy as np
import time
from neo4j import GraphDatabase

# Neo4j configuration
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "Shady5000$")

# %%
class UAVNetworkSimulation:

    def __init__(self, uri, auth):
        self.driver = GraphDatabase.driver(uri, auth=auth)

    def close(self):
        self.driver.close()
    
    def create_initial_graph(self, num_uavs, connection_range, ground_station_pos, backbone_range):
        G = nx.Graph()

        # Add UAV nodes
        # for i in range(num_uavs):
        #     G.add_node(i, pos=(random.randint(0, 100), random.randint(0, 100)))
        # Define typical throughput and latency ranges (for example purposes)
        typical_throughput = (50, 100)  # Mbps
        typical_latency = (10, 50)     # Milliseconds
        typical_battery = (100,100) # battery life %

        # Add UAV nodes with properties
        for i in range(num_uavs):
            throughput = random.randint(*typical_throughput)
            latency = random.randint(*typical_latency)
            battery = random.randint(*typical_battery)
            G.add_node(i, pos=(random.randint(0, 100), random.randint(0, 100)),
                       throughput=throughput, latency=latency, battery=battery)

        # Add Backbone UAV
        backbone_uav_id = num_uavs
        G.add_node(backbone_uav_id, pos=(random.randint(0, 100), random.randint(0, 100)), is_backbone=True,
                       throughput=throughput, latency=latency, battery=battery)

        # Connect Backbone UAV to other UAVs
        for i in range(num_uavs):
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        # Add and connect the Ground Station
        ground_station_id = num_uavs + 1
        G.add_node(ground_station_id, pos=ground_station_pos, is_ground_station=True, throughput=throughput, latency=latency, battery=battery)
        G.add_edge(backbone_uav_id, ground_station_id)

        # Add edges between UAVs within connection range
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        return G

    def upload_to_neo4j(self, G):
        with self.driver.session() as session:
            # Clear existing data
            session.run("MATCH (n) DETACH DELETE n")

            # Add nodes
            for node in G.nodes:
                is_backbone = G.nodes[node].get('is_backbone', False)
                is_ground_station = G.nodes[node].get('is_ground_station', False)
                is_attack_node = G.nodes[node].get('is_attack_node', False)

                if is_backbone:
                    session.run(f"""
                        CREATE (b:BackboneUAV {{id: $id, pos: $pos, uavType: $uavType,
                            throughput: $throughput, latency: $latency, battery: $battery  + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "Backbone UAV", throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])
                elif is_ground_station:
                    session.run(f"""
                        CREATE (g:GroundStation {{id: $id, pos: $pos, gsName: $GS, battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], GS = "Ground Station", battery=G.nodes[node]['battery'])
                else:
                    session.run(f"""
                        CREATE (u:UAV {{id: $id, pos: $pos, uavType: $uavType, uavName: $uavName,
                            throughput: $throughput + 'mb/s', latency: $latency + 'ms', battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "UAV", uavName = "UAV"  + str(node), throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])

            # Add relationships
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)


    def draw_graph(self, G):
        pos = nx.get_node_attributes(G, 'pos')

        # Prepare custom labels
        labels = {}
        for node in G.nodes:
            if G.nodes[node].get('is_backbone', False):
                labels[node] = 'Backbone UAV'
            elif G.nodes[node].get('is_ground_station', False):
                labels[node] = 'Ground Station'
            elif G.nodes[node].get('is_attack_node', False):
                labels[node] = 'Attack Node'
            else:
                labels[node] = f'UAV{node}'

        # Differentiate node types
        regular_nodes = [node for node in G.nodes if not G.nodes[node].get('is_backbone', False) and not G.nodes[node].get('is_ground_station', False)]
        backbone_nodes = [node for node in G.nodes if G.nodes[node].get('is_backbone', False)]
        ground_station_nodes = [node for node in G.nodes if G.nodes[node].get('is_ground_station', False)]
        attacking_nodes = [node for node in G.nodes if G.nodes[node].get('is_attack_node', False)]

        # Draw regular UAV nodes
        nx.draw_networkx_nodes(G, pos, nodelist=regular_nodes, node_color='green', node_size=300, label='UAV')
        
        # Draw backbone UAV node
        nx.draw_networkx_nodes(G, pos, nodelist=backbone_nodes, node_color='lightgreen', node_size=500, label='Backbone UAV')

        # Draw ground station node
        nx.draw_networkx_nodes(G, pos, nodelist=ground_station_nodes, node_color='lightblue', node_size=500, label='Ground Station')

        nx.draw_networkx_nodes(G, pos, nodelist=attacking_nodes, node_color='red', node_size=500, label='Attack Node')

        # Draw edges
        nx.draw_networkx_edges(G, pos, edge_color='gray')

        # Draw custom labels
        nx.draw_networkx_labels(G, pos, labels)

        plt.title("Multilayer UAV Network")
        plt.legend()
        plt.show()
        
    def update_uav_positions(self, G, move_range):
        """
        Update the positions of UAVs randomly within a given range.
        """
        for node in G.nodes:
            if 'is_backbone' not in G.nodes[node] and 'is_ground_station' not in G.nodes[node]:
                current_pos = G.nodes[node]['pos']
                new_pos = (current_pos[0] + random.uniform(-move_range, move_range), 
                           current_pos[1] + random.uniform(-move_range, move_range))
                G.nodes[node]['pos'] = new_pos
        return G

    def update_network_connections(self, G, connection_range, backbone_range):
        """
        Update the network connections based on new positions and connection range.
        """
        num_uavs = len(G.nodes) - 2  # Excluding backbone UAV and ground station
        backbone_uav_id = num_uavs

        # Update connections for regular UAVs
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                if G.has_edge(i, j):
                    G.remove_edge(i, j)
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        # Update connections for the Backbone UAV
        for i in range(num_uavs):
            if G.has_edge(i, backbone_uav_id):
                G.remove_edge(i, backbone_uav_id)
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        return G

    def update_neo4j_database(self, G):
        """
        Update the Neo4j database with the new positions and connections.
        """
        with self.driver.session() as session:
            # Update positions
            for node in G.nodes:
                pos = G.nodes[node]['pos']
                session.run("""
                    MATCH (n)
                    WHERE n.id = $id
                    SET n.pos = $pos
                    """, id=node, pos=pos)

            # Update relationships
            session.run("MATCH (n)-[r:COMMUNICATES_WITH]->() DELETE r")
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)
    
    def generate_network_traffic(self, G, num_packets):
        """
        Generate network traffic considering the throughput of UAVs.
        """
        packets = []
        for _ in range(num_packets):
            source = random.randint(0, len(G.nodes) - 3)  # Exclude backbone and ground station
            target = random.randint(0, len(G.nodes) - 3)
            
            #Packet size should not exceed the throughput of the source UAV
            max_packet_size = G.nodes[source]['throughput']
            size = random.randint(1, max_packet_size)

            packets.append({'source': source, 'target': target, 'size': size})
        return packets
    
    def route_packets(self, G, packets):
        """
        Determine the path for each packet and calculate cumulative latency.
        """
        for packet in packets:
            source = packet['source']
            target = packet['target']
            if nx.has_path(G, source, target):
                path = nx.shortest_path(G, source, target)
                packet['path'] = path
                packet['delivered'] = True

                # Calculate cumulative latency
                total_latency = sum(G.nodes[node]['latency'] for node in path)
                packet['total_latency'] = total_latency
            else:
                packet['path'] = []
                packet['delivered'] = False
                packet['total_latency'] = None
        return packets


    def add_attack_node(self, G, target_ids, num_uavs, attack_node_pos=(random.randint(0, 100), random.randint(0, 100))):
        # Calculate a new ID for the attack node by taking the maximum current ID + 1
        attack_node_id = max(G.nodes()) + 1
        attk_battery = (100,100)
        battery = random.randint(*attk_battery)
        # Add the attack node with specified properties
        G.add_node(attack_node_id, pos=attack_node_pos, nodeName="Attack Node", is_attack_node=True, throughput=1000, latency=1, battery=battery)

        # Directly connect the attack node to the target node
        for target_id in target_ids:
            if target_id in G.nodes():
                G.add_edge(attack_node_id, target_id, weight=5)  # Weight can be adjusted or calculated based on actual metrics

        return attack_node_id

    def upload_attack_node_to_neo4j(self, G, attack_node_id, target_ids):
        with self.driver.session() as session:
            # Retrieve node data from the graph
            attack_node = G.nodes[attack_node_id]
            # Create the attack node in Neo4j
            session.run("""
                CREATE (a:AttackNode {
                    id: $id, 
                    pos: $pos,
                    nodeName: $nodeName,
                    throughput: $throughput, 
                    latency: $latency, 
                    battery: $battery, 
                    is_attack_node: $is_attack_node
                })
                """, id=attack_node_id, 
                    pos=str(attack_node['pos']),
                    nodeName=attack_node['nodeName'],
                    throughput=attack_node['throughput'], 
                    latency=attack_node['latency'], 
                    battery=attack_node['battery'], 
                    is_attack_node=True)

            # Create a relationship from the attack node to the target UAV
            for target_id in target_ids:
                if target_id in G.nodes():
                    session.run("""
                        MATCH (a:AttackNode {id: $attack_id}), (u:UAV {id: $target_id})
                        CREATE (a)-[:ATTACKS]->(u)
                        """, attack_id=attack_node_id, target_id=target_id)

    def update_network_metrics(self, G):
        for node in G.nodes():
            # Randomly increase latency by up to 10ms and decrease throughput by up to 10 Mbps
            G.nodes[node]['latency'] = max(1, G.nodes[node]['latency'] + random.randint(-5, 5))
            G.nodes[node]['throughput'] = max(1, G.nodes[node]['throughput'] + random.randint(-10, 10))

    def run_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets):
    
        #Run the simulation for a specified period of time.
        results = []    
        start_time = time.time()
        iteration = 0
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            
            # Update UAV positions
            self.update_uav_positions(G, move_range)

            # Update network connections
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G) 
            # Optional: Update Neo4j database and redraw the graph at each step
            # self.update_neo4j_database(G)
            # self.draw_graph(G)
            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)
             # Capture and record metrics for each node
            current_time = time.time() - start_time
            for node_id in G.nodes():
                results.append({
                    'time': current_time,
                    'node_id': node_id,
                    'latency': G.nodes[node_id]['latency'],
                    'throughput': G.nodes[node_id]['throughput']
                })
            print(results)
             # Log the routed packets information
            for i, packet in enumerate(routed_packets):
                print(f"  Packet {i}: Source: {packet['source']}, Target: {packet['target']}, "
                      f"Size: {packet['size']}, Delivered: {packet['delivered']}, "
                      f"Path: {packet['path']}, Total Latency: {packet['total_latency']}")

            # Wait for the next update
            time.sleep(update_interval)
            iteration += 1
        return results

    def simulate_ddos_attack(self, G, attack_node_id, target_ids, increase_factor, decrease_factor):
        for target_id in target_ids:
            if target_id in G.nodes():
                G.nodes[target_id]['latency'] = int(G.nodes[target_id]['latency'] * increase_factor)
                G.nodes[target_id]['throughput'] = int(G.nodes[target_id]['throughput'] * decrease_factor)
                G.nodes[target_id]['battery'] = int(G.nodes[target_id]['battery'] * decrease_factor)
                # Apply effects to neighboring nodes, ensuring integer operations
                for neighbor in G.neighbors(target_id):
                    G.nodes[neighbor]['latency'] = int(G.nodes[neighbor]['latency'] * (increase_factor - 0.1))
                    G.nodes[neighbor]['throughput'] = int(G.nodes[neighbor]['throughput'] * (decrease_factor + 0.1))
                    # G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))
                    if 'battery' in G.nodes[neighbor]:
                        G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))


    def run_ddos_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids):
        #Run the simulation for a specified period of time.
        import time
        metrics = []  # List to store metrics over time
        start_time = time.time()
        iteration = 0
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            # Update UAV positions
            self.update_uav_positions(G, move_range)

            # Update network connections
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G)
            # Trigger DDoS attack
            if iteration == 1:  # Start the DDoS attack at the first iteration
                self.simulate_ddos_attack(G, attack_node_id, target_ids, 0.5, 0.5)  # Increase latency by 50% and reduce throughput by 50%
                current_metrics = {node: {'latency': G.nodes[node]['latency'], 'throughput': G.nodes[node]['throughput'], 'battery': G.nodes[node]['battery']} for node in G.nodes()}
                print("Current metrics:", current_metrics)
            # Generate and route network traffic
            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)

            # Log the routed packets information
            for i, packet in enumerate(routed_packets):
                print(f"  Packet {i}: Source: {packet['source']}, Target: {packet['target']}, "
                    f"Size: {packet['size']}, Delivered: {packet['delivered']}, "
                    f"Path: {packet['path']}, Total Latency: {packet['total_latency']}")

            # Capture metrics
            current_metrics = {node: {'latency': G.nodes[node]['latency'], 'throughput': G.nodes[node]['throughput']} for node in G.nodes()}
            print("Current metrics:", current_metrics)
            metrics.append((time.time() - start_time, current_metrics))
            # Wait for the next update
            time.sleep(update_interval)
            iteration += 1
        return metrics

    def plot_time_series(self, results):
        import matplotlib.pyplot as plt

        # Filter results for a specific node for clarity, e.g., node 0
        node_results = [res for res in results if res['node_id'] == 0]
        times = [res['time'] for res in node_results]
        latencies = [res['latency'] for res in node_results]
        throughputs = [res['throughput'] for res in node_results]

        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(times, latencies, marker='o', color='r')
        plt.title('Latency Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Latency (ms)')

        plt.subplot(1, 2, 2)
        plt.plot(times, throughputs, marker='o', color='b')
        plt.title('Throughput Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Throughput (Mbps)')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# Here we create the original graph and assign standard through put and latency values to each UAV. More nodes can be added to the network by parsing a new value to the "num_uavs" parameters below. Connections between nodes are based on node range and Euclidean distance.

# %%
"""Creating The Network First"""
# Simulation Parameters
num_uavs = 10
connection_range = 30
ground_station_pos = (50, 50)
backbone_range = 50
num_packets = 10

total_time = 60  # Total time to run the simulation in seconds
update_interval = 5  # Time interval between updates in seconds
move_range = 5

# Initialize Simulation
simulation = UAVNetworkSimulation(URI, AUTH)

# Create and Setup UAV Network
uav_network = simulation.create_initial_graph(num_uavs, connection_range, ground_station_pos, backbone_range)

# Upload to Neo4j
simulation.upload_to_neo4j(uav_network)

# Draw Initial Graph
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

# %% [markdown]
# We run our movement simulation code, in the process UAVs can make new communications as they are currently routing fictional packets. We log the results below immediately and generate data based on our routing logic. Perform descriptive statistics.

# %%
"""Routing Simulation"""
# Run the Simulation
results = simulation.run_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets)

# Update network connections
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# Update Neo4j Database with the new positions and connections
simulation.update_neo4j_database(uav_network)

# Now draw the graph to visualize the updated network
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

simulation.plot_time_series(results)
# Out:
# Iteration 0:
# [{'time': 0.001985311508178711, 'node_id': 0, 'latency': 31, 'throughput': 95}, {'time': 0.001985311508178711, 'node_id': 1, 'latency': 51, 'throughput': 62}, {'time': 0.001985311508178711, 'node_id': 2, 'latency': 31, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 3, 'latency': 25, 'throughput': 82}, {'time': 0.001985311508178711, 'node_id': 4, 'latency': 15, 'throughput': 68}, {'time': 0.001985311508178711, 'node_id': 5, 'latency': 20, 'throughput': 96}, {'time': 0.001985311508178711, 'node_id': 6, 'latency': 34, 'throughput': 74}, {'time': 0.001985311508178711, 'node_id': 7, 'latency': 51, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 8, 'latency': 36, 'throughput': 68}, {'time': 0.001985311508178711, 'node_id': 9, 'latency': 41, 'throughput': 69}, {'time': 0.001985311508178711, 'node_id': 10, 'latency': 42, 'throughput': 74}, {'time': 0.001985311508178711, 'node_id': 11, 'latency': 42, 'throughput': 83}]
#   Packet 0: Source: 0, Target: 5, Size: 37, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 9, Target: 7, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 0, Target: 4, Size: 44, Delivered: True, Path: [0, 4], Total Latency: 46
#   Packet 3: Source: 7, Target: 3, Size: 5, Delivered: True, Path: [7, 3], Total Latency: 76
#   Packet 4: Source: 2, Target: 0, Size: 79, Delivered: True, Path: [2, 0], Total Latency: 62
#   Packet 5: Source: 6, Target: 2, Size: 72, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 8, Size: 52, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 7, Target: 7, Size: 23, Delivered: True, Path: [7], Total Latency: 51
#   Packet 8: Source: 9, Target: 4, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 8, Target: 8, Size: 59, Delivered: True, Path: [8], Total Latency: 36
# Iteration 1:
# [{'time': 0.001985311508178711, 'node_id': 0, 'latency': 31, 'throughput': 95}, {'time': 0.001985311508178711, 'node_id': 1, 'latency': 51, 'throughput': 62}, {'time': 0.001985311508178711, 'node_id': 2, 'latency': 31, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 3, 'latency': 25, 'throughput': 82}, {'time': 0.001985311508178711, 'node_id': 4, 'latency': 15, 'throughput': 68}, {'time': 0.001985311508178711, 'node_id': 5, 'latency': 20, 'throughput': 96}, {'time': 0.001985311508178711, 'node_id': 6, 'latency': 34, 'throughput': 74}, {'time': 0.001985311508178711, 'node_id': 7, 'latency': 51, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 8, 'latency': 36, 'throughput': 68}, {'time': 0.001985311508178711, 'node_id': 9, 'latency': 41, 'throughput': 69}, {'time': 0.001985311508178711, 'node_id': 10, 'latency': 42, 'throughput': 74}, {'time': 0.001985311508178711, 'node_id': 11, 'latency': 42, 'throughput': 83}, {'time': 5.014408826828003, 'node_id': 0, 'latency': 32, 'throughput': 101}, {'time': 5.014408826828003, 'node_id': 1, 'latency': 51, 'throughput': 67}, {'time': 5.014408826828
, 'latency': 39, 'throughput': 69}, {'time': 10.028316736221313, 'node_id': 9, 'latency': 41, 'throughput': 69}, {'time': 10.028316736221313, 'node_id': 10, 'latency': 43, 'throughput': 75}, {'time': 10.028316736221313, 'node_id': 11, 'latency': 42, 'throughput': 78}, {'time': 15.041766166687012, 'node_id': 0, 'latency': 26, 'throughput': 101}, {'time': 15.041766166687012, 'node_id': 1, 'latency': 47, 'throughput': 71}, {'time': 15.041766166687012, 'node_id': 2, 'latency': 35, 'throughput': 82}, {'time': 15.041766166687012, 'node_id': 3, 'latency': 31, 'throughput': 102}, {'time': 15.041766166687012, 'node_id': 4, 'latency': 18, 'throughput': 74}, {'time': 15.041766166687012, 'node_id': 5, 'latency': 15, 'throughput': 89}, {'time': 15.041766166687012, 'node_id': 6, 'latency': 32, 'throughput': 78}, {'time': 15.041766166687012, 'node_id': 7, 'latency': 53, 'throughput': 92}, {'time': 15.041766166687012, 'node_id': 8, 'latency': 40, 'throughput': 76}, {'time': 15.041766166687012, 'node_id': 9, 'latency': 42, 'throughput': 69}, {'time': 15.041766166687012, 'node_id': 10, 'latency': 48, 'throughput': 67}, {'time': 15.041766166687012, 'node_id': 11, 'latency': 46, 'throughput': 87}, {'time': 20.052628993988037, 'node_id': 0, 'latency': 21, 'throughput': 106}, {'time': 20.052628993988037, 'node_id': 1, 'latency': 44, 'throughput': 80}, {'time': 20.052628993988037, 'node_id': 2, 'latency': 32, 'throughput': 74}, {'time': 20.052628993988037, 'node_id': 3, 'late ...
#   Packet 0: Source: 9, Target: 6, Size: 51, Delivered: True, Path: [9, 8, 6], Total Latency: 113
#   Packet 1: Source: 1, Target: 9, Size: 42, Delivered: True, Path: [1, 0, 5, 8, 9], Total Latency: 170
#   Packet 2: Source: 5, Target: 8, Size: 83, Delivered: True, Path: [5, 8], Total Latency: 61
#   Packet 3: Source: 6, Target: 3, Size: 34, Delivered: True, Path: [6, 5, 3], Total Latency: 81
#   Packet 4: Source: 7, Target: 8, Size: 34, Delivered: True, Path: [7, 3, 5, 8], Total Latency: 136
#   Packet 5: Source: 9, Target: 4, Size: 41, Delivered: True, Path: [9, 8, 5, 0, 4], Total Latency: 139
#   Packet 6: Source: 1, Target: 4, Size: 24, Delivered: True, Path: [1, 0, 4], Total Latency: 81
#   Packet 7: Source: 9, Target: 5, Size: 15, Delivered: True, Path: [9, 8, 5], Total Latency: 104
#   Packet 8: Source: 2, Target: 0, Size: 71, Delivered: True, Path: [2, 0], Total Latency: 48
#   Packet 9: Source: 8, Target: 7, Size: 3, Delivered: True, Path: [8, 5, 3, 7], Total Latency: 136
# Iteration 6:
# [{'time': 0.001985311508178711, 'node_id': 0, 'latency': 31, 'throughput': 95}, {'time': 0.001985311508178711, 'node_id': 1, 'latency': 51, 'throughput': 62}, {'time': 0.001985311508178711, 'node_id': 2, 'latency': 31, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 3, 'latency': 25, 'throughput': 82}, {'time': 0.001985311508178711, 'node_id': 4, 'latency': 15, 'throughput
}, {'time': 15.041766166687012, 'node_id': 7, 'latency': 53, 'throughput': 92}, {'time': 15.041766166687012, 'node_id': 8, 'latency': 40, 'throughput': 76}, {'time': 15.041766166687012, 'node_id': 9, 'latency': 42, 'throughput': 69}, {'time': 15.041766166687012, 'node_id': 10, 'latency': 48, 'throughput': 67}, {'time': 15.041766166687012, 'node_id': 11, 'latency': 46, 'throughput': 87}, {'time': 20.052628993988037, 'node_id': 0, 'latency': 21, 'throughput': 106}, {'time': 20.052628993988037, 'node_id': 1, 'latency': 44, 'throughput': 80}, {'time': 20.052628993988037, 'node_id': 2, 'latency': 32, 'throughput': 74}, {'time': 20.052628993988037, 'node_id': 3, 'late ...
#   Packet 0: Source: 8, Target: 1, Size: 34, Delivered: True, Path: [8, 5, 0, 1], Total Latency: 116
#   Packet 1: Source: 9, Target: 8, Size: 41, Delivered: True, Path: [9, 8], Total Latency: 84
#   Packet 2: Source: 0, Target: 4, Size: 47, Delivered: True, Path: [0, 4], Total Latency: 33
#   Packet 3: Source: 3, Target: 1, Size: 101, Delivered: True, Path: [3, 1], Total Latency: 77
#   Packet 4: Source: 6, Target: 3, Size: 44, Delivered: True, Path: [6, 5, 3], Total Latency: 90
#   Packet 5: Source: 6, Target: 7, Size: 52, Delivered: True, Path: [6, 5, 0, 1, 7], Total Latency: 154
#   Packet 6: Source: 3, Target: 4, Size: 93, Delivered: True, Path: [3, 4], Total Latency: 52
#   Packet 7: Source: 3, Target: 7, Size: 56, Delivered: True, Path: [3, 1, 7], Total Latency: 118
#   Packet 8: Source: 1, Target: 6, Size: 25, Delivered: True, Path: [1, 0, 5, 6], Total Latency: 113
#   Packet 9: Source: 0, Target: 7, Size: 87, Delivered: True, Path: [0, 1, 7], Total Latency: 99
# Iteration 7:
# [{'time': 0.001985311508178711, 'node_id': 0, 'latency': 31, 'throughput': 95}, {'time': 0.001985311508178711, 'node_id': 1, 'latency': 51, 'throughput': 62}, {'time': 0.001985311508178711, 'node_id': 2, 'latency': 31, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 3, 'latency': 25, 'throughput': 82}, {'time': 0.001985311508178711, 'node_id': 4, 'latency': 15, 'throughput': 68}, {'time': 0.001985311508178711, 'node_id': 5, 'latency': 20, 'throughput': 96}, {'time': 0.001985311508178711, 'node_id': 6, 'latency': 34, 'throughput': 74}, {'time': 0.001985311508178711, 'node_id': 7, 'latency': 51, 'throughput': 79}, {'time': 0.001985311508178711, 'node_id': 8, 'latency': 36, 'throughput': 68}, {'time': 0.001985311508178711, 'node_id': 9, 'latency': 41, 'throughput': 69}, {'time': 0.001985311508178711, 'node_id': 10, 'latency': 42, 'throughput': 74}, {'time': 0.001985311508178711, 'node_id': 11, 'latency': 42, 'throughput': 83}, {'time': 5.014408826828003, 'node_id': 0, 'latency': 32, 'throughput': 101}, {'time': 5.014408826828003, 'node_id': 1, 'latency': 51, 'throughput': 67}, {'time': 5.014408826828003, 'node_id': 2, 'latency': 36, 'throughput': 70}, {'time': 5.014408826828003, 'node_
'time': 10.028316736221313, 'node_id': 5, 'latency': 13, 'throughput': 90}, {'time': 10.028316736221313, 'node_id': 6, 'latency': 35, 'throughput': 78}, {'time': 10.028316736221313, 'node_id': 7, 'latency': 54, 'throughput': 92}, {'time': 10.028316736221313, 'node_id': 8, 'latency': 39, 'throughput': 69}, {'time': 10.028316736221313, 'node_id': 9, 'latency': 41, 'throughput': 69}, {'time': 10.028316736221313, 'node_id': 10, 'latency': 43, 'throughput': 75}, {'time': 10.028316736221313, 'node_id': 11, 'latency': 42, 'throughput': 78}, {'time': 15.041766166687012, 'node_id': 0, 'latency': 26, 'throughput': 101}, {'time': 15.041766166687012, 'node_id': 1, 'latency': 47, 'throughput': 71}, {'time': 15.041766166687012, 'node_id': 2, 'latency': 35, 'throughput': 82}, {'time': 15.041766166687012, 'node_id': 3, 'latency': 31, 'throughput': 102}, {'time': 15.041766166687012, 'node_id': 4, 'latency': 18, 'throughput': 74}, {'time': 15.041766166687012, 'node_id': 5, 'latency': 15, 'throughput': 89}, {'time': 15.041766166687012, 'node_id': 6, 'latency': 32, 'throughput': 78}, {'time': 15.041766166687012, 'node_id': 7, 'latency': 53, 'throughput': 92}, {'time': 15.041766166687012, 'node_id': 8, 'latency': 40, 'throughput': 76}, {'time': 15.041766166687012, 'node_id': 9, 'latency': 42, 'throughput': 69}, {'time': 15.041766166687012, 'node_id': 10, 'latency': 48, 'throughput': 67}, {'time': 15.041766166687012, 'node_id': 11, 'latency': 46, 'throughput': 87}, {'time': 20.052628993988037, 'node_id': 0, 'latency': 21, 'throughput': 106}, {'time': 20.052628993988037, 'node_id': 1, 'latency': 44, 'throughput': 80}, {'time': 20.052628993988037, 'node_id': 2, 'latency': 32, 'throughput': 74}, {'time': 20.052628993988037, 'node_id': 3, 'late ...
#   Packet 0: Source: 3, Target: 0, Size: 35, Delivered: True, Path: [3, 0], Total Latency: 55
#   Packet 1: Source: 7, Target: 4, Size: 72, Delivered: True, Path: [7, 1, 0, 4], Total Latency: 104
#   Packet 2: Source: 7, Target: 1, Size: 3, Delivered: True, Path: [7, 1], Total Latency: 75
#   Packet 3: Source: 1, Target: 8, Size: 49, Delivered: True, Path: [1, 0, 5, 8], Total Latency: 130
#   Packet 4: Source: 7, Target: 5, Size: 4, Delivered: True, Path: [7, 1, 0, 5], Total Latency: 115
#   Packet 5: Source: 3, Target: 9, Size: 116, Delivered: True, Path: [3, 0, 5, 8, 9], Total Latency: 167
#   Packet 6: Source: 6, Target: 5, Size: 47, Delivered: True, Path: [6, 5], Total Latency: 61
#   Packet 7: Source: 9, Target: 6, Size: 1, Delivered: True, Path: [9, 8, 6], Total Latency: 125
#   Packet 8: Source: 6, Target: 3, Size: 18, Delivered: True, Path: [6, 5, 0, 3], Total Latency: 116
#   Packet 9: Source: 4, Target: 6, Size: 57, Delivered: True, Path: [4, 0, 5, 6], Total Latency: 90
# C:\Users\Solomon\AppData\Local\Temp\ipykernel_22988\1866737523.py:182: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with self.driver.session() as session:

# %% [markdown]
# Adding The Attack Node.

# %%
#Add Attack Node
# Initialize the simulation object and create the initial UAV network
simulation = UAVNetworkSimulation(URI, AUTH)
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# # Upload the initial UAV network to Neo4j
simulation.upload_to_neo4j(uav_network)

# Target UAV ID for the DDoS attack
target_uav_ids = [5, 7] # Example: Target UAV ID that you want to attack

# Add the attack node and connect it to the target UAV
attack_node_id = simulation.add_attack_node(uav_network, target_uav_ids, num_uavs)
simulation.upload_attack_node_to_neo4j(uav_network, attack_node_id, target_uav_ids)

# Optionally, visualize the updated network to confirm the addition and connection of the attack node
simulation.draw_graph(uav_network)

# Close the Neo4j connection at the end of the session
simulation.close()

# %%
"""DDoS Simulation"""
# Initialize your network G here
target_nodes = [5, 7]  # Target node IDs that will be affected by the DDoS attack
# Assuming you have an attack node and some target nodes
attack_node_id = simulation.add_attack_node(uav_network, target_nodes, num_uavs)  # ID of your attack node

total_time = 120  # For example, run the simulation for 120 seconds
update_interval = 5
move_range = 10
connection_range = 30
backbone_range = 50
num_packets = 10
target_ids = [5, 7]  # Targeting nodes 5 and 7 for the DDoS attack

# Run the DDoS simulation
simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)
# Out:
# Iteration 0:
#   Packet 0: Source: 12, Target: 9, Size: 128, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 5, Target: 8, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 0, Target: 2, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 10, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 0, Target: 11, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 8, Target: 12, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 5, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 12, Target: 0, Size: 142, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 1, Target: 12, Size: 16, Delivered: True, Path: [1, 12], Total Latency: 56
#   Packet 9: Source: 1, Target: 5, Size: 3, Delivered: True, Path: [1, 13, 5], Total Latency: 59
# Current metrics: {0: {'latency': 38, 'throughput': 17}, 1: {'latency': 24, 'throughput': 23}, 2: {'latency': 12, 'throughput': 69}, 3: {'latency': 14, 'throughput': 66}, 4: {'latency': 4, 'throughput': 35}, 5: {'latency': 34, 'throughput': 1}, 6: {'latency': 4, 'throughput': 20}, 7: {'latency': 23, 'throughput': 47}, 8: {'latency': 32, 'throughput': 2}, 9: {'latency': 52, 'throughput': 99}, 10: {'latency': 1, 'throughput': 24}, 11: {'latency': 47, 'throughput': 37}, 12: {'latency': 32, 'throughput': 143}, 13: {'latency': 1, 'throughput': 997}, 14: {'latency': 3, 'throughput': 991}}
# Iteration 1:
# Current metrics: {0: {'latency': 34, 'throughput': 17, 'battery': 100}, 1: {'latency': 20, 'throughput': 32, 'battery': 60}, 2: {'latency': 16, 'throughput': 72, 'battery': 60}, 3: {'latency': 18, 'throughput': 68, 'battery': 60}, 4: {'latency': 0, 'throughput': 21, 'battery': 12}, 5: {'latency': 15, 'throughput': 1, 'battery': 12}, 6: {'latency': 4, 'throughput': 14, 'battery': 60}, 7: {'latency': 9, 'throughput': 26, 'battery': 12}, 8: {'latency': 30, 'throughput': 11, 'battery': 60}, 9: {'latency': 20, 'throughput': 60, 'battery': 60}, 10: {'latency': 1, 'throughput': 23, 'battery': 60}, 11: {'latency': 42, 'throughput': 31, 'battery': 60}, 12: {'latency': 27, 'throughput': 137, 'battery': 12}, 13: {'latency': 0, 'throughput': 602, 'battery': 60}, 14: {'latency': 0, 'throughput': 357, 'battery': 36}}
#   Packet 0: Source: 10, Target: 12, Size: 17, Delivered: True, Path: [10, 13, 12], Total Latency: 28
#   Packet 1: Source: 3, Target: 8, Size: 38, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 6, Target: 8, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 9, Target: 11, Size: 16, Delivered: True, Path: [9, 7, 14, 5, 13, 11], Total Latency: 86
#   Packet 4: Source: 12, Target: 4, Size: 90, Delivered: True, Path: [12, 13, 4], Total Latency: 27
#   Packet 5: Source: 11, Target: 7, Size: 3, Delivered: True, Path: [11, 13, 5, 14, 7], Total Latency: 66
#   Packet 6: Source: 8, Target: 11, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 8, Target: 12, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 8, Target: 6, Size: 6, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 12, Target: 10, Size: 123, Delivered: True, Path: [12, 13, 10], Total Latency: 28
# Current metrics: {0: {'latency': 34, 'throughput': 17}, 1: {'latency': 20, 'throughput': 32}, 2: {'latency': 16, 'throughput': 72}, 3: {'latency': 18, 'throughput': 68}, 4: {'latency': 0, 'throughput': 21}, 5: {'latency': 15, 'throughput': 1}, 6: {'latency': 4, 'throughput': 14}, 7: {'latency': 9, 'throughput': 26}, 8: {'latency': 30, 'throughput': 11}, 9: {'latency': 20, 'throughput': 60}, 10: {'latency': 1, 'throughput': 23}, 11: {'latency': 42, 'throughput': 31}, 12: {'latency': 27, 'throughput': 137}, 13: {'latency': 0, 'throughput': 602}, 14: {'latency': 0, 'throughput': 357}}
# Iteration 2:
#   Packet 0: Source: 4, Target: 12, Size: 11, Delivered: True, Path: [4, 3, 1, 12], Total Latency: 64
#   Packet 1: Source: 5, Target: 2, Size: 7, Delivered: True, Path: [5, 13, 2], Total Latency: 31
#   Packet 2: Source: 6, Target: 11, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 7, Target: 2, Size: 6, Delivered: True, Path: [7, 14, 5, 13, 2], Total Latency: 40
#   Packet 4: Source: 5, Target: 7, Size: 5, Delivered: True, Path: [5, 14, 7], Total Latency: 23
#   Packet 5: Source: 1, Target: 6, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 0, Target: 1, Size: 21, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 3, Target: 8, Size: 40, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 1, Target: 8, Size: 25, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 12, Target: 6, Size: 81, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 32, 'throughput': 24}, 1: {'latency': 19, 'throughput': 38}, 2: {'latency': 12, 'throughput': 74}, 3: {'latency': 19, 'throughput': 77}, 4: {'latency': 2, 'throughput': 11}, 5: {'latency': 14, 'throughput': 10}, 6: {'latency': 8, 'throughput': 15}, 7: {'latency': 8, 'throughput': 16}, 8: {'latency': 31, 'throughput': 11}, 9: {'latency': 18, 'throughput': 60}, 10: {'latency': 1, 'throughput': 23}, 11: {'latency': 37, 'throughput': 32}, 12: {'latency': 24, 'throughput': 131}, 13: {'latency': 5, 'throughput': 595}, 14: {'latency': 1, 'throughput': 359}}
# Iteration 3:
#   Packet 0: Source: 0, Target: 5, Size: 31, Delivered: True, Path: [0, 12, 2, 13, 5], Total Latency: 76
#   Packet 1: Source: 9, Target: 10, Size: 27, Delivered: True, Path: [9, 7, 14, 5, 13, 10], Total Latency: 53
#   Packet 2: Source: 2, Target: 8, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 2, Target: 5, Size: 74, Delivered: True, Path: [2, 13, 5], Total Latency: 30
#   Packet 4: Source: 12, Target: 4, Size: 96, Delivered: True, Path: [12, 2, 13, 4], Total Latency: 39
#   Packet 5: Source: 10, Target: 11, Size: 29, Delivered: True, Path: [10, 13, 2, 11], Total Latency: 61
#   Packet 6: Source: 1, Target: 9, Size: 2, Delivered: True, Path: [1, 13, 5, 14, 7, 9], Total Latency: 71
#   Packet 7: Source: 7, Target: 6, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 6, Target: 1, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 4, Target: 12, Size: 17, Delivered: True, Path: [4, 13, 2, 12], Total Latency: 39
# Current metrics: {0: {'latency': 27, 'throughput': 33}, 1: {'latency': 23, 'throughput': 34}, 2: {'latency': 10, 'throughput': 78}, 3: {'latency': 22, 'throughput': 78}, 4: {'latency': 1, 'throughput': 20}, 5: {'latency': 11, 'throughput': 20}, 6: {'latency': 8, 'throughput': 6}, 7: {'latency': 9, 'throughput': 18}, 8: {'latency': 33, 'throughput': 7}, 9: {'latency': 13, 'throughput': 58}, 10: {'latency': 5, 'throughput': 31}, 11: {'latency': 37, 'throughput': 31}, 12: {'latency': 19, 'throughput': 126}, 13: {'latency': 9, 'throughput': 589}, 14: {'latency': 6, 'throughput': 358}}
# Iteration 4:
#   Packet 0: Source: 7, Target: 4, Size: 10, Delivered: True, Path: [7, 14, 5, 4], Total Latency: 27
#   Packet 1: Source: 5, Target: 0, Size: 9, Delivered: True, Path: [5, 13, 3, 0], Total Latency: 71
#   Packet 2: Source: 9, Target: 12, Size: 40, Delivered: True, Path: [9, 7, 14, 5, 13, 2, 12], Total Latency: 76
#   Packet 3: Source: 10, Target: 7, Size: 19, Delivered: True, Path: [10, 13, 5, 14, 7], Total Latency: 40
#   Packet 4: Source: 11, Target: 4, Size: 8, Delivered: True, Path: [11, 13, 4], Total Latency: 52
#   Packet 5: Source: 3, Target: 7, Size: 53, Delivered: True, Path: [3, 13, 5, 14, 7], Total Latency: 55
#   Packet 6: Source: 3, Target: 6, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 7, Target: 0, Size: 1, Delivered: True, Path: [7, 14, 5, 13, 3, 0], Total Latency: 81
#   Packet 8: Source: 0, Target: 7, Size: 2, Delivered: True, Path: [0, 3, 13, 5, 14, 7], Total Latency: 81
#   Packet 9: Source: 9, Target: 1, Size: 12, Delivered: True, Path: [9, 7, 14, 5, 13, 1], Total Latency: 81
# Current metrics: {0: {'latency': 26, 'throughput': 41}, 1: {'latency': 28, 'throughput': 43}, 2: {'latency': 5, 'throughput': 75}, 3: {'latency': 18, 'throughput': 69}, 4: {'latency': 1, 'throughput': 22}, 5: {'latency': 16, 'throughput': 27}, 6: {'latency': 11, 'throughput': 13}, 7: {'latency': 4, 'throughput': 25}, 8: {'latency': 29, 'throughput': 8}, 9: {'latency': 16, 'throughput': 48}, 10: {'latency': 3, 'throughput': 30}, 11: {'latency': 40, 'throughput': 21}, 12: {'latency': 18, 'throughput': 132}, 13: {'latency': 11, 'throughput': 590}, 14: {'latency': 6, 'throughput': 368}}
# Iteration 5:
#   Packet 0: Source: 2, Target: 7, Size: 47, Delivered: True, Path: [2, 13, 5, 14, 7], Total Latency: 43
#   Packet 1: Source: 5, Target: 0, Size: 19, Delivered: True, Path: [5, 13, 3, 0], Total Latency: 72
#   Packet 2: Source: 6, Target: 12, Size: 6, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 5, Target: 2, Size: 4, Delivered: True, Path: [5, 13, 2], Total Latency: 35
#   Packet 4: Source: 8, Target: 9, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 12, Target: 1, Size: 55, Delivered: True, Path: [12, 2, 1], Total Latency: 51
#   Packet 6: Source: 8, Target: 6, Size: 12, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 3, Target: 5, Size: 42, Delivered: True, Path: [3, 13, 5], Total Latency: 47
#   Packet 8: Source: 8, Target: 12, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 2, Target: 3, Size: 28, Delivered: True, Path: [2, 1, 3], Total Latency: 53
# Current metrics: {0: {'latency': 25, 'throughput': 45}, 1: {'latency': 33, 'throughput': 39}, 2: {'latency': 4, 'throughput': 81}, 3: {'latency': 16, 'throughput': 74}, 4: {'latency': 1, 'throughput': 17}, 5: {'latency': 21, 'throughput': 21}, 6: {'latency': 12, 'throughput': 13}, 7: {'latency': 4, 'throughput': 29}, 8: {'latency': 26, 'throughput': 17}, 9: {'latency': 21, 'throughput': 50}, 10: {'latency': 4, 'throughput': 26}, 11: {'latency': 37, 'throughput': 17}, 12: {'latency': 14, 'throughput': 139}, 13: {'latency': 10, 'throughput': 592}, 14: {'latency': 4, 'throughput': 360}}
# Iteration 6:
#   Packet 0: Source: 5, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 5, Target: 5, Size: 8, Delivered: True, Path: [5], Total Latency: 20
#   Packet 2: Source: 6, Target: 3, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 0, Target: 1, Size: 3, Delivered: True, Path: [0, 3, 13, 1], Total Latency: 89
#   Packet 4: Source: 12, Target: 12, Size: 131, Delivered: True, Path: [12], Total Latency: 16
#   Packet 5: Source: 6, Target: 12, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 5, Target: 3, Size: 2, Delivered: True, Path: [5, 13, 3], Total Latency: 48
#   Packet 7: Source: 10, Target: 7, Size: 18, Delivered: True, Path: [10, 13, 5, 14, 7], Total Latency: 51
#   Packet 8: Source: 9, Target: 10, Size: 6, Delivered: True, Path: [9, 7, 14, 5, 13, 10], Total Latency: 71
#   Packet 9: Source: 4, Target: 11, Size: 4, Delivered: True, Path: [4, 13, 11], Total Latency: 50
# Current metrics: {0: {'latency': 24, 'throughput': 48}, 1: {'latency': 37, 'throughput': 43}, 2: {'latency': 9, 'throughput': 72}, 3: {'latency': 15, 'throughput': 70}, 4: {'latency': 1, 'throughput': 9}, 5: {'latency': 20, 'throughput': 11}, 6: {'latency': 9, 'throughput': 7}, 7: {'latency': 8, 'throughput': 35}, 8: {'latency': 29, 'throughput': 12}, 9: {'latency': 20, 'throughput': 45}, 10: {'latency': 1, 'throughput': 34}, 11: {'latency': 36, 'throughput': 11}, 12: {'latency': 16, 'throughput': 147}, 13: {'latency': 13, 'throughput': 592}, 14: {'latency': 9, 'throughput': 366}}
# Iteration 7:
#   Packet 0: Source: 1, Target: 5, Size: 22, Delivered: True, Path: [1, 13, 5], Total Latency: 77
#   Packet 1: Source: 4, Target: 8, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 1, Target: 12, Size: 21, Delivered: True, Path: [1, 12], Total Latency: 52
#   Packet 3: Source: 0, Target: 0, Size: 9, Delivered: True, Path: [0], Total Latency: 21
#   Packet 4: Source: 3, Target: 1, Size: 5, Delivered: True, Path: [3, 13, 1], Total Latency: 72
#   Packet 5: Source: 9, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 11, Target: 11, Size: 2, Delivered: True, Path: [11], Total Latency: 35
#   Packet 7: Source: 0, Target: 0, Size: 9, Delivered: True, Path: [0], Total Latency: 21
#   Packet 8: Source: 9, Target: 0, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 4, Target: 2, Size: 4, Delivered: True, Path: [4, 13, 2], Total Latency: 29
# Current metrics: {0: {'latency': 21, 'throughput': 55}, 1: {'latency': 40, 'throughput': 48}, 2: {'latency': 14, 'throughput': 64}, 3: {'latency': 18, 'throughput': 60}, 4: {'latency': 1, 'throughput': 14}, 5: {'latency': 23, 'throughput': 21}, 6: {'latency': 4, 'throughput': 12}, 7: {'latency': 7, 'throughput': 27}, 8: {'latency': 27, 'throughput': 5}, 9: {'latency': 15, 'throughput': 41}, 10: {'latency': 3, 'throughput': 24}, 11: {'latency': 35, 'throughput': 15}, 12: {'latency': 12, 'throughput': 147}, 13: {'latency': 14, 'throughput': 584}, 14: {'latency': 6, 'throughput': 372}}
# Iteration 8:
#   Packet 0: Source: 11, Target: 11, Size: 15, Delivered: True, Path: [11], Total Latency: 37
#   Packet 1: Source: 5, Target: 9, Size: 6, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 8, Target: 11, Size: 11, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 5, Target: 11, Size: 11, Delivered: True, Path: [5, 13, 11], Total Latency: 77
#   Packet 4: Source: 1, Target: 7, Size: 27, Delivered: True, Path: [1, 13, 5, 14, 7], Total Latency: 100
#   Packet 5: Source: 7, Target: 12, Size: 27, Delivered: True, Path: [7, 14, 5, 13, 1, 12], Total Latency: 107
#   Packet 6: Source: 12, Target: 2, Size: 136, Delivered: True, Path: [12, 1, 2], Total Latency: 64
#   Packet 7: Source: 3, Target: 1, Size: 38, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 11, Target: 4, Size: 3, Delivered: True, Path: [11, 13, 4], Total Latency: 55
#   Packet 9: Source: 9, Target: 0, Size: 28, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 26, 'throughput': 48}, 1: {'latency': 38, 'throughput': 56}, 2: {'latency': 19, 'throughput': 58}, 3: {'latency': 19, 'throughput': 57}, 4: {'latency': 1, 'throughput': 22}, 5: {'latency': 23, 'throughput': 14}, 6: {'latency': 1, 'throughput': 15}, 7: {'latency': 11, 'throughput': 35}, 8: {'latency': 28, 'throughput': 14}, 9: {'latency': 16, 'throughput': 42}, 10: {'latency': 1, 'throughput': 14}, 11: {'latency': 37, 'throughput': 18}, 12: {'latency': 7, 'throughput': 140}, 13: {'latency': 17, 'throughput': 594}, 14: {'latency': 11, 'throughput': 362}}
# Iteration 9:
#   Packet 0: Source: 0, Target: 2, Size: 43, Delivered: True, Path: [0, 2], Total Latency: 40
#   Packet 1: Source: 6, Target: 9, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 2, Target: 4, Size: 7, Delivered: True, Path: [2, 13, 4], Total Latency: 30
#   Packet 3: Source: 8, Target: 10, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 5, Target: 0, Size: 4, Delivered: True, Path: [5, 13, 2, 0], Total Latency: 82
#   Packet 5: Source: 2, Target: 6, Size: 6, Delivered: True, Path: [2, 0, 6], Total Latency: 44
#   Packet 6: Source: 2, Target: 11, Size: 25, Delivered: True, Path: [2, 1, 11], Total Latency: 94
#   Packet 7: Source: 0, Target: 1, Size: 30, Delivered: True, Path: [0, 2, 1], Total Latency: 79
#   Packet 8: Source: 11, Target: 11, Size: 2, Delivered: True, Path: [11], Total Latency: 41
#   Packet 9: Source: 7, Target: 6, Size: 12, Delivered: True, Path: [7, 14, 5, 13, 2, 0, 6], Total Latency: 105
# Current metrics: {0: {'latency': 26, 'throughput': 44}, 1: {'latency': 39, 'throughput': 46}, 2: {'latency': 14, 'throughput': 58}, 3: {'latency': 19, 'throughput': 56}, 4: {'latency': 1, 'throughput': 26}, 5: {'latency': 27, 'throughput': 8}, 6: {'latency': 4, 'throughput': 11}, 7: {'latency': 6, 'throughput': 44}, 8: {'latency': 32, 'throughput': 11}, 9: {'latency': 21, 'throughput': 33}, 10: {'latency': 2, 'throughput': 14}, 11: {'latency': 41, 'throughput': 9}, 12: {'latency': 2, 'throughput': 147}, 13: {'latency': 15, 'throughput': 598}, 14: {'latency': 13, 'throughput': 356}}
# Iteration 10:
#   Packet 0: Source: 12, Target: 3, Size: 35, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 11, Target: 4, Size: 5, Delivered: True, Path: [11, 13, 4], Total Latency: 52
#   Packet 2: Source: 8, Target: 5, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 1, Target: 1, Size: 21, Delivered: True, Path: [1], Total Latency: 38
#   Packet 4: Source: 9, Target: 12, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 0, Target: 0, Size: 31, Delivered: True, Path: [0], Total Latency: 29
#   Packet 6: Source: 10, Target: 9, Size: 8, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 6, Target: 10, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 0, Target: 10, Size: 11, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 5, Target: 11, Size: 15, Delivered: True, Path: [5, 13, 11], Total Latency: 82
# Current metrics: {0: {'latency': 29, 'throughput': 36}, 1: {'latency': 38, 'throughput': 39}, 2: {'latency': 10, 'throughput': 60}, 3: {'latency': 18, 'throughput': 53}, 4: {'latency': 1, 'throughput': 17}, 5: {'latency': 31, 'throughput': 15}, 6: {'latency': 3, 'throughput': 21}, 7: {'latency': 11, 'throughput': 40}, 8: {'latency': 31, 'throughput': 6}, 9: {'latency': 25, 'throughput': 31}, 10: {'latency': 5, 'throughput': 14}, 11: {'latency': 37, 'throughput': 12}, 12: {'latency': 1, 'throughput': 138}, 13: {'latency': 14, 'throughput': 598}, 14: {'latency': 18, 'throughput': 364}}
# Iteration 11:
#   Packet 0: Source: 11, Target: 3, Size: 1, Delivered: True, Path: [11, 13, 3], Total Latency: 67
#   Packet 1: Source: 0, Target: 6, Size: 8, Delivered: True, Path: [0, 6], Total Latency: 28
#   Packet 2: Source: 5, Target: 7, Size: 1, Delivered: True, Path: [5, 14, 7], Total Latency: 58
#   Packet 3: Source: 2, Target: 1, Size: 37, Delivered: True, Path: [2, 1], Total Latency: 51
#   Packet 4: Source: 7, Target: 11, Size: 28, Delivered: True, Path: [7, 14, 5, 13, 11], Total Latency: 108
#   Packet 5: Source: 5, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 12, Target: 10, Size: 116, Delivered: True, Path: [12, 13, 10], Total Latency: 26
#   Packet 7: Source: 0, Target: 4, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 5, Target: 12, Size: 15, Delivered: True, Path: [5, 13, 12], Total Latency: 43
#   Packet 9: Source: 5, Target: 2, Size: 10, Delivered: True, Path: [5, 13, 2], Total Latency: 51
# Current metrics: {0: {'latency': 24, 'throughput': 46}, 1: {'latency': 42, 'throughput': 45}, 2: {'latency': 9, 'throughput': 53}, 3: {'latency': 17, 'throughput': 47}, 4: {'latency': 4, 'throughput': 14}, 5: {'latency': 27, 'throughput': 25}, 6: {'latency': 4, 'throughput': 22}, 7: {'latency': 9, 'throughput': 40}, 8: {'latency': 35, 'throughput': 1}, 9: {'latency': 22, 'throughput': 34}, 10: {'latency': 10, 'throughput': 8}, 11: {'latency': 35, 'throughput': 3}, 12: {'latency': 1, 'throughput': 141}, 13: {'latency': 15, 'throughput': 590}, 14: {'latency': 22, 'throughput': 372}}
# Iteration 12:
#   Packet 0: Source: 10, Target: 1, Size: 1, Delivered: True, Path: [10, 13, 1], Total Latency: 63
#   Packet 1: Source: 2, Target: 9, Size: 37, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 5, Target: 4, Size: 4, Delivered: True, Path: [5, 13, 4], Total Latency: 46
#   Packet 3: Source: 11, Target: 3, Size: 1, Delivered: True, Path: [11, 13, 3], Total Latency: 62
#   Packet 4: Source: 10, Target: 12, Size: 3, Delivered: True, Path: [10, 13, 12], Total Latency: 23
#   Packet 5: Source: 12, Target: 3, Size: 39, Delivered: True, Path: [12, 13, 3], Total Latency: 32
#   Packet 6: Source: 5, Target: 1, Size: 14, Delivered: True, Path: [5, 13, 1], Total Latency: 81
#   Packet 7: Source: 9, Target: 1, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 3, Target: 9, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 1, Target: 11, Size: 35, Delivered: True, Path: [1, 11], Total Latency: 78
# Current metrics: {0: {'latency': 24, 'throughput': 37}, 1: {'latency': 44, 'throughput': 49}, 2: {'latency': 14, 'throughput': 51}, 3: {'latency': 18, 'throughput': 48}, 4: {'latency': 9, 'throughput': 17}, 5: {'latency': 27, 'throughput': 32}, 6: {'latency': 9, 'throughput': 19}, 7: {'latency': 4, 'throughput': 30}, 8: {'latency': 33, 'throughput': 5}, 9: {'latency': 19, 'throughput': 40}, 10: {'latency': 9, 'throughput': 15}, 11: {'latency': 34, 'throughput': 13}, 12: {'latency': 4, 'throughput': 149}, 13: {'latency': 10, 'throughput': 586}, 14: {'latency': 18, 'throughput': 379}}
# Iteration 13:
#   Packet 0: Source: 3, Target: 9, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 11, Target: 10, Size: 7, Delivered: True, Path: [11, 4, 10], Total Latency: 54
#   Packet 2: Source: 10, Target: 12, Size: 15, Delivered: True, Path: [10, 4, 12], Total Latency: 23
#   Packet 3: Source: 0, Target: 2, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 7, Target: 11, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 11, Target: 9, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 3, Target: 0, Size: 42, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 5, Target: 11, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 11, Target: 6, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 5, Target: 12, Size: 38, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 29, 'throughput': 34}, 1: {'latency': 47, 'throughput': 47}, 2: {'latency': 13, 'throughput': 46}, 3: {'latency': 15, 'throughput': 46}, 4: {'latency': 8, 'throughput': 10}, 5: {'latency': 29, 'throughput': 38}, 6: {'latency': 13, 'throughput': 21}, 7: {'latency': 7, 'throughput': 25}, 8: {'latency': 38, 'throughput': 4}, 9: {'latency': 15, 'throughput': 36}, 10: {'latency': 8, 'throughput': 15}, 11: {'latency': 38, 'throughput': 12}, 12: {'latency': 7, 'throughput': 153}, 13: {'latency': 6, 'throughput': 583}, 14: {'latency': 23, 'throughput': 387}}
# Iteration 14:
#   Packet 0: Source: 8, Target: 6, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 11, Target: 9, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 12, Target: 11, Size: 117, Delivered: True, Path: [12, 11], Total Latency: 42
#   Packet 3: Source: 12, Target: 1, Size: 21, Delivered: True, Path: [12, 1], Total Latency: 49
#   Packet 4: Source: 5, Target: 2, Size: 31, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 7, Target: 3, Size: 18, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 1, Target: 7, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 5, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 3, Target: 2, Size: 5, Delivered: True, Path: [3, 13, 2], Total Latency: 36
#   Packet 9: Source: 1, Target: 5, Size: 32, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 32, 'throughput': 24}, 1: {'latency': 44, 'throughput': 38}, 2: {'latency': 16, 'throughput': 39}, 3: {'latency': 11, 'throughput': 39}, 4: {'latency': 6, 'throughput': 19}, 5: {'latency': 27, 'throughput': 44}, 6: {'latency': 9, 'throughput': 22}, 7: {'latency': 4, 'throughput': 23}, 8: {'latency': 34, 'throughput': 1}, 9: {'latency': 15, 'throughput': 26}, 10: {'latency': 7, 'throughput': 13}, 11: {'latency': 37, 'throughput': 8}, 12: {'latency': 5, 'throughput': 161}, 13: {'latency': 9, 'throughput': 579}, 14: {'latency': 23, 'throughput': 388}}
# Iteration 15:
#   Packet 0: Source: 3, Target: 4, Size: 33, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 5, Target: 1, Size: 28, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 7, Target: 4, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 5, Target: 6, Size: 39, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 11, Target: 8, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 3, Target: 5, Size: 40, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 6, Target: 3, Size: 23, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 8, Target: 12, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 1, Target: 0, Size: 35, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 2, Target: 11, Size: 1, Delivered: True, Path: [2, 11], Total Latency: 46
# Current metrics: {0: {'latency': 37, 'throughput': 20}, 1: {'latency': 42, 'throughput': 39}, 2: {'latency': 14, 'throughput': 30}, 3: {'latency': 15, 'throughput': 40}, 4: {'latency': 7, 'throughput': 11}, 5: {'latency': 31, 'throughput': 40}, 6: {'latency': 12, 'throughput': 30}, 7: {'latency': 6, 'throughput': 24}, 8: {'latency': 36, 'throughput': 1}, 9: {'latency': 15, 'throughput': 26}, 10: {'latency': 10, 'throughput': 10}, 11: {'latency': 32, 'throughput': 11}, 12: {'latency': 6, 'throughput': 160}, 13: {'latency': 11, 'throughput': 574}, 14: {'latency': 23, 'throughput': 394}}
# Iteration 16:
#   Packet 0: Source: 11, Target: 5, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 10, Target: 9, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 1, Target: 8, Size: 22, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 8, Target: 0, Size: 8, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 6, Target: 0, Size: 23, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 8, Target: 8, Size: 2, Delivered: True, Path: [8], Total Latency: 35
#   Packet 6: Source: 5, Target: 12, Size: 16, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 11, Target: 3, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 2, Target: 5, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 3, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 36, 'throughput': 12}, 1: {'latency': 45, 'throughput': 39}, 2: {'latency': 11, 'throughput': 28}, 3: {'latency': 19, 'throughput': 44}, 4: {'latency': 5, 'throughput': 9}, 5: {'latency': 33, 'throughput': 31}, 6: {'latency': 14, 'throughput': 36}, 7: {'latency': 5, 'throughput': 33}, 8: {'latency': 35, 'throughput': 11}, 9: {'latency': 18, 'throughput': 21}, 10: {'latency': 13, 'throughput': 12}, 11: {'latency': 35, 'throughput': 1}, 12: {'latency': 1, 'throughput': 166}, 13: {'latency': 14, 'throughput': 576}, 14: {'latency': 27, 'throughput': 401}}
# Iteration 17:
#   Packet 0: Source: 1, Target: 1, Size: 5, Delivered: True, Path: [1], Total Latency: 43
#   Packet 1: Source: 1, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 1, Target: 8, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 11, Target: 8, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 7, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 10, Target: 0, Size: 13, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 6, Target: 1, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 7, Target: 9, Size: 17, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 6, Target: 3, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 2, Target: 0, Size: 11, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 41, 'throughput': 17}, 1: {'latency': 43, 'throughput': 32}, 2: {'latency': 9, 'throughput': 23}, 3: {'latency': 21, 'throughput': 39}, 4: {'latency': 5, 'throughput': 1}, 5: {'latency': 35, 'throughput': 38}, 6: {'latency': 14, 'throughput': 26}, 7: {'latency': 3, 'throughput': 24}, 8: {'latency': 30, 'throughput': 16}, 9: {'latency': 17, 'throughput': 24}, 10: {'latency': 8, 'throughput': 14}, 11: {'latency': 36, 'throughput': 1}, 12: {'latency': 2, 'throughput': 157}, 13: {'latency': 18, 'throughput': 567}, 14: {'latency': 27, 'throughput': 400}}
# Iteration 18:
#   Packet 0: Source: 9, Target: 2, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 9, Target: 10, Size: 16, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 7, Target: 3, Size: 3, Delivered: True, Path: [7, 14, 5, 13, 3], Total Latency: 109
#   Packet 3: Source: 4, Target: 1, Size: 1, Delivered: True, Path: [4, 1], Total Latency: 49
#   Packet 4: Source: 5, Target: 2, Size: 20, Delivered: True, Path: [5, 13, 2], Total Latency: 66
#   Packet 5: Source: 12, Target: 3, Size: 153, Delivered: True, Path: [12, 1, 13, 3], Total Latency: 96
#   Packet 6: Source: 7, Target: 4, Size: 32, Delivered: True, Path: [7, 14, 5, 13, 4], Total Latency: 86
#   Packet 7: Source: 3, Target: 7, Size: 12, Delivered: True, Path: [3, 13, 5, 14, 7], Total Latency: 109
#   Packet 8: Source: 8, Target: 7, Size: 8, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 1, Target: 11, Size: 6, Delivered: True, Path: [1, 11], Total Latency: 89
# Current metrics: {0: {'latency': 43, 'throughput': 22}, 1: {'latency': 48, 'throughput': 41}, 2: {'latency': 13, 'throughput': 25}, 3: {'latency': 24, 'throughput': 36}, 4: {'latency': 1, 'throughput': 1}, 5: {'latency': 34, 'throughput': 32}, 6: {'latency': 14, 'throughput': 16}, 7: {'latency': 5, 'throughput': 34}, 8: {'latency': 27, 'throughput': 8}, 9: {'latency': 13, 'throughput': 22}, 10: {'latency': 6, 'throughput': 24}, 11: {'latency': 41, 'throughput': 1}, 12: {'latency': 5, 'throughput': 160}, 13: {'latency': 19, 'throughput': 576}, 14: {'latency': 27, 'throughput': 394}}
# Iteration 19:
#   Packet 0: Source: 6, Target: 0, Size: 15, Delivered: True, Path: [6, 0], Total Latency: 58
#   Packet 1: Source: 9, Target: 3, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 4, Target: 10, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 10, Target: 1, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 4, Target: 1, Size: 6, Delivered: True, Path: [4, 1], Total Latency: 50
#   Packet 5: Source: 6, Target: 12, Size: 18, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 11, Target: 3, Size: 3, Delivered: True, Path: [11, 13, 3], Total Latency: 78
#   Packet 7: Source: 1, Target: 12, Size: 5, Delivered: True, Path: [1, 12], Total Latency: 46
#   Packet 8: Source: 3, Target: 4, Size: 24, Delivered: True, Path: [3, 13, 4], Total Latency: 45
#   Packet 9: Source: 9, Target: 9, Size: 1, Delivered: True, Path: [9], Total Latency: 14
# Current metrics: {0: {'latency': 45, 'throughput': 30}, 1: {'latency': 45, 'throughput': 31}, 2: {'latency': 15, 'throughput': 15}, 3: {'latency': 21, 'throughput': 39}, 4: {'latency': 5, 'throughput': 10}, 5: {'latency': 30, 'throughput': 26}, 6: {'latency': 13, 'throughput': 21}, 7: {'latency': 1, 'throughput': 38}, 8: {'latency': 31, 'throughput': 11}, 9: {'latency': 14, 'throughput': 15}, 10: {'latency': 8, 'throughput': 18}, 11: {'latency': 38, 'throughput': 3}, 12: {'latency': 1, 'throughput': 155}, 13: {'latency': 19, 'throughput': 585}, 14: {'latency': 25, 'throughput': 393}}
# Iteration 20:
#   Packet 0: Source: 9, Target: 4, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 6, Target: 8, Size: 8, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 8, Target: 10, Size: 12, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 8, Target: 7, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 10, Target: 7, Size: 6, Delivered: True, Path: [10, 13, 5, 14, 7], Total Latency: 81
#   Packet 5: Source: 12, Target: 8, Size: 144, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 1, Target: 6, Size: 16, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 9, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 12, Target: 3, Size: 108, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 6, Target: 3, Size: 11, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 43, 'throughput': 27}, 1: {'latency': 46, 'throughput': 39}, 2: {'latency': 10, 'throughput': 7}, 3: {'latency': 26, 'throughput': 29}, 4: {'latency': 3, 'throughput': 6}, 5: {'latency': 30, 'throughput': 22}, 6: {'latency': 10, 'throughput': 20}, 7: {'latency': 1, 'throughput': 41}, 8: {'latency': 35, 'throughput': 18}, 9: {'latency': 10, 'throughput': 11}, 10: {'latency': 4, 'throughput': 27}, 11: {'latency': 37, 'throughput': 1}, 12: {'latency': 3, 'throughput': 151}, 13: {'latency': 22, 'throughput': 591}, 14: {'latency': 24, 'throughput': 390}}
# Iteration 21:
#   Packet 0: Source: 7, Target: 4, Size: 29, Delivered: True, Path: [7, 14, 5, 13, 4], Total Latency: 70
#   Packet 1: Source: 6, Target: 0, Size: 21, Delivered: True, Path: [6, 0], Total Latency: 52
#   Packet 2: Source: 1, Target: 10, Size: 1, Delivered: True, Path: [1, 13, 10], Total Latency: 63
#   Packet 3: Source: 8, Target: 10, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 1, Target: 8, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 8, Target: 9, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 5, Target: 11, Size: 15, Delivered: True, Path: [5, 13, 11], Total Latency: 83
#   Packet 7: Source: 10, Target: 5, Size: 2, Delivered: True, Path: [10, 13, 5], Total Latency: 45
#   Packet 8: Source: 1, Target: 0, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 11, Target: 10, Size: 1, Delivered: True, Path: [11, 13, 10], Total Latency: 57
# Current metrics: {0: {'latency': 43, 'throughput': 29}, 1: {'latency': 45, 'throughput': 32}, 2: {'latency': 6, 'throughput': 2}, 3: {'latency': 29, 'throughput': 31}, 4: {'latency': 1, 'throughput': 1}, 5: {'latency': 27, 'throughput': 32}, 6: {'latency': 9, 'throughput': 21}, 7: {'latency': 1, 'throughput': 35}, 8: {'latency': 39, 'throughput': 28}, 9: {'latency': 13, 'throughput': 21}, 10: {'latency': 1, 'throughput': 29}, 11: {'latency': 39, 'throughput': 1}, 12: {'latency': 4, 'throughput': 155}, 13: {'latency': 17, 'throughput': 583}, 14: {'latency': 24, 'throughput': 388}}
# Iteration 22:
#   Packet 0: Source: 5, Target: 0, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 2, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 5, Target: 2, Size: 1, Delivered: True, Path: [5, 13, 2], Total Latency: 52
#   Packet 3: Source: 11, Target: 5, Size: 1, Delivered: True, Path: [11, 13, 5], Total Latency: 78
#   Packet 4: Source: 4, Target: 0, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 8, Target: 4, Size: 18, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 8, Target: 1, Size: 8, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 7, Target: 11, Size: 32, Delivered: True, Path: [7, 14, 5, 13, 11], Total Latency: 103
#   Packet 8: Source: 2, Target: 6, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 3, Target: 0, Size: 6, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 47, 'throughput': 29}, 1: {'latency': 43, 'throughput': 28}, 2: {'latency': 8, 'throughput': 5}, 3: {'latency': 26, 'throughput': 24}, 4: {'latency': 5, 'throughput': 5}, 5: {'latency': 27, 'throughput': 31}, 6: {'latency': 12, 'throughput': 14}, 7: {'latency': 1, 'throughput': 44}, 8: {'latency': 44, 'throughput': 30}, 9: {'latency': 12, 'throughput': 30}, 10: {'latency': 1, 'throughput': 29}, 11: {'latency': 34, 'throughput': 1}, 12: {'latency': 9, 'throughput': 156}, 13: {'latency': 17, 'throughput': 591}, 14: {'latency': 24, 'throughput': 395}}
# Iteration 23:
#   Packet 0: Source: 4, Target: 9, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 5, Target: 10, Size: 1, Delivered: True, Path: [5, 13, 10], Total Latency: 49
#   Packet 2: Source: 10, Target: 2, Size: 16, Delivered: True, Path: [10, 13, 2], Total Latency: 34
#   Packet 3: Source: 12, Target: 0, Size: 46, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 1, Target: 12, Size: 15, Delivered: True, Path: [1, 12], Total Latency: 42
#   Packet 5: Source: 11, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 12, Target: 6, Size: 113, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 5, Target: 5, Size: 25, Delivered: True, Path: [5], Total Latency: 27
#   Packet 8: Source: 3, Target: 0, Size: 27, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 6, Target: 0, Size: 4, Delivered: True, Path: [6, 0], Total Latency: 66
# Current metrics: {0: {'latency': 49, 'throughput': 24}, 1: {'latency': 38, 'throughput': 18}, 2: {'latency': 12, 'throughput': 1}, 3: {'latency': 25, 'throughput': 32}, 4: {'latency': 2, 'throughput': 1}, 5: {'latency': 27, 'throughput': 25}, 6: {'latency': 17, 'throughput': 5}, 7: {'latency': 1, 'throughput': 41}, 8: {'latency': 44, 'throughput': 20}, 9: {'latency': 9, 'throughput': 40}, 10: {'latency': 1, 'throughput': 23}, 11: {'latency': 36, 'throughput': 3}, 12: {'latency': 4, 'throughput': 166}, 13: {'latency': 21, 'throughput': 590}, 14: {'latency': 28, 'throughput': 391}}
# [(0.0014882087707519531,
#   {0: {'latency': 38, 'throughput': 17},
#    1: {'latency': 24, 'throughput': 23},
#    2: {'latency': 12, 'throughput': 69},
#    3: {'latency': 14, 'throughput': 66},
#    4: {'latency': 4, 'throughput': 35},
#    5: {'latency': 34, 'throughput': 1},
#    6: {'latency': 4, 'throughput': 20},
#    7: {'latency': 23, 'throughput': 47},
#    8: {'latency': 32, 'throughput': 2},
#    9: {'latency': 52, 'throughput': 99},
#    10: {'latency': 1, 'throughput': 24},
#    11: {'latency': 47, 'throughput': 37},
#    12: {'latency': 32, 'throughput': 143},
#    13: {'latency': 1, 'throughput': 997},
#    14: {'latency': 3, 'throughput': 991}}),
#  (5.005770206451416,
#   {0: {'latency': 34, 'throughput': 17},
#    1: {'latency': 20, 'throughput': 32},
#    2: {'latency': 16, 'throughput': 72},
#    3: {'latency': 18, 'throughput': 68},
#    4: {'latency': 0, 'throughput': 21},
#    5: {'latency': 15, 'throughput': 1},
#    6: {'latency': 4, 'throughput': 14},
#    7: {'latency': 9, 'throughput': 26},
#    8: {'latency': 30, 'throughput': 11},
#    9: {'latency': 20, 'throughput': 60},
#    10: {'latency': 1, 'throughput': 23},
#    11: {'latency': 42, 'throughput': 31},
#    12: {'latency': 27, 'throughput': 137},
#    13: {'latency': 0, 'throughput': 602},
#    14: {'latency': 0, 'throughput': 357}}),
#  (10.013572454452515,
#   {0: {'latency': 32, 'throughput': 24},
#    1: {'latency': 19, 'throughput': 38},
#    2: {'latency': 12, 'throughput': 74},
#    3: {'latency': 19, 'throughput': 77},
#    4: {'latency': 2, 'throughput': 11},
#    5: {'latency': 14, 'throughput': 10},
#    6: {'latency': 8, 'throughput': 15},
#    7: {'latency': 8, 'throughput': 16},
#    8: {'latency': 31, 'throughput': 11},
#    9: {'latency': 18, 'throughput': 60},
#    10: {'latency': 1, 'throughput': 23},
#    11: {'latency': 37, 'throughput': 32},
#    12: {'latency': 24, 'throughput': 131},
#    13: {'latency': 5, 'throughput': 595},
#    14: {'latency': 1, 'throughput': 359}}),
#  (15.029620885848999,
#   {0: {'latency': 27, 'throughput': 33},
#    1: {'latency': 23, 'throughput': 34},
#    2: {'latency': 10, 'throughput': 78},
#    3: {'latency': 22, 'throughput': 78},
#    4: {'latency': 1, 'throughput': 20},
#    5: {'latency': 11, 'throughput': 20},
#    6: {'latency': 8, 'throughput': 6},
#    7: {'latency': 9, 'throughput': 18},
#    8: {'latency': 33, 'throughput': 7},
#    9: {'latency': 13, 'throughput': 58},
#    10: {'latency': 5, 'throughput': 31},
#    11: {'latency': 37, 'throughput': 31},
#    12: {'latency': 19, 'throughput': 126},
#    13: {'latency': 9, 'throughput': 589},
#    14: {'latency': 6, 'throughput': 358}}),
#  (20.042187213897705,
#   {0: {'latency': 26, 'throughput': 41},
#    1: {'latency': 28, 'throughput': 43},
#    2: {'latency': 5, 'throughput': 75},
#    3: {'latency': 18, 'throughput': 69},
#    4: {'latency': 1, 'throughput': 22},
#    5: {'latency': 16, 'throughput': 27},
#    6: {'latency': 11, 'throughput': 13},
#    7: {'latency': 4, 'throughput': 25},
#    8: {'latency': 29, 'throughput': 8},
#    9: {'latency': 16, 'throughput': 48},
#    10: {'latency': 3, 'throughput': 30},
#    11: {'latency': 40, 'throughput': 21},
#    12: {'latency': 18, 'throughput': 132},
#    13: {'latency': 11, 'throughput': 590},
#    14: {'latency': 6, 'throughput': 368}}),
#  (25.04944109916687,
#   {0: {'latency': 25, 'throughput': 45},
#    1: {'latency': 33, 'throughput': 39},
#    2: {'latency': 4, 'throughput': 81},
#    3: {'latency': 16, 'throughput': 74},
#    4: {'latency': 1, 'throughput': 17},
#    5: {'latency': 21, 'throughput': 21},
#    6: {'latency': 12, 'throughput': 13},
#    7: {'latency': 4, 'throughput': 29},
#    8: {'latency': 26, 'throughput': 17},
#    9: {'latency': 21, 'throughput': 50},
#    10: {'latency': 4, 'throughput': 26},
#    11: {'latency': 37, 'throughput': 17},
#    12: {'latency': 14, 'throughput': 139},
#    13: {'latency': 10, 'throughput': 592},
#    14: {'latency': 4, 'throughput': 360}}),
#  (30.057666778564453,
#   {0: {'latency': 24, 'throughput': 48},
#    1: {'latency': 37, 'throughput': 43},
#    2: {'latency': 9, 'throughput': 72},
#    3: {'latency': 15, 'throughput': 70},
#    4: {'latency': 1, 'throughput': 9},
#    5: {'latency': 20, 'throughput': 11},
#    6: {'latency': 9, 'throughput': 7},
#    7: {'latency': 8, 'throughput': 35},
#    8: {'latency': 29, 'throughput': 12},
#    9: {'latency': 20, 'throughput': 45},
#    10: {'latency': 1, 'throughput': 34},
#    11: {'latency': 36, 'throughput': 11},
#    12: {'latency': 16, 'throughput': 147},
#    13: {'latency': 13, 'throughput': 592},
#    14: {'latency': 9, 'throughput': 366}}),
#  (35.0611367225647,
#   {0: {'latency': 21, 'throughput': 55},
#    1: {'latency': 40, 'throughput': 48},
#    2: {'latency': 14, 'throughput': 64},
#    3: {'latency': 18, 'throughput': 60},
#    4: {'latency': 1, 'throughput': 14},
#    5: {'latency': 23, 'throughput': 21},
#    6: {'latency': 4, 'throughput': 12},
#    7: {'latency': 7, 'throughput': 27},
#    8: {'latency': 27, 'throughput': 5},
#    9: {'latency': 15, 'throughput': 41},
#    10: {'latency': 3, 'throughput': 24},
#    11: {'latency': 35, 'throughput': 15},
#    12: {'latency': 12, 'throughput': 147},
#    13: {'latency': 14, 'throughput': 584},
#    14: {'latency': 6, 'throughput': 372}}),
#  (40.067206621170044,
#   {0: {'latency': 26, 'throughput': 48},
#    1: {'latency': 38, 'throughput': 56},
#    2: {'latency': 19, 'throughput': 58},
#    3: {'latency': 19, 'throughput': 57},
#    4: {'latency': 1, 'throughput': 22},
#    5: {'latency': 23, 'throughput': 14},
#    6: {'latency': 1, 'throughput': 15},
#    7: {'latency': 11, 'throughput': 35},
#    8: {'latency': 28, 'throughput': 14},
#    9: {'latency': 16, 'throughput': 42},
#    10: {'latency': 1, 'throughput': 14},
#    11: {'latency': 37, 'throughput': 18},
#    12: {'latency': 7, 'throughput': 140},
#    13: {'latency': 17, 'throughput': 594},
#    14: {'latency': 11, 'throughput': 362}}),
#  (45.078428506851196,
#   {0: {'latency': 26, 'throughput': 44},
#    1: {'latency': 39, 'throughput': 46},
#    2: {'latency': 14, 'throughput': 58},
#    3: {'latency': 19, 'throughput': 56},
#    4: {'latency': 1, 'throughput': 26},
#    5: {'latency': 27, 'throughput': 8},
#    6: {'latency': 4, 'throughput': 11},
#    7: {'latency': 6, 'throughput': 44},
#    8: {'latency': 32, 'throughput': 11},
#    9: {'latency': 21, 'throughput': 33},
#    10: {'latency': 2, 'throughput': 14},
#    11: {'latency': 41, 'throughput': 9},
#    12: {'latency': 2, 'throughput': 147},
#    13: {'latency': 15, 'throughput': 598},
#    14: {'latency': 13, 'throughput': 356}}),
#  (50.096893548965454,
#   {0: {'latency': 29, 'throughput': 36},
#    1: {'latency': 38, 'throughput': 39},
#    2: {'latency': 10, 'throughput': 60},
#    3: {'latency': 18, 'throughput': 53},
#    4: {'latency': 1, 'throughput': 17},
#    5: {'latency': 31, 'throughput': 15},
#    6: {'latency': 3, 'throughput': 21},
#    7: {'latency': 11, 'throughput': 40},
#    8: {'latency': 31, 'throughput': 6},
#    9: {'latency': 25, 'throughput': 31},
#    10: {'latency': 5, 'throughput': 14},
#    11: {'latency': 37, 'throughput': 12},
#    12: {'latency': 1, 'throughput': 138},
#    13: {'latency': 14, 'throughput': 598},
#    14: {'latency': 18, 'throughput': 364}}),
#  (55.1059947013855,
#   {0: {'latency': 24, 'throughput': 46},
#    1: {'latency': 42, 'throughput': 45},
#    2: {'latency': 9, 'throughput': 53},
#    3: {'latency': 17, 'throughput': 47},
#    4: {'latency': 4, 'throughput': 14},
#    5: {'latency': 27, 'throughput': 25},
#    6: {'latency': 4, 'throughput': 22},
#    7: {'latency': 9, 'throughput': 40},
#    8: {'latency': 35, 'throughput': 1},
#    9: {'latency': 22, 'throughput': 34},
#    10: {'latency': 10, 'throughput': 8},
#    11: {'latency': 35, 'throughput': 3},
#    12: {'latency': 1, 'throughput': 141},
#    13: {'latency': 15, 'throughput': 590},
#    14: {'latency': 22, 'throughput': 372}}),
#  (60.12302374839783,
#   {0: {'latency': 24, 'throughput': 37},
#    1: {'latency': 44, 'throughput': 49},
#    2: {'latency': 14, 'throughput': 51},
#    3: {'latency': 18, 'throughput': 48},
#    4: {'latency': 9, 'throughput': 17},
#    5: {'latency': 27, 'throughput': 32},
#    6: {'latency': 9, 'throughput': 19},
#    7: {'latency': 4, 'throughput': 30},
#    8: {'latency': 33, 'throughput': 5},
#    9: {'latency': 19, 'throughput': 40},
#    10: {'latency': 9, 'throughput': 15},
#    11: {'latency': 34, 'throughput': 13},
#    12: {'latency': 4, 'throughput': 149},
#    13: {'latency': 10, 'throughput': 586},
#    14: {'latency': 18, 'throughput': 379}}),
#  (65.12823677062988,
#   {0: {'latency': 29, 'throughput': 34},
#    1: {'latency': 47, 'throughput': 47},
#    2: {'latency': 13, 'throughput': 46},
#    3: {'latency': 15, 'throughput': 46},
#    4: {'latency': 8, 'throughput': 10},
#    5: {'latency': 29, 'throughput': 38},
#    6: {'latency': 13, 'throughput': 21},
#    7: {'latency': 7, 'throughput': 25},
#    8: {'latency': 38, 'throughput': 4},
#    9: {'latency': 15, 'throughput': 36},
#    10: {'latency': 8, 'throughput': 15},
#    11: {'latency': 38, 'throughput': 12},
#    12: {'latency': 7, 'throughput': 153},
#    13: {'latency': 6, 'throughput': 583},
#    14: {'latency': 23, 'throughput': 387}}),
#  (70.14224195480347,
#   {0: {'latency': 32, 'throughput': 24},
#    1: {'latency': 44, 'throughput': 38},
#    2: {'latency': 16, 'throughput': 39},
#    3: {'latency': 11, 'throughput': 39},
#    4: {'latency': 6, 'throughput': 19},
#    5: {'latency': 27, 'throughput': 44},
#    6: {'latency': 9, 'throughput': 22},
#    7: {'latency': 4, 'throughput': 23},
#    8: {'latency': 34, 'throughput': 1},
#    9: {'latency': 15, 'throughput': 26},
#    10: {'latency': 7, 'throughput': 13},
#    11: {'latency': 37, 'throughput': 8},
#    12: {'latency': 5, 'throughput': 161},
#    13: {'latency': 9, 'throughput': 579},
#    14: {'latency': 23, 'throughput': 388}}),
#  (75.15193247795105,
#   {0: {'latency': 37, 'throughput': 20},
#    1: {'latency': 42, 'throughput': 39},
#    2: {'latency': 14, 'throughput': 30},
#    3: {'latency': 15, 'throughput': 40},
#    4: {'latency': 7, 'throughput': 11},
#    5: {'latency': 31, 'throughput': 40},
#    6: {'latency': 12, 'throughput': 30},
#    7: {'latency': 6, 'throughput': 24},
#    8: {'latency': 36, 'throughput': 1},
#    9: {'latency': 15, 'throughput': 26},
#    10: {'latency': 10, 'throughput': 10},
#    11: {'latency': 32, 'throughput': 11},
#    12: {'latency': 6, 'throughput': 160},
#    13: {'latency': 11, 'throughput': 574},
#    14: {'latency': 23, 'throughput': 394}}),
#  (80.16931486129761,
#   {0: {'latency': 36, 'throughput': 12},
#    1: {'latency': 45, 'throughput': 39},
#    2: {'latency': 11, 'throughput': 28},
#    3: {'latency': 19, 'throughput': 44},
#    4: {'latency': 5, 'throughput': 9},
#    5: {'latency': 33, 'throughput': 31},
#    6: {'latency': 14, 'throughput': 36},
#    7: {'latency': 5, 'throughput': 33},
#    8: {'latency': 35, 'throughput': 11},
#    9: {'latency': 18, 'throughput': 21},
#    10: {'latency': 13, 'throughput': 12},
#    11: {'latency': 35, 'throughput': 1},
#    12: {'latency': 1, 'throughput': 166},
#    13: {'latency': 14, 'throughput': 576},
#    14: {'latency': 27, 'throughput': 401}}),
#  (85.17218589782715,
#   {0: {'latency': 41, 'throughput': 17},
#    1: {'latency': 43, 'throughput': 32},
#    2: {'latency': 9, 'throughput': 23},
#    3: {'latency': 21, 'throughput': 39},
#    4: {'latency': 5, 'throughput': 1},
#    5: {'latency': 35, 'throughput': 38},
#    6: {'latency': 14, 'throughput': 26},
#    7: {'latency': 3, 'throughput': 24},
#    8: {'latency': 30, 'throughput': 16},
#    9: {'latency': 17, 'throughput': 24},
#    10: {'latency': 8, 'throughput': 14},
#    11: {'latency': 36, 'throughput': 1},
#    12: {'latency': 2, 'throughput': 157},
#    13: {'latency': 18, 'throughput': 567},
#    14: {'latency': 27, 'throughput': 400}}),
#  (90.17994952201843,
#   {0: {'latency': 43, 'throughput': 22},
#    1: {'latency': 48, 'throughput': 41},
#    2: {'latency': 13, 'throughput': 25},
#    3: {'latency': 24, 'throughput': 36},
#    4: {'latency': 1, 'throughput': 1},
#    5: {'latency': 34, 'throughput': 32},
#    6: {'latency': 14, 'throughput': 16},
#    7: {'latency': 5, 'throughput': 34},
#    8: {'latency': 27, 'throughput': 8},
#    9: {'latency': 13, 'throughput': 22},
#    10: {'latency': 6, 'throughput': 24},
#    11: {'latency': 41, 'throughput': 1},
#    12: {'latency': 5, 'throughput': 160},
#    13: {'latency': 19, 'throughput': 576},
#    14: {'latency': 27, 'throughput': 394}}),
#  (95.19354057312012,
#   {0: {'latency': 45, 'throughput': 30},
#    1: {'latency': 45, 'throughput': 31},
#    2: {'latency': 15, 'throughput': 15},
#    3: {'latency': 21, 'throughput': 39},
#    4: {'latency': 5, 'throughput': 10},
#    5: {'latency': 30, 'throughput': 26},
#    6: {'latency': 13, 'throughput': 21},
#    7: {'latency': 1, 'throughput': 38},
#    8: {'latency': 31, 'throughput': 11},
#    9: {'latency': 14, 'throughput': 15},
#    10: {'latency': 8, 'throughput': 18},
#    11: {'latency': 38, 'throughput': 3},
#    12: {'latency': 1, 'throughput': 155},
#    13: {'latency': 19, 'throughput': 585},
#    14: {'latency': 25, 'throughput': 393}}),
#  (100.2007987499237,
#   {0: {'latency': 43, 'throughput': 27},
#    1: {'latency': 46, 'throughput': 39},
#    2: {'latency': 10, 'throughput': 7},
#    3: {'latency': 26, 'throughput': 29},
#    4: {'latency': 3, 'throughput': 6},
#    5: {'latency': 30, 'throughput': 22},
#    6: {'latency': 10, 'throughput': 20},
#    7: {'latency': 1, 'throughput': 41},
#    8: {'latency': 35, 'throughput': 18},
#    9: {'latency': 10, 'throughput': 11},
#    10: {'latency': 4, 'throughput': 27},
#    11: {'latency': 37, 'throughput': 1},
#    12: {'latency': 3, 'throughput': 151},
#    13: {'latency': 22, 'throughput': 591},
#    14: {'latency': 24, 'throughput': 390}}),
#  (105.21407175064087,
#   {0: {'latency': 43, 'throughput': 29},
#    1: {'latency': 45, 'throughput': 32},
#    2: {'latency': 6, 'throughput': 2},
#    3: {'latency': 29, 'throughput': 31},
#    4: {'latency': 1, 'throughput': 1},
#    5: {'latency': 27, 'throughput': 32},
#    6: {'latency': 9, 'throughput': 21},
#    7: {'latency': 1, 'throughput': 35},
#    8: {'latency': 39, 'throughput': 28},
#    9: {'latency': 13, 'throughput': 21},
#    10: {'latency': 1, 'throughput': 29},
#    11: {'latency': 39, 'throughput': 1},
#    12: {'latency': 4, 'throughput': 155},
#    13: {'latency': 17, 'throughput': 583},
#    14: {'latency': 24, 'throughput': 388}}),
#  (110.22544169425964,
#   {0: {'latency': 47, 'throughput': 29},
#    1: {'latency': 43, 'throughput': 28},
#    2: {'latency': 8, 'throughput': 5},
#    3: {'latency': 26, 'throughput': 24},
#    4: {'latency': 5, 'throughput': 5},
#    5: {'latency': 27, 'throughput': 31},
#    6: {'latency': 12, 'throughput': 14},
#    7: {'latency': 1, 'throughput': 44},
#    8: {'latency': 44, 'throughput': 30},
#    9: {'latency': 12, 'throughput': 30},
#    10: {'latency': 1, 'throughput': 29},
#    11: {'latency': 34, 'throughput': 1},
#    12: {'latency': 9, 'throughput': 156},
#    13: {'latency': 17, 'throughput': 591},
#    14: {'latency': 24, 'throughput': 395}}),
#  (115.23876142501831,
#   {0: {'latency': 49, 'throughput': 24},
#    1: {'latency': 38, 'throughput': 18},
#    2: {'latency': 12, 'throughput': 1},
#    3: {'latency': 25, 'throughput': 32},
#    4: {'latency': 2, 'throughput': 1},
#    5: {'latency': 27, 'throughput': 25},
#    6: {'latency': 17, 'throughput': 5},
#    7: {'latency': 1, 'throughput': 41},
#    8: {'latency': 44, 'throughput': 20},
#    9: {'latency': 9, 'throughput': 40},
#    10: {'latency': 1, 'throughput': 23},
#    11: {'latency': 36, 'throughput': 3},
#    12: {'latency': 4, 'throughput': 166},
#    13: {'latency': 21, 'throughput': 590},
#    14: {'latency': 28, 'throughput': 391}})]

# %%
import matplotlib.pyplot as plt

metrics = simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)
def plot_network_metrics(metrics):
    # Assume metrics is a list of tuples with (timestamp, {node_id: {'latency': val, 'throughput': val}})
    times = [m[0] for m in metrics]
    # Let's say we want to track changes for node 5 and node 7
    latencies_5 = [m[1][5]['latency'] for m in metrics]
    throughputs_5 = [m[1][5]['throughput'] for m in metrics]
    latencies_7 = [m[1][7]['latency'] for m in metrics]
    throughputs_7 = [m[1][7]['throughput'] for m in metrics]

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times, latencies_5, label='Latency UAV 5')
    plt.plot(times, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times, throughputs_5, label='Throughput UAV 5')
    plt.plot(times, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()

if metrics:
    plot_network_metrics(metrics)
else:
    print("No data was returned from the simulation.")
# Out:
# Iteration 0:
#   Packet 0: Source: 1, Target: 7, Size: 44, Delivered: True, Path: [1, 3, 5, 12, 7], Total Latency: 132
#   Packet 1: Source: 8, Target: 10, Size: 33, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 6, Target: 10, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 4, Target: 8, Size: 47, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 5, Target: 3, Size: 44, Delivered: True, Path: [5, 3], Total Latency: 34
#   Packet 5: Source: 2, Target: 10, Size: 17, Delivered: True, Path: [2, 11, 10], Total Latency: 100
#   Packet 6: Source: 4, Target: 0, Size: 47, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 7, Target: 2, Size: 20, Delivered: True, Path: [7, 12, 5, 3, 11, 2], Total Latency: 164
#   Packet 8: Source: 9, Target: 0, Size: 31, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 3, Target: 5, Size: 37, Delivered: True, Path: [3, 5], Total Latency: 34
# Current metrics: {0: {'latency': 48, 'throughput': 9}, 1: {'latency': 36, 'throughput': 54}, 2: {'latency': 20, 'throughput': 19}, 3: {'latency': 6, 'throughput': 64}, 4: {'latency': 12, 'throughput': 70}, 5: {'latency': 28, 'throughput': 98}, 6: {'latency': 6, 'throughput': 31}, 7: {'latency': 38, 'throughput': 35}, 8: {'latency': 8, 'throughput': 37}, 9: {'latency': 41, 'throughput': 62}, 10: {'latency': 32, 'throughput': 49}, 11: {'latency': 48, 'throughput': 59}, 12: {'latency': 24, 'throughput': 381}}
# Iteration 1:
# Current metrics: {0: {'latency': 44, 'throughput': 8, 'battery': 100}, 1: {'latency': 14, 'throughput': 28, 'battery': 60}, 2: {'latency': 22, 'throughput': 27, 'battery': 60}, 3: {'latency': 0, 'throughput': 41, 'battery': 60}, 4: {'latency': 5, 'throughput': 36, 'battery': 21}, 5: {'latency': 11, 'throughput': 53, 'battery': 25}, 6: {'latency': 8, 'throughput': 27, 'battery': 60}, 7: {'latency': 17, 'throughput': 20, 'battery': 25}, 8: {'latency': 9, 'throughput': 34, 'battery': 60}, 9: {'latency': 42, 'throughput': 58, 'battery': 100}, 10: {'latency': 31, 'throughput': 57, 'battery': 60}, 11: {'latency': 49, 'throughput': 54, 'battery': 60}, 12: {'latency': 3, 'throughput': 138, 'battery': 12}}
#   Packet 0: Source: 0, Target: 5, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 2, Target: 10, Size: 22, Delivered: True, Path: [2, 11, 10], Total Latency: 102
#   Packet 2: Source: 9, Target: 3, Size: 26, Delivered: True, Path: [9, 11, 3], Total Latency: 91
#   Packet 3: Source: 8, Target: 10, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 7, Target: 3, Size: 3, Delivered: True, Path: [7, 12, 5, 3], Total Latency: 31
#   Packet 5: Source: 0, Target: 3, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 9, Target: 9, Size: 13, Delivered: True, Path: [9], Total Latency: 42
#   Packet 7: Source: 3, Target: 1, Size: 34, Delivered: True, Path: [3, 1], Total Latency: 14
#   Packet 8: Source: 7, Target: 2, Size: 6, Delivered: True, Path: [7, 12, 5, 1, 11, 2], Total Latency: 116
#   Packet 9: Source: 0, Target: 2, Size: 3, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 44, 'throughput': 8}, 1: {'latency': 14, 'throughput': 28}, 2: {'latency': 22, 'throughput': 27}, 3: {'latency': 0, 'throughput': 41}, 4: {'latency': 5, 'throughput': 36}, 5: {'latency': 11, 'throughput': 53}, 6: {'latency': 8, 'throughput': 27}, 7: {'latency': 17, 'throughput': 20}, 8: {'latency': 9, 'throughput': 34}, 9: {'latency': 42, 'throughput': 58}, 10: {'latency': 31, 'throughput': 57}, 11: {'latency': 49, 'throughput': 54}, 12: {'latency': 3, 'throughput': 138}}
# Iteration 2:
#   Packet 0: Source: 5, Target: 8, Size: 46, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 6, Target: 2, Size: 4, Delivered: True, Path: [6, 11, 2], Total Latency: 65
#   Packet 2: Source: 1, Target: 4, Size: 23, Delivered: True, Path: [1, 5, 4], Total Latency: 32
#   Packet 3: Source: 0, Target: 0, Size: 10, Delivered: True, Path: [0], Total Latency: 48
#   Packet 4: Source: 3, Target: 0, Size: 25, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 3, Target: 2, Size: 23, Delivered: True, Path: [3, 11, 2], Total Latency: 62
#   Packet 6: Source: 8, Target: 0, Size: 11, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 0, Target: 2, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 4, Target: 1, Size: 21, Delivered: True, Path: [4, 5, 1], Total Latency: 32
#   Packet 9: Source: 4, Target: 1, Size: 26, Delivered: True, Path: [4, 5, 1], Total Latency: 32
# Current metrics: {0: {'latency': 48, 'throughput': 15}, 1: {'latency': 18, 'throughput': 33}, 2: {'latency': 17, 'throughput': 36}, 3: {'latency': 1, 'throughput': 42}, 4: {'latency': 1, 'throughput': 34}, 5: {'latency': 13, 'throughput': 55}, 6: {'latency': 4, 'throughput': 29}, 7: {'latency': 20, 'throughput': 17}, 8: {'latency': 10, 'throughput': 26}, 9: {'latency': 39, 'throughput': 59}, 10: {'latency': 34, 'throughput': 59}, 11: {'latency': 44, 'throughput': 60}, 12: {'latency': 7, 'throughput': 145}}
# Iteration 3:
#   Packet 0: Source: 9, Target: 5, Size: 27, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 0, Target: 0, Size: 12, Delivered: True, Path: [0], Total Latency: 46
#   Packet 2: Source: 2, Target: 1, Size: 1, Delivered: True, Path: [2, 11, 1], Total Latency: 79
#   Packet 3: Source: 0, Target: 3, Size: 11, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 4, Target: 5, Size: 8, Delivered: True, Path: [4, 5], Total Latency: 16
#   Packet 5: Source: 8, Target: 2, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 0, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 8, Target: 7, Size: 13, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 1, Target: 3, Size: 10, Delivered: True, Path: [1, 3], Total Latency: 20
#   Packet 9: Source: 1, Target: 9, Size: 24, Delivered: True, Path: [1, 11, 9], Total Latency: 106
# Current metrics: {0: {'latency': 46, 'throughput': 13}, 1: {'latency': 18, 'throughput': 24}, 2: {'latency': 17, 'throughput': 39}, 3: {'latency': 2, 'throughput': 44}, 4: {'latency': 1, 'throughput': 33}, 5: {'latency': 15, 'throughput': 51}, 6: {'latency': 4, 'throughput': 19}, 7: {'latency': 23, 'throughput': 11}, 8: {'latency': 13, 'throughput': 33}, 9: {'latency': 44, 'throughput': 49}, 10: {'latency': 29, 'throughput': 59}, 11: {'latency': 44, 'throughput': 70}, 12: {'latency': 12, 'throughput': 147}}
# Iteration 4:
#   Packet 0: Source: 9, Target: 1, Size: 18, Delivered: True, Path: [9, 11, 1], Total Latency: 111
#   Packet 1: Source: 2, Target: 6, Size: 10, Delivered: True, Path: [2, 11, 6], Total Latency: 73
#   Packet 2: Source: 8, Target: 2, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 1, Target: 5, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 3, Target: 4, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 2, Target: 1, Size: 43, Delivered: True, Path: [2, 3, 1], Total Latency: 38
#   Packet 6: Source: 10, Target: 9, Size: 33, Delivered: True, Path: [10, 11, 9], Total Latency: 119
#   Packet 7: Source: 0, Target: 9, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 2, Target: 0, Size: 45, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 10, Target: 2, Size: 1, Delivered: True, Path: [10, 3, 2], Total Latency: 46
# Current metrics: {0: {'latency': 51, 'throughput': 4}, 1: {'latency': 16, 'throughput': 31}, 2: {'latency': 20, 'throughput': 47}, 3: {'latency': 2, 'throughput': 48}, 4: {'latency': 1, 'throughput': 29}, 5: {'latency': 11, 'throughput': 43}, 6: {'latency': 5, 'throughput': 23}, 7: {'latency': 21, 'throughput': 21}, 8: {'latency': 17, 'throughput': 30}, 9: {'latency': 47, 'throughput': 51}, 10: {'latency': 24, 'throughput': 55}, 11: {'latency': 48, 'throughput': 68}, 12: {'latency': 8, 'throughput': 137}}
# Iteration 5:
#   Packet 0: Source: 6, Target: 10, Size: 2, Delivered: True, Path: [6, 11, 10], Total Latency: 73
#   Packet 1: Source: 3, Target: 5, Size: 43, Delivered: True, Path: [3, 1, 10, 7, 12, 5], Total Latency: 89
#   Packet 2: Source: 5, Target: 8, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 6, Target: 0, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 4, Target: 7, Size: 9, Delivered: True, Path: [4, 5, 12, 7], Total Latency: 50
#   Packet 5: Source: 8, Target: 5, Size: 11, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 8, Target: 4, Size: 18, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 2, Target: 5, Size: 36, Delivered: True, Path: [2, 11, 10, 7, 12, 5], Total Latency: 135
#   Packet 8: Source: 0, Target: 4, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 7, Target: 7, Size: 7, Delivered: True, Path: [7], Total Latency: 23
# Current metrics: {0: {'latency': 52, 'throughput': 4}, 1: {'latency': 16, 'throughput': 41}, 2: {'latency': 16, 'throughput': 57}, 3: {'latency': 1, 'throughput': 43}, 4: {'latency': 1, 'throughput': 26}, 5: {'latency': 14, 'throughput': 45}, 6: {'latency': 3, 'throughput': 19}, 7: {'latency': 23, 'throughput': 14}, 8: {'latency': 22, 'throughput': 25}, 9: {'latency': 50, 'throughput': 46}, 10: {'latency': 23, 'throughput': 53}, 11: {'latency': 47, 'throughput': 75}, 12: {'latency': 12, 'throughput': 147}}
# Iteration 6:
#   Packet 0: Source: 7, Target: 10, Size: 8, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 10, Target: 10, Size: 11, Delivered: True, Path: [10], Total Latency: 18
#   Packet 2: Source: 1, Target: 6, Size: 16, Delivered: True, Path: [1, 3, 6], Total Latency: 19
#   Packet 3: Source: 6, Target: 10, Size: 14, Delivered: True, Path: [6, 11, 10], Total Latency: 69
#   Packet 4: Source: 7, Target: 6, Size: 16, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 7, Target: 7, Size: 15, Delivered: True, Path: [7], Total Latency: 28
#   Packet 6: Source: 7, Target: 4, Size: 7, Delivered: True, Path: [7, 12, 5, 4], Total Latency: 49
#   Packet 7: Source: 3, Target: 6, Size: 12, Delivered: True, Path: [3, 6], Total Latency: 2
#   Packet 8: Source: 8, Target: 7, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 4, Target: 6, Size: 18, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 52, 'throughput': 11}, 1: {'latency': 17, 'throughput': 31}, 2: {'latency': 13, 'throughput': 55}, 3: {'latency': 1, 'throughput': 40}, 4: {'latency': 1, 'throughput': 27}, 5: {'latency': 13, 'throughput': 35}, 6: {'latency': 1, 'throughput': 18}, 7: {'latency': 28, 'throughput': 22}, 8: {'latency': 24, 'throughput': 18}, 9: {'latency': 52, 'throughput': 46}, 10: {'latency': 18, 'throughput': 63}, 11: {'latency': 50, 'throughput': 67}, 12: {'latency': 7, 'throughput': 153}}
# Iteration 7:
#   Packet 0: Source: 2, Target: 3, Size: 46, Delivered: True, Path: [2, 1, 3], Total Latency: 32
#   Packet 1: Source: 3, Target: 10, Size: 34, Delivered: True, Path: [3, 11, 10], Total Latency: 70
#   Packet 2: Source: 5, Target: 0, Size: 13, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 3, Target: 5, Size: 23, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 9, Target: 3, Size: 5, Delivered: True, Path: [9, 1, 3], Total Latency: 75
#   Packet 5: Source: 7, Target: 6, Size: 22, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 5, Target: 7, Size: 2, Delivered: True, Path: [5, 12, 7], Total Latency: 57
#   Packet 7: Source: 9, Target: 8, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 6, Target: 9, Size: 19, Delivered: True, Path: [6, 11, 9], Total Latency: 102
#   Packet 9: Source: 9, Target: 7, Size: 10, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 51, 'throughput': 5}, 1: {'latency': 22, 'throughput': 30}, 2: {'latency': 9, 'throughput': 57}, 3: {'latency': 1, 'throughput': 34}, 4: {'latency': 5, 'throughput': 33}, 5: {'latency': 17, 'throughput': 34}, 6: {'latency': 1, 'throughput': 19}, 7: {'latency': 30, 'throughput': 26}, 8: {'latency': 26, 'throughput': 10}, 9: {'latency': 52, 'throughput': 53}, 10: {'latency': 20, 'throughput': 61}, 11: {'latency': 49, 'throughput': 70}, 12: {'latency': 10, 'throughput': 161}}
# Iteration 8:
#   Packet 0: Source: 2, Target: 5, Size: 55, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 6, Target: 10, Size: 21, Delivered: True, Path: [6, 11, 10], Total Latency: 73
#   Packet 2: Source: 10, Target: 5, Size: 28, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 6, Target: 4, Size: 19, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 7, Target: 10, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 7, Target: 8, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 3, Target: 10, Size: 28, Delivered: True, Path: [3, 11, 10], Total Latency: 73
#   Packet 7: Source: 6, Target: 3, Size: 4, Delivered: True, Path: [6, 3], Total Latency: 2
#   Packet 8: Source: 10, Target: 2, Size: 43, Delivered: True, Path: [10, 9, 2], Total Latency: 78
#   Packet 9: Source: 4, Target: 7, Size: 16, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 49, 'throughput': 1}, 1: {'latency': 17, 'throughput': 26}, 2: {'latency': 10, 'throughput': 63}, 3: {'latency': 1, 'throughput': 35}, 4: {'latency': 8, 'throughput': 39}, 5: {'latency': 21, 'throughput': 25}, 6: {'latency': 1, 'throughput': 28}, 7: {'latency': 31, 'throughput': 18}, 8: {'latency': 28, 'throughput': 12}, 9: {'latency': 50, 'throughput': 62}, 10: {'latency': 18, 'throughput': 60}, 11: {'latency': 54, 'throughput': 64}, 12: {'latency': 7, 'throughput': 160}}
# Iteration 9:
#   Packet 0: Source: 9, Target: 6, Size: 6, Delivered: True, Path: [9, 11, 6], Total Latency: 105
#   Packet 1: Source: 7, Target: 0, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 2, Target: 5, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 9, Target: 10, Size: 44, Delivered: True, Path: [9, 11, 10], Total Latency: 117
#   Packet 4: Source: 10, Target: 2, Size: 40, Delivered: True, Path: [10, 11, 2], Total Latency: 83
#   Packet 5: Source: 5, Target: 3, Size: 21, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 5, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 10, Target: 8, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 6, Target: 4, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 3, Target: 8, Size: 9, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 47, 'throughput': 11}, 1: {'latency': 19, 'throughput': 33}, 2: {'latency': 13, 'throughput': 61}, 3: {'latency': 3, 'throughput': 44}, 4: {'latency': 8, 'throughput': 41}, 5: {'latency': 16, 'throughput': 27}, 6: {'latency': 3, 'throughput': 31}, 7: {'latency': 36, 'throughput': 25}, 8: {'latency': 29, 'throughput': 16}, 9: {'latency': 47, 'throughput': 71}, 10: {'latency': 15, 'throughput': 54}, 11: {'latency': 55, 'throughput': 56}, 12: {'latency': 6, 'throughput': 161}}
# Iteration 10:
#   Packet 0: Source: 6, Target: 1, Size: 2, Delivered: True, Path: [6, 1], Total Latency: 30
#   Packet 1: Source: 7, Target: 0, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 7, Target: 5, Size: 11, Delivered: True, Path: [7, 12, 5], Total Latency: 62
#   Packet 3: Source: 5, Target: 9, Size: 6, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 9, Target: 10, Size: 32, Delivered: True, Path: [9, 10], Total Latency: 66
#   Packet 5: Source: 10, Target: 4, Size: 17, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 4, Target: 6, Size: 18, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 10, Target: 6, Size: 44, Delivered: True, Path: [10, 11, 6], Total Latency: 82
#   Packet 8: Source: 9, Target: 6, Size: 17, Delivered: True, Path: [9, 11, 6], Total Latency: 118
#   Packet 9: Source: 0, Target: 2, Size: 3, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 48, 'throughput': 4}, 1: {'latency': 22, 'throughput': 37}, 2: {'latency': 15, 'throughput': 61}, 3: {'latency': 4, 'throughput': 47}, 4: {'latency': 6, 'throughput': 40}, 5: {'latency': 16, 'throughput': 26}, 6: {'latency': 8, 'throughput': 31}, 7: {'latency': 36, 'throughput': 20}, 8: {'latency': 30, 'throughput': 9}, 9: {'latency': 51, 'throughput': 67}, 10: {'latency': 15, 'throughput': 51}, 11: {'latency': 59, 'throughput': 48}, 12: {'latency': 10, 'throughput': 152}}
# Iteration 11:
#   Packet 0: Source: 6, Target: 4, Size: 15, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 5, Target: 0, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 6, Target: 1, Size: 9, Delivered: True, Path: [6, 3, 1], Total Latency: 36
#   Packet 3: Source: 0, Target: 7, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 7, Target: 5, Size: 5, Delivered: True, Path: [7, 12, 5], Total Latency: 61
#   Packet 5: Source: 5, Target: 4, Size: 19, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 7, Target: 6, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 4, Target: 10, Size: 12, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 6, Target: 8, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 8, Target: 5, Size: 1, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 47, 'throughput': 1}, 1: {'latency': 18, 'throughput': 29}, 2: {'latency': 13, 'throughput': 60}, 3: {'latency': 9, 'throughput': 51}, 4: {'latency': 1, 'throughput': 33}, 5: {'latency': 13, 'throughput': 21}, 6: {'latency': 9, 'throughput': 37}, 7: {'latency': 40, 'throughput': 21}, 8: {'latency': 25, 'throughput': 1}, 9: {'latency': 47, 'throughput': 74}, 10: {'latency': 17, 'throughput': 49}, 11: {'latency': 54, 'throughput': 48}, 12: {'latency': 8, 'throughput': 154}}
# Iteration 12:
#   Packet 0: Source: 2, Target: 4, Size: 63, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 1, Target: 3, Size: 22, Delivered: True, Path: [1, 11, 3], Total Latency: 86
#   Packet 2: Source: 4, Target: 6, Size: 21, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 1, Target: 9, Size: 23, Delivered: True, Path: [1, 2, 9], Total Latency: 81
#   Packet 4: Source: 0, Target: 7, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 4, Target: 9, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 3, Target: 10, Size: 40, Delivered: True, Path: [3, 11, 10], Total Latency: 75
#   Packet 7: Source: 9, Target: 5, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 1, Target: 5, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 9, Target: 4, Size: 48, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 42, 'throughput': 7}, 1: {'latency': 23, 'throughput': 26}, 2: {'latency': 11, 'throughput': 66}, 3: {'latency': 12, 'throughput': 53}, 4: {'latency': 4, 'throughput': 31}, 5: {'latency': 17, 'throughput': 18}, 6: {'latency': 7, 'throughput': 30}, 7: {'latency': 40, 'throughput': 29}, 8: {'latency': 23, 'throughput': 1}, 9: {'latency': 47, 'throughput': 80}, 10: {'latency': 12, 'throughput': 49}, 11: {'latency': 51, 'throughput': 53}, 12: {'latency': 13, 'throughput': 147}}
# Iteration 13:
#   Packet 0: Source: 7, Target: 0, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 3, Target: 7, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 2, Target: 3, Size: 3, Delivered: True, Path: [2, 11, 3], Total Latency: 79
#   Packet 3: Source: 4, Target: 8, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 10, Target: 10, Size: 21, Delivered: True, Path: [10], Total Latency: 12
#   Packet 5: Source: 5, Target: 3, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 3, Size: 21, Delivered: True, Path: [2, 11, 3], Total Latency: 79
#   Packet 7: Source: 3, Target: 1, Size: 44, Delivered: True, Path: [3, 11, 1], Total Latency: 88
#   Packet 8: Source: 7, Target: 9, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 2, Target: 5, Size: 5, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 37, 'throughput': 1}, 1: {'latency': 23, 'throughput': 19}, 2: {'latency': 14, 'throughput': 59}, 3: {'latency': 15, 'throughput': 53}, 4: {'latency': 1, 'throughput': 39}, 5: {'latency': 15, 'throughput': 15}, 6: {'latency': 8, 'throughput': 21}, 7: {'latency': 37, 'throughput': 39}, 8: {'latency': 27, 'throughput': 7}, 9: {'latency': 51, 'throughput': 80}, 10: {'latency': 12, 'throughput': 53}, 11: {'latency': 50, 'throughput': 58}, 12: {'latency': 14, 'throughput': 146}}
# Iteration 14:
#   Packet 0: Source: 3, Target: 10, Size: 7, Delivered: True, Path: [3, 11, 10], Total Latency: 72
#   Packet 1: Source: 8, Target: 6, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 9, Target: 5, Size: 50, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 2, Target: 1, Size: 28, Delivered: True, Path: [2, 1], Total Latency: 36
#   Packet 4: Source: 4, Target: 10, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 4, Target: 10, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 10, Target: 9, Size: 50, Delivered: True, Path: [10, 11, 9], Total Latency: 114
#   Packet 7: Source: 3, Target: 10, Size: 47, Delivered: True, Path: [3, 11, 10], Total Latency: 72
#   Packet 8: Source: 0, Target: 2, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 9, Target: 0, Size: 2, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 37, 'throughput': 1}, 1: {'latency': 23, 'throughput': 29}, 2: {'latency': 13, 'throughput': 58}, 3: {'latency': 12, 'throughput': 59}, 4: {'latency': 5, 'throughput': 43}, 5: {'latency': 13, 'throughput': 7}, 6: {'latency': 7, 'throughput': 11}, 7: {'latency': 35, 'throughput': 39}, 8: {'latency': 27, 'throughput': 7}, 9: {'latency': 54, 'throughput': 73}, 10: {'latency': 9, 'throughput': 50}, 11: {'latency': 51, 'throughput': 54}, 12: {'latency': 17, 'throughput': 136}}
# Iteration 15:
#   Packet 0: Source: 5, Target: 7, Size: 7, Delivered: True, Path: [5, 12, 7], Total Latency: 69
#   Packet 1: Source: 9, Target: 7, Size: 35, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 4, Target: 1, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 4, Target: 8, Size: 25, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 4, Target: 2, Size: 32, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 7, Target: 5, Size: 19, Delivered: True, Path: [7, 12, 5], Total Latency: 69
#   Packet 6: Source: 8, Target: 6, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 3, Target: 4, Size: 54, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 5, Target: 4, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 0, Target: 1, Size: 3, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 33, 'throughput': 4}, 1: {'latency': 26, 'throughput': 31}, 2: {'latency': 11, 'throughput': 63}, 3: {'latency': 15, 'throughput': 55}, 4: {'latency': 6, 'throughput': 42}, 5: {'latency': 13, 'throughput': 10}, 6: {'latency': 3, 'throughput': 16}, 7: {'latency': 35, 'throughput': 41}, 8: {'latency': 25, 'throughput': 7}, 9: {'latency': 49, 'throughput': 77}, 10: {'latency': 7, 'throughput': 41}, 11: {'latency': 53, 'throughput': 44}, 12: {'latency': 21, 'throughput': 140}}
# Iteration 16:
#   Packet 0: Source: 4, Target: 10, Size: 47, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 9, Target: 7, Size: 74, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 1, Target: 8, Size: 15, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 6, Target: 5, Size: 17, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 5, Target: 10, Size: 6, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 0, Target: 0, Size: 1, Delivered: True, Path: [0], Total Latency: 30
#   Packet 6: Source: 8, Target: 7, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 10, Target: 0, Size: 31, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 6, Target: 7, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 0, Target: 8, Size: 2, Delivered: True, Path: [0, 8], Total Latency: 50
# Current metrics: {0: {'latency': 30, 'throughput': 3}, 1: {'latency': 23, 'throughput': 23}, 2: {'latency': 10, 'throughput': 60}, 3: {'latency': 20, 'throughput': 53}, 4: {'latency': 4, 'throughput': 48}, 5: {'latency': 12, 'throughput': 12}, 6: {'latency': 3, 'throughput': 23}, 7: {'latency': 30, 'throughput': 49}, 8: {'latency': 20, 'throughput': 1}, 9: {'latency': 45, 'throughput': 84}, 10: {'latency': 12, 'throughput': 45}, 11: {'latency': 51, 'throughput': 42}, 12: {'latency': 20, 'throughput': 130}}
# Iteration 17:
#   Packet 0: Source: 8, Target: 4, Size: 9, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 4, Target: 1, Size: 38, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 8, Target: 9, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 4, Target: 0, Size: 29, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 3, Target: 9, Size: 48, Delivered: True, Path: [3, 2, 9], Total Latency: 72
#   Packet 5: Source: 5, Target: 1, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 4, Size: 19, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 2, Target: 2, Size: 30, Delivered: True, Path: [2], Total Latency: 9
#   Packet 8: Source: 4, Target: 5, Size: 32, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 8, Target: 2, Size: 3, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 26, 'throughput': 9}, 1: {'latency': 22, 'throughput': 24}, 2: {'latency': 9, 'throughput': 60}, 3: {'latency': 18, 'throughput': 55}, 4: {'latency': 3, 'throughput': 51}, 5: {'latency': 17, 'throughput': 2}, 6: {'latency': 1, 'throughput': 30}, 7: {'latency': 25, 'throughput': 59}, 8: {'latency': 19, 'throughput': 9}, 9: {'latency': 45, 'throughput': 82}, 10: {'latency': 7, 'throughput': 40}, 11: {'latency': 53, 'throughput': 32}, 12: {'latency': 23, 'throughput': 136}}
# Iteration 18:
#   Packet 0: Source: 9, Target: 6, Size: 81, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 2, Target: 10, Size: 42, Delivered: True, Path: [2, 11, 10], Total Latency: 67
#   Packet 2: Source: 9, Target: 10, Size: 45, Delivered: True, Path: [9, 11, 10], Total Latency: 106
#   Packet 3: Source: 10, Target: 2, Size: 19, Delivered: True, Path: [10, 11, 2], Total Latency: 67
#   Packet 4: Source: 5, Target: 2, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 5, Target: 7, Size: 3, Delivered: True, Path: [5, 12, 7], Total Latency: 75
#   Packet 6: Source: 10, Target: 2, Size: 24, Delivered: True, Path: [10, 11, 2], Total Latency: 67
#   Packet 7: Source: 10, Target: 0, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 10, Target: 9, Size: 19, Delivered: True, Path: [10, 11, 9], Total Latency: 106
#   Packet 9: Source: 2, Target: 9, Size: 34, Delivered: True, Path: [2, 9], Total Latency: 61
# Current metrics: {0: {'latency': 31, 'throughput': 6}, 1: {'latency': 26, 'throughput': 22}, 2: {'latency': 11, 'throughput': 60}, 3: {'latency': 17, 'throughput': 52}, 4: {'latency': 7, 'throughput': 48}, 5: {'latency': 20, 'throughput': 3}, 6: {'latency': 1, 'throughput': 36}, 7: {'latency': 30, 'throughput': 64}, 8: {'latency': 23, 'throughput': 14}, 9: {'latency': 50, 'throughput': 83}, 10: {'latency': 4, 'throughput': 32}, 11: {'latency': 52, 'throughput': 42}, 12: {'latency': 25, 'throughput': 129}}
# Iteration 19:
#   Packet 0: Source: 6, Target: 0, Size: 25, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 0, Target: 9, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 2, Target: 8, Size: 42, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 7, Target: 5, Size: 11, Delivered: True, Path: [7, 12, 5], Total Latency: 77
#   Packet 4: Source: 0, Target: 7, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 2, Target: 9, Size: 16, Delivered: True, Path: [2, 9], Total Latency: 64
#   Packet 6: Source: 1, Target: 6, Size: 17, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 1, Target: 2, Size: 16, Delivered: True, Path: [1, 2], Total Latency: 37
#   Packet 8: Source: 5, Target: 9, Size: 1, Delivered: True, Path: [5, 11, 9], Total Latency: 126
#   Packet 9: Source: 0, Target: 7, Size: 12, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 27, 'throughput': 12}, 1: {'latency': 25, 'throughput': 17}, 2: {'latency': 12, 'throughput': 65}, 3: {'latency': 16, 'throughput': 62}, 4: {'latency': 9, 'throughput': 56}, 5: {'latency': 23, 'throughput': 10}, 6: {'latency': 2, 'throughput': 36}, 7: {'latency': 25, 'throughput': 54}, 8: {'latency': 27, 'throughput': 6}, 9: {'latency': 52, 'throughput': 74}, 10: {'latency': 3, 'throughput': 42}, 11: {'latency': 51, 'throughput': 40}, 12: {'latency': 29, 'throughput': 133}}
# Iteration 20:
#   Packet 0: Source: 2, Target: 8, Size: 71, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 6, Target: 8, Size: 13, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 1, Target: 4, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 6, Target: 10, Size: 2, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 10, Target: 8, Size: 36, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 6, Target: 5, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 0, Size: 30, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 9, Target: 1, Size: 12, Delivered: True, Path: [9, 2, 1], Total Latency: 89
#   Packet 8: Source: 7, Target: 5, Size: 29, Delivered: True, Path: [7, 12, 5], Total Latency: 81
#   Packet 9: Source: 7, Target: 5, Size: 11, Delivered: True, Path: [7, 12, 5], Total Latency: 81
# Current metrics: {0: {'latency': 31, 'throughput': 13}, 1: {'latency': 20, 'throughput': 24}, 2: {'latency': 12, 'throughput': 72}, 3: {'latency': 19, 'throughput': 67}, 4: {'latency': 6, 'throughput': 66}, 5: {'latency': 26, 'throughput': 6}, 6: {'latency': 3, 'throughput': 37}, 7: {'latency': 21, 'throughput': 47}, 8: {'latency': 22, 'throughput': 2}, 9: {'latency': 57, 'throughput': 81}, 10: {'latency': 5, 'throughput': 40}, 11: {'latency': 46, 'throughput': 43}, 12: {'latency': 34, 'throughput': 134}}
# Iteration 21:
#   Packet 0: Source: 5, Target: 5, Size: 2, Delivered: True, Path: [5], Total Latency: 31
#   Packet 1: Source: 8, Target: 8, Size: 1, Delivered: True, Path: [8], Total Latency: 25
#   Packet 2: Source: 3, Target: 4, Size: 42, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 0, Target: 4, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 5, Target: 4, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 9, Target: 0, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 6, Target: 4, Size: 14, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 10, Target: 7, Size: 30, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 3, Target: 0, Size: 57, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 9, Target: 9, Size: 69, Delivered: True, Path: [9], Total Latency: 54
# Current metrics: {0: {'latency': 35, 'throughput': 8}, 1: {'latency': 16, 'throughput': 33}, 2: {'latency': 12, 'throughput': 66}, 3: {'latency': 15, 'throughput': 59}, 4: {'latency': 6, 'throughput': 56}, 5: {'latency': 31, 'throughput': 4}, 6: {'latency': 1, 'throughput': 27}, 7: {'latency': 16, 'throughput': 42}, 8: {'latency': 25, 'throughput': 1}, 9: {'latency': 54, 'throughput': 88}, 10: {'latency': 6, 'throughput': 32}, 11: {'latency': 48, 'throughput': 36}, 12: {'latency': 36, 'throughput': 131}}
# Iteration 22:
#   Packet 0: Source: 1, Target: 8, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 6, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 1, Target: 2, Size: 21, Delivered: True, Path: [1, 2], Total Latency: 35
#   Packet 3: Source: 5, Target: 5, Size: 1, Delivered: True, Path: [5], Total Latency: 35
#   Packet 4: Source: 8, Target: 10, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 10, Target: 9, Size: 12, Delivered: True, Path: [10, 11, 9], Total Latency: 104
#   Packet 6: Source: 9, Target: 9, Size: 49, Delivered: True, Path: [9], Total Latency: 55
#   Packet 7: Source: 2, Target: 8, Size: 3, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 5, Target: 2, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 2, Target: 5, Size: 9, Delivered: False, Path: [], Total Latency: None
# Current metrics: {0: {'latency': 31, 'throughput': 13}, 1: {'latency': 21, 'throughput': 35}, 2: {'latency': 14, 'throughput': 69}, 3: {'latency': 17, 'throughput': 61}, 4: {'latency': 4, 'throughput': 53}, 5: {'latency': 35, 'throughput': 8}, 6: {'latency': 1, 'throughput': 23}, 7: {'latency': 18, 'throughput': 36}, 8: {'latency': 28, 'throughput': 1}, 9: {'latency': 55, 'throughput': 86}, 10: {'latency': 5, 'throughput': 27}, 11: {'latency': 44, 'throughput': 33}, 12: {'latency': 40, 'throughput': 139}}
# Iteration 23:
#   Packet 0: Source: 0, Target: 0, Size: 1, Delivered: True, Path: [0], Total Latency: 36
#   Packet 1: Source: 7, Target: 2, Size: 13, Delivered: True, Path: [7, 9, 11, 2], Total Latency: 128
#   Packet 2: Source: 9, Target: 7, Size: 32, Delivered: True, Path: [9, 7], Total Latency: 75
#   Packet 3: Source: 4, Target: 4, Size: 10, Delivered: True, Path: [4], Total Latency: 6
#   Packet 4: Source: 2, Target: 2, Size: 17, Delivered: True, Path: [2], Total Latency: 9
#   Packet 5: Source: 10, Target: 6, Size: 28, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 8, Target: 1, Size: 1, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 3, Target: 1, Size: 25, Delivered: True, Path: [3, 1], Total Latency: 31
#   Packet 8: Source: 5, Target: 1, Size: 3, Delivered: True, Path: [5, 11, 1], Total Latency: 99
#   Packet 9: Source: 1, Target: 2, Size: 21, Delivered: True, Path: [1, 2], Total Latency: 28
# Current metrics: {0: {'latency': 36, 'throughput': 10}, 1: {'latency': 19, 'throughput': 29}, 2: {'latency': 9, 'throughput': 76}, 3: {'latency': 12, 'throughput': 59}, 4: {'latency': 6, 'throughput': 44}, 5: {'latency': 36, 'throughput': 3}, 6: {'latency': 1, 'throughput': 21}, 7: {'latency': 19, 'throughput': 38}, 8: {'latency': 31, 'throughput': 1}, 9: {'latency': 56, 'throughput': 89}, 10: {'latency': 1, 'throughput': 30}, 11: {'latency': 44, 'throughput': 27}, 12: {'latency': 37, 'throughput': 134}}

# %% [markdown]
# Descriptive Statistics, Performing Correlation Analysis On the Dataset and plotting correlation matrix.

# %%
"""Pearson's Correlation"""

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data provided
data = [
    {'time': 0.001983642578125, 'node_id': 0, 'latency': 16, 'throughput': 71},
    {'time': 0.001983642578125, 'node_id': 1, 'latency': 41, 'throughput': 54},
    {'time': 0.001983642578125, 'node_id': 2, 'latency': 32, 'throughput': 76},
    {'time': 0.001983642578125, 'node_id': 3, 'latency': 7, 'throughput': 52},
    {'time': 0.001983642578125, 'node_id': 4, 'latency': 18, 'throughput': 53},
    {'time': 0.001983642578125, 'node_id': 5, 'latency': 17, 'throughput': 65},
    {'time': 0.001983642578125, 'node_id': 6, 'latency': 16, 'throughput': 84},
    {'time': 0.001983642578125, 'node_id': 7, 'latency': 40, 'throughput': 55},
    {'time': 0.001983642578125, 'node_id': 8, 'latency': 37, 'throughput': 68},
    {'time': 0.001983642578125, 'node_id': 9, 'latency': 39, 'throughput': 77},
    {'time': 0.001983642578125, 'node_id': 10, 'latency': 36, 'throughput': 86},
    {'time': 0.001983642578125, 'node_id': 11, 'latency': 39, 'throughput': 94},
    {'time': 5.015164613723755, 'node_id': 0, 'latency': 17, 'throughput': 78},
    # Assuming the rest of the data points are appended here in the same format...
]

# Converting data into a pandas DataFrame
df = pd.DataFrame(data)

# Calculating the correlation between latency and throughput
correlation_matrix = df[['latency', 'throughput']].corr()
print(correlation_matrix)


# Plotting a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
heatmap.set_title('Correlation Heatmap between Latency and Throughput', pad=12)
plt.show()
# Out:
#              latency  throughput
# latency     1.000000    0.209531
# throughput  0.209531    1.000000
