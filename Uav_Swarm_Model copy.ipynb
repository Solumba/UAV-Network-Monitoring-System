# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np
import time
import csv
import os
import time
from datetime import datetime
from neo4j import GraphDatabase

# Neo4j configuration
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "Shady5000$")

# %%
class UAVNetworkSimulation:

    def __init__(self, uri, auth):
        self.driver = GraphDatabase.driver(uri, auth=auth)

    def close(self):
        self.driver.close()
    
    def create_initial_graph(self, num_uavs, connection_range, ground_station_pos, backbone_range):
        #Create undirected graph
        G = nx.Graph()

        # Define typical throughput and latency ranges (for example purposes)
        typical_throughput = (50, 100)  # Mbps
        typical_latency = (10, 50)     # Milliseconds
        typical_battery = (100,100) # %

        # Add UAV nodes with properties
        for i in range(num_uavs):
            throughput = random.randint(*typical_throughput)
            latency = random.randint(*typical_latency)
            battery = random.randint(*typical_battery)
            G.add_node(i, pos=(random.randint(0, 100), random.randint(0, 100)),
                       throughput=throughput, latency=latency, battery=battery)

        # Add The Backbone UAV
        backbone_uav_id = num_uavs
        G.add_node(backbone_uav_id, pos=(random.randint(0, 100), random.randint(0, 100)), is_backbone=True,
                       throughput=throughput, latency=latency, battery=battery)

        # Connect Backbone UAV to other UAVs Based on Euclidean Distance
        for i in range(num_uavs):
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        # Add and connect the Ground Station To The Backbone Only
        ground_station_id = num_uavs + 1
        G.add_node(ground_station_id, pos=ground_station_pos, is_ground_station=True, throughput=throughput, latency=latency, battery=battery)
        G.add_edge(backbone_uav_id, ground_station_id)

        # Add edges between UAVs within connection range
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        return G
    
    # Upload Current Graph To Neo4j
    def upload_to_neo4j(self, G):
        with self.driver.session() as session:
            # Clear existing data
            session.run("MATCH (n) DETACH DELETE n")

            # Add nodes
            for node in G.nodes:
                is_backbone = G.nodes[node].get('is_backbone', False)
                is_ground_station = G.nodes[node].get('is_ground_station', False)
                is_attack_node = G.nodes[node].get('is_attack_node', False)

                if is_backbone:
                    session.run(f"""
                        CREATE (b:BackboneUAV {{id: $id, pos: $pos, uavType: $uavType,
                            throughput: $throughput, latency: $latency, battery: $battery  + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "Backbone UAV", throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])
                elif is_ground_station:
                    session.run(f"""
                        CREATE (g:GroundStation {{id: $id, pos: $pos, gsName: $GS, battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], GS = "Ground Station", battery=G.nodes[node]['battery'])
                else:
                    session.run(f"""
                        CREATE (u:UAV {{id: $id, pos: $pos, uavType: $uavType, uavName: $uavName,
                            throughput: $throughput + 'mb/s', latency: $latency + 'ms', battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "UAV", uavName = "UAV"  + str(node), throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])

            # Add relationships
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)

    # Draw Graph
    def draw_graph(self, G):
        pos = nx.get_node_attributes(G, 'pos')

        # Labelling Each Type Of Node
        labels = {}
        for node in G.nodes:
            if G.nodes[node].get('is_backbone', False):
                labels[node] = 'Backbone UAV'
            elif G.nodes[node].get('is_ground_station', False):
                labels[node] = 'Ground Station'
            elif G.nodes[node].get('is_attack_node', False):
                labels[node] = 'Attack Node'
            else:
                labels[node] = f'UAV{node}'

        # Differentiate node types
        regular_nodes = [node for node in G.nodes if not G.nodes[node].get('is_backbone', False) and not G.nodes[node].get('is_ground_station', False)]
        backbone_nodes = [node for node in G.nodes if G.nodes[node].get('is_backbone', False)]
        ground_station_nodes = [node for node in G.nodes if G.nodes[node].get('is_ground_station', False)]
        attacking_nodes = [node for node in G.nodes if G.nodes[node].get('is_attack_node', False)]

        # Draw regular UAV nodes
        nx.draw_networkx_nodes(G, pos, nodelist=regular_nodes, node_color='green', node_size=300, label='UAV')
        
        # Draw backbone UAV node
        nx.draw_networkx_nodes(G, pos, nodelist=backbone_nodes, node_color='lightgreen', node_size=500, label='Backbone UAV')

        # Draw ground station node
        nx.draw_networkx_nodes(G, pos, nodelist=ground_station_nodes, node_color='lightblue', node_size=500, label='Ground Station')

        nx.draw_networkx_nodes(G, pos, nodelist=attacking_nodes, node_color='red', node_size=500, label='Attack Node')

        # Draw edges
        nx.draw_networkx_edges(G, pos, edge_color='gray')

        # Draw custom labels
        nx.draw_networkx_labels(G, pos, labels)

        plt.title("Multilayer UAV Network")
        plt.legend()
        plt.show()
        
    def update_uav_positions(self, G, move_range):
        
        # Update the positions of UAVs randomly within a given range.
    
        for node in G.nodes:
            if 'is_backbone' not in G.nodes[node] and 'is_ground_station' not in G.nodes[node]:
                current_pos = G.nodes[node]['pos']
                new_pos = (current_pos[0] + random.uniform(-move_range, move_range), 
                           current_pos[1] + random.uniform(-move_range, move_range))
                G.nodes[node]['pos'] = new_pos
        return G

    def update_network_connections(self, G, connection_range, backbone_range):
        
        # Update the network connections based on new positions and connection range.
        # Excluding backbone UAV and ground station
        num_uavs = len(G.nodes) - 2  
        backbone_uav_id = num_uavs

        # Update connections for regular UAVs
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                if G.has_edge(i, j):
                    G.remove_edge(i, j)
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        # Update connections for the Backbone UAV
        for i in range(num_uavs):
            if G.has_edge(i, backbone_uav_id):
                G.remove_edge(i, backbone_uav_id)
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        return G

    def update_neo4j_database(self, G):
        
        # Update the Neo4j database with the new positions and connections.
        
        with self.driver.session() as session:
            # Update positions
            for node in G.nodes:
                pos = G.nodes[node]['pos']
                session.run("""
                    MATCH (n)
                    WHERE n.id = $id
                    SET n.pos = $pos
                    """, id=node, pos=pos)

            # Update relationships
            session.run("MATCH (n)-[r:COMMUNICATES_WITH]->() DELETE r")
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)
    
    def generate_network_traffic(self, G, num_packets):
        
        # Generate network traffic considering the throughput of UAVs.
        
        packets = []
        for _ in range(num_packets):
            # Exclude backbone and ground station
            source = random.randint(0, len(G.nodes) - 3)  
            target = random.randint(0, len(G.nodes) - 3)
            
            # Packet size should not exceed the throughput of the source UAV
            max_packet_size = G.nodes[source]['throughput']
            size = random.randint(1, max_packet_size)

            packets.append({'source': source, 'target': target, 'size': size})
        return packets
    
    def route_packets(self, G, packets):
        
        # Determine the path for each packet and calculate cumulative latency.
        
        for packet in packets:
            source = packet['source']
            target = packet['target']
            if nx.has_path(G, source, target):
                path = nx.shortest_path(G, source, target)
                packet['path'] = path
                packet['delivered'] = True

                # Calculate cumulative latency
                total_latency = sum(G.nodes[node]['latency'] for node in path)
                packet['total_latency'] = total_latency
            else:
                packet['path'] = []
                packet['delivered'] = False
                packet['total_latency'] = None
        return packets


    def add_attack_node(self, G, target_ids, num_uavs, attack_node_pos=(random.randint(0, 100), random.randint(0, 100))):
        
        # Calculate a new ID for the attack node by taking the maximum current ID + 1
        
        attack_node_id = max(G.nodes()) + 1
        attk_battery = (100,100)
        battery = random.randint(*attk_battery)
        
        # Add the attack node with specified properties
        G.add_node(attack_node_id, pos=attack_node_pos, nodeName="Attack Node", is_attack_node=True, throughput=1000, latency=1, battery=battery)

        # Directly connect the attack node to the target node
        for target_id in target_ids:
            if target_id in G.nodes():
                G.add_edge(attack_node_id, target_id, weight=5)  # Weight can be adjusted or calculated based on actual metrics

        return attack_node_id

    def upload_attack_node_to_neo4j(self, G, attack_node_id, target_ids):
        
        with self.driver.session() as session:
            # Retrieve node data from the graph
            attack_node = G.nodes[attack_node_id]
            
            # Create the attack node in Neo4j
            session.run("""
                CREATE (a:AttackNode {
                    id: $id, 
                    pos: $pos,
                    nodeName: $nodeName,
                    throughput: $throughput, 
                    latency: $latency, 
                    battery: $battery, 
                    is_attack_node: $is_attack_node
                })
                """, id=attack_node_id, 
                    pos=str(attack_node['pos']),
                    nodeName=attack_node['nodeName'],
                    throughput=attack_node['throughput'], 
                    latency=attack_node['latency'], 
                    battery=attack_node['battery'], 
                    is_attack_node=True)

            # Create a relationship from the attack node to the target UAV
            for target_id in target_ids:
                if target_id in G.nodes():
                    session.run("""
                        MATCH (a:AttackNode {id: $attack_id}), (u:UAV {id: $target_id})
                        CREATE (a)-[:ATTACKS]->(u)
                        """, attack_id=attack_node_id, target_id=target_id)

    def update_network_metrics(self, G):
        
        for node in G.nodes():
            # Randomly increase latency by up to 10ms and decrease throughput by up to 10 Mbps
            G.nodes[node]['latency'] = max(1, G.nodes[node]['latency'] + random.randint(-5, 5))
            G.nodes[node]['throughput'] = max(1, G.nodes[node]['throughput'] + random.randint(-10, 10))

    def update_network_ddos_metrics(self, G):
        
        for node in G.nodes():
            # Randomly increase latency by up to 10ms and decrease throughput by up to 10 Mbps
            G.nodes[node]['latency'] += random.randint(1, 5)
            G.nodes[node]['throughput'] = max(1, G.nodes[node]['throughput'] - random.randint(1, 10))

    def run_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets):
    
        # Run the simulation for a specified period of time.
        results = []    
        start_time = time.time()
        iteration = 0
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            
            # Update UAV positions
            self.update_uav_positions(G, move_range)

            # Update network connections
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G) 

            # Update Neo4j database and redraw the graph
            # self.update_neo4j_database(G)
            # self.draw_graph(G)

            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)
            # Capture and record metrics for each node
            current_time = time.time() - start_time
            for node_id in G.nodes():
                results.append({
                    'time': current_time,
                    'node_id': node_id,
                    'latency': G.nodes[node_id]['latency'],
                    'throughput': G.nodes[node_id]['throughput']
                })
            print(results)

            # Log the routed packets information
            for i, packet in enumerate(routed_packets):
                print(f"  Packet {i}: Source: {packet['source']}, Target: {packet['target']}, "
                      f"Size: {packet['size']}, Delivered: {packet['delivered']}, "
                      f"Path: {packet['path']}, Total Latency: {packet['total_latency']}")

            # Wait for the next update
            time.sleep(update_interval)
            iteration += 1
        return results

    def simulate_ddos_attack(self, G, attack_node_id, target_ids, increase_factor, decrease_factor):
        for target_id in target_ids:
            if target_id in G.nodes():
                G.nodes[target_id]['latency'] = int(G.nodes[target_id]['latency'] * increase_factor)
                G.nodes[target_id]['throughput'] = int(G.nodes[target_id]['throughput'] * decrease_factor)
                G.nodes[target_id]['battery'] = int(G.nodes[target_id]['battery'] * decrease_factor)
                # Apply effects to neighboring nodes, ensuring integer operations
                for neighbor in G.neighbors(target_id):
                    G.nodes[neighbor]['latency'] = int(G.nodes[neighbor]['latency'] * (increase_factor - 0.1))
                    G.nodes[neighbor]['throughput'] = int(G.nodes[neighbor]['throughput'] * (decrease_factor + 0.1))
                    # G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))
                    if 'battery' in G.nodes[neighbor]:
                        G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))


    def run_ddos_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids):
        metrics = []  # List to store metrics over time
        start_time = time.time()
        iteration = 0
        
        # Define the directory and filename
        directory = "simulation_results"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/ddos_simulation_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            
            # Simulation updates
            self.update_uav_positions(G, move_range)
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G)
            
            # Trigger DDoS attack
            if iteration == 1:
                self.simulate_ddos_attack(G, attack_node_id, target_ids, 0.5, 0.5)
            
            # Traffic generation and routing
            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)
            
            # Capture and log metrics
            current_metrics = [
                (node, time.time() - start_time, G.nodes[node]['latency'], G.nodes[node]['throughput'], G.nodes[node]['battery'])
                for node in G.nodes()
            ]
            metrics.extend(current_metrics)
            
            # Print packet info
            for i, packet in enumerate(routed_packets):
                print(f"Packet {i}: Source: {packet['source']}, Target: {packet['target']}, Size: {packet['size']}, Delivered: {packet['delivered']}, Path: {packet['path']}, Total Latency: {packet['total_latency']}")
            
            # Delay for next update
            time.sleep(update_interval)
            iteration += 1
        
        # Save metrics to CSV
        with open(filename, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Node', 'Time', 'Latency', 'Throughput', 'Battery'])
            writer.writerows(metrics)
        
        print(f"Metrics saved to {filename}")
        return metrics

    def plot_time_series(self, results):
        import matplotlib.pyplot as plt

        # Filter results for a specific node for clarity, e.g., node 0
        node_results = [res for res in results if res['node_id'] == 0]
        times = [res['time'] for res in node_results]
        latencies = [res['latency'] for res in node_results]
        throughputs = [res['throughput'] for res in node_results]

        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(times, latencies, marker='o', color='r')
        plt.title('Latency Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Latency (ms)')

        plt.subplot(1, 2, 2)
        plt.plot(times, throughputs, marker='o', color='b')
        plt.title('Throughput Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Throughput (Mbps)')

        plt.tight_layout()
        plt.show()
    
    def analyze_network(self, G):
        # Calculate basic properties
        num_nodes = G.number_of_nodes()
        num_edges = G.number_of_edges()
        sparsity = nx.density(G)  # Density close to 0 indicates a sparse graph
        
        # Centrality measures
        degree_centrality = nx.degree_centrality(G)  # Normalized to (n-1)
        closeness_centrality = nx.closeness_centrality(G)
        betweenness_centrality = nx.betweenness_centrality(G)
        
        # Identifying the most central node
        most_central_node = max(degree_centrality, key=degree_centrality.get)
        
        # Network robustness (using node connectivity)
        connectivity = nx.node_connectivity(G)
        
        # Plotting
        pos = nx.spring_layout(G)  # positions for all nodes
        plt.figure(figsize=(8, 8))
        nx.draw_networkx_nodes(G, pos, node_size=700)
        nx.draw_networkx_edges(G, pos, width=6)
        nx.draw_networkx_labels(G, pos, font_size=20, font_family="sans-serif")
        plt.axis("off")
        plt.show()

        return {
            "Number of Nodes": num_nodes,
            "Number of Edges": num_edges,
            "Sparsity": sparsity,
            "Degree Centrality": degree_centrality,
            "Closeness Centrality": closeness_centrality,
            "Betweenness Centrality": betweenness_centrality,
            "Most Central Node": most_central_node,
            "Connectivity": connectivity
        }

# %% [markdown]
# Here we create the original graph and assign standard through put and latency values to each UAV. More nodes can be added to the network by parsing a new value to the "num_uavs" parameters below. Connections between nodes are based on node range and Euclidean distance.

# %%
"""Creating The Network First"""
# Simulation Parameters
num_uavs = 10
connection_range = 30
ground_station_pos = (50, 50)
backbone_range = 50
num_packets = 10

total_time = 60  # Total time to run the simulation in seconds
update_interval = 5  # Time interval between updates in seconds
move_range = 5

# Initialize Simulation
simulation = UAVNetworkSimulation(URI, AUTH)

# Create and Setup UAV Network
uav_network = simulation.create_initial_graph(num_uavs, connection_range, ground_station_pos, backbone_range)

# Upload to Neo4j
simulation.upload_to_neo4j(uav_network)

# Draw Initial Graph
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

# %% [markdown]
# We run our movement simulation code, in the process UAVs can make new communications as they are currently routing fictional packets. We log the results below immediately and generate data based on our routing logic. Perform descriptive statistics.

# %%
"""Routing Simulation"""
# Run the Simulation
results = simulation.run_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets)

# Update network connections
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# Update Neo4j Database with the new positions and connections
simulation.update_neo4j_database(uav_network)

# Now draw the graph to visualize the updated network
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

simulation.plot_time_series(results)

# %% [markdown]
# Adding The Attack Node.

# %%
#Add Attack Node
# Initialize the simulation object and create the initial UAV network
simulation = UAVNetworkSimulation(URI, AUTH)
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# # Upload the initial UAV network to Neo4j
simulation.upload_to_neo4j(uav_network)

# Target UAV ID for the DDoS attack
target_uav_ids = [5, 7] # Example: Target UAV ID that you want to attack

# Add the attack node and connect it to the target UAV
attack_node_id = simulation.add_attack_node(uav_network, target_uav_ids, num_uavs)
simulation.upload_attack_node_to_neo4j(uav_network, attack_node_id, target_uav_ids)

# Optionally, visualize the updated network to confirm the addition and connection of the attack node
simulation.draw_graph(uav_network)

# Close the Neo4j connection at the end of the session
simulation.close()

# %%
"""DDoS Simulation"""
# Initialize your network G here
target_nodes = [5, 7]  # Target node IDs that will be affected by the DDoS attack
# Assuming you have an attack node and some target nodes
attack_node_id = simulation.add_attack_node(uav_network, target_nodes, num_uavs)  # ID of your attack node

total_time = 120  # For example, run the simulation for 120 seconds
update_interval = 5
move_range = 10
connection_range = 30
backbone_range = 50
num_packets = 10
target_ids = [5, 7]  # Targeting nodes 5 and 7 for the DDoS attack

# Run the DDoS simulation
simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)
# Out:
# Iteration 0:
# Packet 0: Source: 6, Target: 2, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 5, Size: 18, Delivered: True, Path: [9, 11, 5], Total Latency: 75
# Packet 2: Source: 7, Target: 9, Size: 39, Delivered: True, Path: [7, 4, 9], Total Latency: 85
# Packet 3: Source: 10, Target: 0, Size: 21, Delivered: True, Path: [10, 11, 4, 0], Total Latency: 122
# Packet 4: Source: 8, Target: 0, Size: 3, Delivered: True, Path: [8, 9, 4, 0], Total Latency: 103
# Packet 5: Source: 0, Target: 2, Size: 50, Delivered: True, Path: [0, 4, 11, 2], Total Latency: 103
# Packet 6: Source: 10, Target: 6, Size: 66, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 8, Target: 9, Size: 3, Delivered: True, Path: [8, 9], Total Latency: 40
# Packet 8: Source: 2, Target: 0, Size: 57, Delivered: True, Path: [2, 11, 4, 0], Total Latency: 103
# Packet 9: Source: 1, Target: 7, Size: 71, Delivered: False, Path: [], Total Latency: None
# Iteration 1:
# Packet 0: Source: 4, Target: 0, Size: 21, Delivered: True, Path: [4, 11, 5, 12, 7, 0], Total Latency: 78
# Packet 1: Source: 4, Target: 10, Size: 65, Delivered: True, Path: [4, 11, 10], Total Latency: 66
# Packet 2: Source: 9, Target: 4, Size: 55, Delivered: True, Path: [9, 4], Total Latency: 56
# Packet 3: Source: 3, Target: 9, Size: 49, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 10, Target: 2, Size: 21, Delivered: True, Path: [10, 2], Total Latency: 29
# Packet 5: Source: 3, Target: 2, Size: 50, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 7, Size: 32, Delivered: True, Path: [2, 5, 12, 7], Total Latency: 24
# Packet 7: Source: 6, Target: 6, Size: 19, Delivered: True, Path: [6], Total Latency: 47
# Packet 8: Source: 9, Target: 5, Size: 33, Delivered: True, Path: [9, 11, 5], Total Latency: 51
# Packet 9: Source: 5, Target: 2, Size: 2, Delivered: True, Path: [5, 2], Total Latency: 10
# Iteration 2:
# Packet 0: Source: 1, Target: 5, Size: 69, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 0, Target: 10, Size: 25, Delivered: True, Path: [0, 7, 12, 5, 10], Total Latency: 53
# Packet 2: Source: 1, Target: 5, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 10, Target: 5, Size: 19, Delivered: True, Path: [10, 5], Total Latency: 28
# Packet 4: Source: 5, Target: 1, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 4, Target: 9, Size: 27, Delivered: True, Path: [4, 9], Total Latency: 60
# Packet 6: Source: 0, Target: 3, Size: 41, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 10, Target: 3, Size: 66, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 6, Target: 10, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 9, Size: 74, Delivered: True, Path: [8, 9], Total Latency: 42
# Iteration 3:
# Packet 0: Source: 3, Target: 9, Size: 34, Delivered: True, Path: [3, 8, 9], Total Latency: 67
# Packet 1: Source: 1, Target: 7, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 10, Size: 79, Delivered: True, Path: [8, 10], Total Latency: 34
# Packet 3: Source: 6, Target: 4, Size: 33, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 6, Size: 18, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 3, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 6, Target: 4, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 6, Target: 0, Size: 30, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 4, Size: 17, Delivered: True, Path: [5, 11, 4], Total Latency: 57
# Packet 9: Source: 8, Target: 0, Size: 11, Delivered: True, Path: [8, 11, 5, 12, 7, 0], Total Latency: 68
# Iteration 4:
# Packet 0: Source: 0, Target: 4, Size: 4, Delivered: True, Path: [0, 7, 12, 5, 11, 4], Total Latency: 84
# Packet 1: Source: 4, Target: 10, Size: 31, Delivered: True, Path: [4, 11, 10], Total Latency: 72
# Packet 2: Source: 3, Target: 7, Size: 57, Delivered: True, Path: [3, 8, 11, 5, 12, 7], Total Latency: 68
# Packet 3: Source: 0, Target: 2, Size: 9, Delivered: True, Path: [0, 7, 12, 5, 11, 2], Total Latency: 56
# Packet 4: Source: 9, Target: 0, Size: 51, Delivered: True, Path: [9, 11, 5, 12, 7, 0], Total Latency: 87
# Packet 5: Source: 8, Target: 3, Size: 28, Delivered: True, Path: [8, 3], Total Latency: 36
# Packet 6: Source: 7, Target: 7, Size: 30, Delivered: True, Path: [7], Total Latency: 12
# Packet 7: Source: 1, Target: 6, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 4, Target: 2, Size: 33, Delivered: True, Path: [4, 11, 2], Total Latency: 52
# Packet 9: Source: 5, Target: 7, Size: 24, Delivered: True, Path: [5, 12, 7], Total Latency: 14
# Iteration 5:
# Packet 0: Source: 0, Target: 6, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 4, Size: 5, Delivered: True, Path: [7, 12, 5, 11, 4], Total Latency: 74
# Packet 2: Source: 7, Target: 3, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 7, Size: 42, Delivered: True, Path: [7], Total Latency: 11
# Packet 4: Source: 5, Target: 6, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 9, Target: 10, Size: 68, Delivered: True, Path: [9, 8, 10], Total Latency: 79
# Packet 6: Source: 8, Target: 10, Size: 49, Delivered: True, Path: [8, 10], Total Latency: 45
# Packet 7: Source: 3, Target: 5, Size: 77, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 7, Target: 3, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 2, Size: 29, Delivered: True, Path: [8, 2], Total Latency: 20
# Iteration 6:
# Packet 0: Source: 6, Target: 9, Size: 23, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 8, Size: 16, Delivered: True, Path: [7, 12, 5, 2, 8], Total Latency: 44
# Packet 2: Source: 5, Target: 4, Size: 7, Delivered: True, Path: [5, 11, 4], Total Latency: 64
# Packet 3: Source: 2, Target: 8, Size: 5, Delivered: True, Path: [2, 8], Total Latency: 24
# Packet 4: Source: 8, Target: 2, Size: 34, Delivered: True, Path: [8, 2], Total Latency: 24
# Packet 5: Source: 8, Target: 6, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 7, Target: 9, Size: 5, Delivered: True, Path: [7, 12, 5, 11, 9], Total Latency: 79
# Packet 7: Source: 10, Target: 9, Size: 69, Delivered: True, Path: [10, 8, 9], Total Latency: 84
# Packet 8: Source: 7, Target: 5, Size: 47, Delivered: True, Path: [7, 12, 5], Total Latency: 20
# Packet 9: Source: 5, Target: 7, Size: 1, Delivered: True, Path: [5, 12, 7], Total Latency: 20
# Iteration 7:
# Packet 0: Source: 7, Target: 9, Size: 5, Delivered: True, Path: [7, 12, 5, 11, 9], Total Latency: 86
# Packet 1: Source: 8, Target: 7, Size: 72, Delivered: True, Path: [8, 11, 5, 12, 7], Total Latency: 67
# Packet 2: Source: 9, Target: 4, Size: 77, Delivered: True, Path: [9, 4], Total Latency: 74
# Packet 3: Source: 6, Target: 8, Size: 46, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 1, Size: 31, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 6, Target: 1, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 3, Target: 3, Size: 18, Delivered: True, Path: [3], Total Latency: 18
# Packet 7: Source: 7, Target: 5, Size: 5, Delivered: True, Path: [7, 12, 5], Total Latency: 31
# Packet 8: Source: 10, Target: 3, Size: 77, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 10, Size: 28, Delivered: True, Path: [4, 8, 10], Total Latency: 86
# Iteration 8:
# Packet 0: Source: 7, Target: 4, Size: 26, Delivered: True, Path: [7, 12, 5, 11, 4], Total Latency: 93
# Packet 1: Source: 9, Target: 2, Size: 6, Delivered: True, Path: [9, 11, 2], Total Latency: 59
# Packet 2: Source: 9, Target: 5, Size: 12, Delivered: True, Path: [9, 11, 5], Total Latency: 70
# Packet 3: Source: 7, Target: 9, Size: 38, Delivered: True, Path: [7, 12, 5, 11, 9], Total Latency: 97
# Packet 4: Source: 0, Target: 2, Size: 28, Delivered: True, Path: [0, 7, 12, 5, 2], Total Latency: 60
# Packet 5: Source: 6, Target: 4, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 3, Target: 9, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 4, Target: 7, Size: 35, Delivered: True, Path: [4, 11, 5, 12, 7], Total Latency: 93
# Packet 8: Source: 4, Target: 4, Size: 47, Delivered: True, Path: [4], Total Latency: 38
# Packet 9: Source: 7, Target: 4, Size: 21, Delivered: True, Path: [7, 12, 5, 11, 4], Total Latency: 93
# Iteration 9:
# Packet 0: Source: 4, Target: 4, Size: 6, Delivered: True, Path: [4], Total Latency: 38
# Packet 1: Source: 4, Target: 1, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 1, Target: 5, Size: 51, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 6, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 2, Target: 10, Size: 1, Delivered: True, Path: [2, 11, 10], Total Latency: 49
# Packet 5: Source: 7, Target: 0, Size: 37, Delivered: True, Path: [7, 0], Total Latency: 36
# Packet 6: Source: 1, Target: 5, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 6, Target: 2, Size: 39, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 10, Target: 6, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 0, Target: 1, Size: 25, Delivered: False, Path: [], Total Latency: None
# Iteration 10:
# Packet 0: Source: 3, Target: 1, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 7, Size: 15, Delivered: True, Path: [7], Total Latency: 18
# Packet 2: Source: 8, Target: 8, Size: 47, Delivered: True, Path: [8], Total Latency: 17
# Packet 3: Source: 1, Target: 9, Size: 48, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 8, Target: 6, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 2, Target: 8, Size: 23, Delivered: True, Path: [2, 10, 8], Total Latency: 54
# Packet 6: Source: 10, Target: 8, Size: 37, Delivered: True, Path: [10, 8], Total Latency: 44
# Packet 7: Source: 8, Target: 4, Size: 57, Delivered: True, Path: [8, 11, 4], Total Latency: 71
# Packet 8: Source: 10, Target: 7, Size: 16, Delivered: True, Path: [10, 11, 7], Total Latency: 59
# Packet 9: Source: 1, Target: 6, Size: 51, Delivered: False, Path: [], Total Latency: None
# Iteration 11:
# Packet 0: Source: 1, Target: 9, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 4, Size: 34, Delivered: True, Path: [8, 11, 4], Total Latency: 70
# Packet 2: Source: 6, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 7, Size: 26, Delivered: True, Path: [0, 7], Total Latency: 40
# Packet 4: Source: 7, Target: 0, Size: 4, Delivered: True, Path: [7, 0], Total Latency: 40
# Packet 5: Source: 8, Target: 7, Size: 78, Delivered: True, Path: [8, 11, 7], Total Latency: 55
# Packet 6: Source: 6, Target: 8, Size: 46, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 6, Size: 41, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 6, Target: 1, Size: 42, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 5, Target: 0, Size: 21, Delivered: True, Path: [5, 12, 7, 0], Total Latency: 69
# Iteration 12:
# Packet 0: Source: 7, Target: 4, Size: 22, Delivered: True, Path: [7, 4], Total Latency: 47
# Packet 1: Source: 3, Target: 6, Size: 79, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 10, Size: 42, Delivered: True, Path: [7, 11, 10], Total Latency: 54
# Packet 3: Source: 8, Target: 1, Size: 52, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 10, Size: 20, Delivered: True, Path: [0, 7, 11, 10], Total Latency: 71
# Packet 5: Source: 3, Target: 5, Size: 48, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 10, Target: 4, Size: 15, Delivered: True, Path: [10, 11, 4], Total Latency: 69
# Packet 7: Source: 3, Target: 8, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 9, Target: 8, Size: 23, Delivered: True, Path: [9, 10, 8], Total Latency: 89
# Packet 9: Source: 7, Target: 8, Size: 2, Delivered: True, Path: [7, 11, 8], Total Latency: 57
# Iteration 13:
# Packet 0: Source: 6, Target: 8, Size: 56, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 4, Target: 4, Size: 19, Delivered: True, Path: [4], Total Latency: 32
# Packet 2: Source: 10, Target: 6, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 8, Size: 46, Delivered: True, Path: [7, 11, 8], Total Latency: 59
# Packet 4: Source: 4, Target: 5, Size: 36, Delivered: True, Path: [4, 11, 5], Total Latency: 58
# Packet 5: Source: 10, Target: 2, Size: 56, Delivered: True, Path: [10, 11, 2], Total Latency: 53
# Packet 6: Source: 5, Target: 1, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 9, Target: 4, Size: 100, Delivered: True, Path: [9, 11, 4], Total Latency: 92
# Packet 8: Source: 3, Target: 6, Size: 40, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 8, Size: 65, Delivered: True, Path: [4, 11, 8], Total Latency: 77
# Iteration 14:
# Packet 0: Source: 9, Target: 8, Size: 7, Delivered: True, Path: [9, 10, 8], Total Latency: 96
# Packet 1: Source: 9, Target: 7, Size: 57, Delivered: True, Path: [9, 11, 7], Total Latency: 69
# Packet 2: Source: 5, Target: 1, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 4, Target: 6, Size: 29, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 5, Target: 5, Size: 11, Delivered: True, Path: [5], Total Latency: 5
# Packet 5: Source: 5, Target: 9, Size: 25, Delivered: True, Path: [5, 9], Total Latency: 48
# Packet 6: Source: 2, Target: 10, Size: 6, Delivered: True, Path: [2, 10], Total Latency: 31
# Packet 7: Source: 2, Target: 10, Size: 10, Delivered: True, Path: [2, 10], Total Latency: 31
# Packet 8: Source: 9, Target: 8, Size: 19, Delivered: True, Path: [9, 10, 8], Total Latency: 96
# Packet 9: Source: 2, Target: 1, Size: 40, Delivered: False, Path: [], Total Latency: None
# Iteration 15:
# Packet 0: Source: 2, Target: 2, Size: 22, Delivered: True, Path: [2], Total Latency: 1
# Packet 1: Source: 4, Target: 5, Size: 80, Delivered: True, Path: [4, 11, 5], Total Latency: 52
# Packet 2: Source: 7, Target: 9, Size: 45, Delivered: True, Path: [7, 11, 9], Total Latency: 68
# Packet 3: Source: 1, Target: 7, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 7, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 10, Target: 9, Size: 29, Delivered: True, Path: [10, 9], Total Latency: 72
# Packet 6: Source: 5, Target: 3, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 10, Size: 54, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 4, Target: 0, Size: 50, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 10, Size: 23, Delivered: True, Path: [8, 11, 10], Total Latency: 66
# Iteration 16:
# Packet 0: Source: 9, Target: 0, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 10, Target: 2, Size: 55, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 4, Target: 3, Size: 54, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 6, Target: 8, Size: 28, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 8, Size: 5, Delivered: True, Path: [7, 11, 8], Total Latency: 46
# Packet 5: Source: 1, Target: 4, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 4, Target: 9, Size: 47, Delivered: True, Path: [4, 11, 9], Total Latency: 99
# Packet 7: Source: 0, Target: 0, Size: 8, Delivered: True, Path: [0], Total Latency: 20
# Packet 8: Source: 2, Target: 10, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 2, Target: 0, Size: 36, Delivered: False, Path: [], Total Latency: None
# Iteration 17:
# Packet 0: Source: 7, Target: 9, Size: 49, Delivered: True, Path: [7, 11, 9], Total Latency: 76
# Packet 1: Source: 6, Target: 3, Size: 88, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 4, Size: 3, Delivered: True, Path: [8, 11, 4], Total Latency: 72
# Packet 3: Source: 9, Target: 8, Size: 40, Delivered: True, Path: [9, 11, 8], Total Latency: 97
# Packet 4: Source: 3, Target: 2, Size: 69, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 10, Target: 9, Size: 5, Delivered: True, Path: [10, 9], Total Latency: 74
# Packet 6: Source: 1, Target: 9, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 7, Target: 5, Size: 2, Delivered: True, Path: [7, 12, 5], Total Latency: 17
# Packet 8: Source: 9, Target: 8, Size: 84, Delivered: True, Path: [9, 11, 8], Total Latency: 97
# Packet 9: Source: 6, Target: 7, Size: 57, Delivered: False, Path: [], Total Latency: None
# Iteration 18:
# Packet 0: Source: 3, Target: 9, Size: 41, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 6, Size: 8, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 0, Size: 60, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 4, Target: 9, Size: 47, Delivered: True, Path: [4, 11, 9], Total Latency: 102
# Packet 4: Source: 6, Target: 3, Size: 39, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 7, Size: 9, Delivered: True, Path: [7], Total Latency: 7
# Packet 6: Source: 9, Target: 6, Size: 54, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 8, Target: 10, Size: 30, Delivered: True, Path: [8, 10], Total Latency: 46
# Packet 8: Source: 1, Target: 3, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 2, Size: 60, Delivered: False, Path: [], Total Latency: None
# Iteration 19:
# Packet 0: Source: 2, Target: 6, Size: 27, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 2, Target: 4, Size: 24, Delivered: True, Path: [2, 10, 11, 4], Total Latency: 75
# Packet 2: Source: 9, Target: 0, Size: 33, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 3, Target: 7, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 2, Size: 39, Delivered: True, Path: [7, 11, 10, 2], Total Latency: 57
# Packet 5: Source: 0, Target: 10, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 1, Target: 4, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 10, Size: 4, Delivered: True, Path: [2, 10], Total Latency: 26
# Packet 8: Source: 4, Target: 5, Size: 80, Delivered: True, Path: [4, 11, 5], Total Latency: 52
# Packet 9: Source: 4, Target: 2, Size: 61, Delivered: True, Path: [4, 11, 10, 2], Total Latency: 75
# Iteration 20:
# Packet 0: Source: 9, Target: 2, Size: 91, Delivered: True, Path: [9, 5, 2], Total Latency: 57
# Packet 1: Source: 8, Target: 1, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 4, Target: 1, Size: 86, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 9, Target: 3, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 3, Target: 0, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 4, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 7, Target: 6, Size: 40, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 6, Target: 1, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 6, Target: 2, Size: 71, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 9, Target: 8, Size: 82, Delivered: True, Path: [9, 11, 8], Total Latency: 98
# Iteration 21:
# Packet 0: Source: 9, Target: 8, Size: 63, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 1, Target: 9, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 0, Size: 44, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 3, Target: 9, Size: 47, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 6, Target: 1, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 9, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 3, Size: 18, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 2, Size: 10, Delivered: True, Path: [2], Total Latency: 9
# Packet 8: Source: 10, Target: 3, Size: 45, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 9, Target: 4, Size: 22, Delivered: True, Path: [9, 11, 4], Total Latency: 90
# Iteration 22:
# Packet 0: Source: 3, Target: 0, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 3, Size: 76, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 2, Target: 3, Size: 17, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 6, Target: 2, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 1, Target: 5, Size: 29, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 3, Target: 8, Size: 81, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 6, Target: 5, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 5, Target: 9, Size: 7, Delivered: True, Path: [5, 11, 9], Total Latency: 68
# Packet 8: Source: 8, Target: 8, Size: 60, Delivered: True, Path: [8], Total Latency: 22
# Packet 9: Source: 4, Target: 2, Size: 77, Delivered: False, Path: [], Total Latency: None
# Iteration 23:
# Packet 0: Source: 4, Target: 2, Size: 89, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 0, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 1, Target: 9, Size: 42, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 6, Target: 8, Size: 5, Delivered: True, Path: [6, 8], Total Latency: 61
# Packet 4: Source: 7, Target: 10, Size: 19, Delivered: True, Path: [7, 11, 10], Total Latency: 56
# Packet 5: Source: 8, Target: 2, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 5, Target: 10, Size: 1, Delivered: True, Path: [5, 10], Total Latency: 20
# Packet 7: Source: 8, Target: 3, Size: 74, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 10, Target: 1, Size: 52, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 8, Target: 8, Size: 3, Delivered: True, Path: [8], Total Latency: 24
# Metrics saved to simulation_results/ddos_simulation_20240426_030300.csv
# [(0, 0.0009989738464355469, 38, 76, 100),
#  (1, 0.0009989738464355469, 44, 73, 100),
#  (2, 0.0009989738464355469, 9, 83, 100),
#  (3, 0.0009989738464355469, 22, 69, 100),
#  (4, 0.0009989738464355469, 25, 62, 100),
#  (5, 0.0009989738464355469, 16, 73, 100),
#  (6, 0.0009989738464355469, 43, 51, 100),
#  (7, 0.0009989738464355469, 32, 92, 100),
#  (8, 0.0009989738464355469, 12, 90, 100),
#  (9, 0.0009989738464355469, 28, 94, 100),
#  (10, 0.0009989738464355469, 28, 83, 100),
#  (11, 0.0009989738464355469, 31, 98, 100),
#  (12, 0.0009989738464355469, 1, 1007, 100),
#  (0, 5.013108730316162, 17, 46, 60),
#  (1, 5.013108730316162, 47, 83, 100),
#  (2, 5.013108730316162, 2, 45, 60),
#  (3, 5.013108730316162, 18, 64, 100),
#  (4, 5.013108730316162, 26, 66, 100),
#  (5, 5.013108730316162, 8, 36, 50),
#  (6, 5.013108730316162, 47, 41, 100),
#  (7, 5.013108730316162, 14, 44, 50),
#  (8, 5.013108730316162, 9, 98, 100),
#  (9, 5.014115571975708, 30, 86, 100),
#  (10, 5.014115571975708, 27, 91, 100),
#  (11, 5.014115571975708, 13, 61, 60),
#  (12, 5.014115571975708, 0, 360, 36),
#  (0, 10.031095266342163, 14, 42, 60),
#  (1, 10.031095266342163, 46, 86, 100),
#  (2, 10.031095266342163, 1, 37, 60),
#  (3, 10.031095266342163, 20, 58, 100),
#  (4, 10.031095266342163, 29, 61, 100),
#  (5, 10.031095266342163, 5, 31, 50),
#  (6, 10.031095266342163, 50, 41, 100),
#  (7, 10.031095266342163, 10, 43, 50),
#  (8, 10.031095266342163, 11, 94, 100),
#  (9, 10.031095266342163, 31, 91, 100),
#  (10, 10.031095266342163, 23, 83, 100),
#  (11, 10.031095266342163, 18, 66, 60),
#  (12, 10.031095266342163, 1, 354, 36),
#  (0, 15.049093246459961, 18, 43, 60),
#  (1, 15.049093246459961, 42, 79, 100),
#  (2, 15.049093246459961, 1, 29, 60),
#  (3, 15.049093246459961, 21, 67, 100),
#  (4, 15.049093246459961, 34, 66, 100),
#  (5, 15.049093246459961, 4, 26, 50),
#  (6, 15.049093246459961, 46, 37, 100),
#  (7, 15.049093246459961, 14, 33, 50),
#  (8, 15.049093246459961, 11, 85, 100),
#  (9, 15.049093246459961, 35, 97, 100),
#  (10, 15.049093246459961, 23, 76, 100),
#  (11, 15.049093246459961, 19, 68, 60),
#  (12, 15.049093246459961, 2, 360, 36),
#  (0, 20.05585503578186, 21, 36, 60),
#  (1, 20.05585503578186, 46, 86, 100),
#  (2, 20.05585503578186, 3, 30, 60),
#  (3, 20.05585503578186, 22, 75, 100),
#  (4, 20.05585503578186, 31, 61, 100),
#  (5, 20.05585503578186, 1, 33, 50),
#  (6, 20.05585503578186, 46, 44, 100),
#  (7, 20.05585503578186, 12, 41, 50),
#  (8, 20.05585503578186, 14, 83, 100),
#  (9, 20.05585503578186, 34, 93, 100),
#  (10, 20.05585503578186, 23, 80, 100),
#  (11, 20.05585503578186, 18, 66, 60),
#  (12, 20.05585503578186, 1, 358, 36),
#  (0, 25.069679260253906, 16, 29, 60),
#  (1, 25.069679260253906, 48, 76, 100),
#  (2, 25.069679260253906, 2, 24, 60),
#  (3, 25.069679260253906, 18, 84, 100),
#  (4, 25.069679260253906, 34, 52, 100),
#  (5, 25.069679260253906, 2, 42, 50),
#  (6, 25.069679260253906, 48, 44, 100),
#  (7, 25.069679260253906, 11, 49, 50),
#  (8, 25.069679260253906, 18, 83, 100),
#  (9, 25.069679260253906, 34, 93, 100),
#  (10, 25.069679260253906, 27, 85, 100),
#  (11, 25.069679260253906, 22, 67, 60),
#  (12, 25.069679260253906, 5, 358, 36),
#  (0, 30.073121786117554, 14, 38, 60),
#  (1, 30.073121786117554, 47, 68, 100),
#  (2, 30.073121786117554, 4, 19, 60),
#  (3, 30.073121786117554, 23, 90, 100),
#  (4, 30.073121786117554, 37, 45, 100),
#  (5, 30.073121786117554, 5, 38, 50),
#  (6, 30.073121786117554, 45, 41, 100),
#  (7, 30.073121786117554, 6, 47, 50),
#  (8, 30.073121786117554, 20, 73, 100),
#  (9, 30.073121786117554, 37, 94, 100),
#  (10, 30.073121786117554, 27, 82, 100),
#  (11, 30.073121786117554, 22, 75, 60),
#  (12, 30.073121786117554, 9, 356, 36),
#  (0, 35.08520555496216, 16, 48, 60),
#  (1, 35.08520555496216, 51, 69, 100),
#  (2, 35.08520555496216, 1, 20, 60),
#  (3, 35.08520555496216, 18, 99, 100),
#  (4, 35.08520555496216, 36, 55, 100),
#  (5, 35.08520555496216, 8, 30, 50),
#  (6, 35.08520555496216, 47, 50, 100),
#  (7, 35.08520555496216, 11, 43, 50),
#  (8, 35.08520555496216, 19, 80, 100),
#  (9, 35.08520555496216, 38, 87, 100),
#  (10, 35.08520555496216, 31, 84, 100),
#  (11, 35.08520555496216, 17, 83, 60),
#  (12, 35.08520555496216, 12, 352, 36),
#  (0, 40.0953574180603, 20, 40, 60),
#  (1, 40.0953574180603, 48, 64, 100),
#  (2, 40.0953574180603, 1, 30, 60),
#  (3, 40.0953574180603, 23, 90, 100),
#  (4, 40.0953574180603, 38, 47, 100),
#  (5, 40.0953574180603, 12, 21, 50),
#  (6, 40.0953574180603, 49, 43, 100),
#  (7, 40.0953574180603, 13, 48, 50),
#  (8, 40.0953574180603, 16, 72, 100),
#  (9, 40.0953574180603, 42, 89, 100),
#  (10, 40.0953574180603, 29, 77, 100),
#  (11, 40.0953574180603, 16, 86, 60),
#  (12, 40.0953574180603, 14, 357, 36),
#  (0, 45.10132169723511, 20, 38, 60),
#  (1, 45.10132169723511, 48, 54, 100),
#  (2, 45.10132169723511, 5, 37, 60),
#  (3, 45.10132169723511, 18, 97, 100),
#  (4, 45.10132169723511, 38, 55, 100),
#  (5, 45.10132169723511, 7, 28, 50),
#  (6, 45.10132169723511, 50, 50, 100),
#  (7, 45.10132169723511, 16, 41, 50),
#  (8, 45.10132169723511, 16, 80, 100),
#  (9, 45.10132169723511, 39, 95, 100),
#  (10, 45.10132169723511, 25, 83, 100),
#  (11, 45.10132169723511, 19, 79, 60),
#  (12, 45.10132169723511, 17, 348, 36),
#  (0, 50.11275839805603, 15, 31, 60),
#  (1, 50.11275839805603, 50, 61, 100),
#  (2, 50.11275839805603, 10, 32, 60),
#  (3, 50.11275839805603, 17, 96, 100),
#  (4, 50.11275839805603, 40, 64, 100),
#  (5, 50.11275839805603, 9, 32, 50),
#  (6, 50.11275839805603, 46, 57, 100),
#  (7, 50.11275839805603, 18, 48, 50),
#  (8, 50.11275839805603, 17, 88, 100),
#  (9, 50.11275839805603, 39, 94, 100),
#  (10, 50.11275839805603, 27, 77, 100),
#  (11, 50.11275839805603, 14, 70, 60),
#  (12, 50.11275839805603, 13, 348, 36),
#  (0, 55.12341618537903, 20, 26, 60),
#  (1, 55.12341618537903, 52, 54, 100),
#  (2, 55.12341618537903, 9, 23, 60),
#  (3, 55.12341618537903, 20, 100, 100),
#  (4, 55.12341618537903, 35, 73, 100),
#  (5, 55.12341618537903, 11, 25, 50),
#  (6, 55.12341618537903, 42, 47, 100),
#  (7, 55.12341618537903, 20, 50, 50),
#  (8, 55.12341618537903, 22, 82, 100),
#  (9, 55.12341618537903, 37, 104, 100),
#  (10, 55.12341618537903, 27, 72, 100),
#  (11, 55.12341618537903, 13, 76, 60),
#  (12, 55.12341618537903, 18, 352, 36),
#  (0, 60.13571524620056, 17, 20, 60),
#  (1, 60.13571524620056, 56, 62, 100),
#  (2, 60.13571524620056, 12, 32, 60),
#  (3, 60.13571524620056, 18, 102, 100),
#  (4, 60.13571524620056, 31, 75, 100),
#  (5, 60.13571524620056, 6, 30, 50),
#  (6, 60.13571524620056, 37, 47, 100),
#  (7, 60.13571524620056, 16, 58, 50),
#  (8, 60.13571524620056, 26, 76, 100),
#  (9, 60.13571524620056, 40, 109, 100),
#  (10, 60.13571524620056, 23, 72, 100),
#  (11, 60.13571524620056, 15, 79, 60),
#  (12, 60.13571524620056, 14, 344, 36),
#  (0, 65.14967226982117, 21, 25, 60),
#  (1, 65.14967226982117, 53, 59, 100),
#  (2, 65.14967226982117, 8, 32, 60),
#  (3, 65.14967226982117, 18, 98, 100),
#  (4, 65.14967226982117, 32, 65, 100),
#  (5, 65.14967226982117, 9, 22, 50),
#  (6, 65.14967226982117, 40, 57, 100),
#  (7, 65.14967226982117, 14, 62, 50),
#  (8, 65.14967226982117, 28, 82, 100),
#  (9, 65.14967226982117, 43, 100, 100),
#  (10, 65.14967226982117, 28, 69, 100),
#  (11, 65.14967226982117, 17, 82, 60),
#  (12, 65.14967226982117, 16, 354, 36),
#  (0, 70.15657305717468, 19, 21, 60),
#  (1, 70.15657305717468, 56, 65, 100),
#  (2, 70.15657305717468, 3, 40, 60),
#  (3, 70.15657305717468, 16, 108, 100),
#  (4, 70.15657305717468, 31, 72, 100),
#  (5, 70.15657305717468, 5, 26, 50),
#  (6, 70.15657305717468, 39, 67, 100),
#  (7, 70.15657305717468, 9, 60, 50),
#  (8, 70.15657305717468, 25, 75, 100),
#  (9, 70.15657305717468, 43, 90, 100),
#  (10, 70.15657305717468, 28, 66, 100),
#  (11, 70.15657305717468, 17, 85, 60),
#  (12, 70.15657305717468, 18, 362, 36),
#  (0, 75.16503548622131, 19, 16, 60),
#  (1, 75.16503548622131, 55, 55, 100),
#  (2, 75.16503548622131, 1, 34, 60),
#  (3, 75.16503548622131, 18, 106, 100),
#  (4, 75.16503548622131, 29, 82, 100),
#  (5, 75.16503548622131, 6, 32, 50),
#  (6, 75.16503548622131, 42, 74, 100),
#  (7, 75.16503548622131, 4, 67, 50),
#  (8, 75.16503548622131, 24, 82, 100),
#  (9, 75.16503548622131, 47, 86, 100),
#  (10, 75.16503548622131, 25, 57, 100),
#  (11, 75.16503548622131, 17, 77, 60),
#  (12, 75.16503548622131, 14, 359, 36),
#  (0, 80.17111325263977, 20, 14, 60),
#  (1, 80.17111325263977, 55, 46, 100),
#  (2, 80.17111325263977, 6, 38, 60),
#  (3, 80.17111325263977, 14, 113, 100),
#  (4, 80.17111325263977, 31, 76, 100),
#  (5, 80.17111325263977, 8, 29, 50),
#  (6, 80.17111325263977, 37, 83, 100),
#  (7, 80.17111325263977, 1, 58, 50),
#  (8, 80.17111325263977, 27, 75, 100),
#  (9, 80.17111325263977, 50, 90, 100),
#  (10, 80.17111325263977, 24, 60, 100),
#  (11, 80.17111325263977, 18, 75, 60),
#  (12, 80.17111325263977, 9, 349, 36),
#  (0, 85.1824049949646, 16, 17, 60),
#  (1, 85.1824049949646, 52, 37, 100),
#  (2, 85.1824049949646, 3, 31, 60),
#  (3, 85.1824049949646, 10, 107, 100),
#  (4, 85.1824049949646, 28, 70, 100),
#  (5, 85.1824049949646, 5, 29, 50),
#  (6, 85.1824049949646, 35, 92, 100),
#  (7, 85.1824049949646, 5, 50, 50),
#  (8, 85.1824049949646, 26, 70, 100),
#  (9, 85.1824049949646, 53, 91, 100),
#  (10, 85.1824049949646, 21, 52, 100),
#  (11, 85.1824049949646, 18, 67, 60),
#  (12, 85.1824049949646, 7, 359, 36),
#  (0, 90.18959999084473, 11, 9, 60),
#  (1, 90.18959999084473, 52, 29, 100),
#  (2, 90.18959999084473, 1, 25, 60),
#  (3, 90.18959999084473, 7, 117, 100),
#  (4, 90.18959999084473, 25, 76, 100),
#  (5, 90.18959999084473, 8, 22, 50),
#  (6, 90.18959999084473, 36, 89, 100),
#  (7, 90.18959999084473, 7, 56, 50),
#  (8, 90.18959999084473, 21, 68, 100),
#  (9, 90.18959999084473, 54, 100, 100),
#  (10, 90.18959999084473, 25, 61, 100),
#  (11, 90.18959999084473, 23, 62, 60),
#  (12, 90.18959999084473, 6, 360, 36),
#  (0, 95.20704102516174, 14, 4, 60),
#  (1, 95.20704102516174, 49, 25, 100),
#  (2, 95.20704102516174, 4, 31, 60),
#  (3, 95.20704102516174, 5, 119, 100),
#  (4, 95.20704102516174, 24, 84, 100),
#  (5, 95.20704102516174, 3, 17, 50),
#  (6, 95.20704102516174, 38, 99, 100),
#  (7, 95.20704102516174, 6, 56, 50),
#  (8, 95.20704102516174, 22, 78, 100),
#  (9, 95.20704102516174, 49, 102, 100),
#  (10, 95.20704102516174, 22, 54, 100),
#  (11, 95.20704102516174, 25, 52, 60),
#  (12, 95.20704102516174, 5, 360, 36),
#  (0, 100.22245979309082, 16, 7, 60),
#  (1, 100.22245979309082, 52, 32, 100),
#  (2, 100.22245979309082, 8, 24, 60),
#  (3, 100.22245979309082, 1, 119, 100),
#  (4, 100.22245979309082, 20, 91, 100),
#  (5, 100.22245979309082, 3, 15, 50),
#  (6, 100.22245979309082, 34, 93, 100),
#  (7, 100.22245979309082, 4, 56, 50),
#  (8, 100.22245979309082, 23, 75, 100),
#  (9, 100.22245979309082, 46, 93, 100),
#  (10, 100.22245979309082, 27, 51, 100),
#  (11, 100.22245979309082, 29, 54, 60),
#  (12, 100.22245979309082, 7, 359, 36),
#  (0, 105.23635196685791, 21, 1, 60),
#  (1, 105.23635196685791, 51, 40, 100),
#  (2, 105.23635196685791, 9, 33, 60),
#  (3, 105.23635196685791, 1, 120, 100),
#  (4, 105.23635196685791, 25, 95, 100),
#  (5, 105.23635196685791, 1, 23, 50),
#  (6, 105.23635196685791, 36, 84, 100),
#  (7, 105.23635196685791, 6, 51, 50),
#  (8, 105.23635196685791, 21, 69, 100),
#  (9, 105.23635196685791, 41, 90, 100),
#  (10, 105.23635196685791, 23, 60, 100),
#  (11, 105.23635196685791, 24, 57, 60),
#  (12, 105.23635196685791, 8, 361, 36),
#  (0, 110.25511145591736, 20, 1, 60),
#  (1, 110.25511145591736, 54, 47, 100),
#  (2, 110.25511145591736, 9, 26, 60),
#  (3, 110.25511145591736, 1, 128, 100),
#  (4, 110.25511145591736, 20, 95, 100),
#  (5, 110.25511145591736, 1, 29, 50),
#  (6, 110.25511145591736, 40, 76, 100),
#  (7, 110.25511145591736, 10, 41, 50),
#  (8, 110.25511145591736, 22, 77, 100),
#  (9, 110.25511145591736, 41, 93, 100),
#  (10, 110.25511145591736, 22, 54, 100),
#  (11, 110.25511145591736, 26, 48, 60),
#  (12, 110.25511145591736, 11, 365, 36),
#  (0, 115.25805306434631, 17, 10, 60),
#  (1, 115.25805306434631, 59, 48, 100),
#  (2, 115.25805306434631, 5, 22, 60),
#  (3, 115.25805306434631, 1, 123, 100),
#  (4, 115.25805306434631, 19, 99, 100),
#  (5, 115.25805306434631, 1, 36, 50),
#  (6, 115.25805306434631, 37, 83, 100),
#  (7, 115.25805306434631, 9, 46, 50),
#  (8, 115.25805306434631, 24, 78, 100),
#  (9, 115.25805306434631, 36, 102, 100),
#  (10, 115.25805306434631, 19, 62, 100),
#  (11, 115.25805306434631, 28, 42, 60),
#  (12, 115.25805306434631, 8, 364, 36)]

# %% [markdown]
# Descriptive Statistics, Performing Correlation Analysis On the Dataset and plotting correlation matrix.

# %%
import matplotlib.pyplot as plt
metrics = simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)

def plot_network_metrics(metrics):
    # Assuming metrics is a list of tuples (node_id, time, latency, throughput, battery)
    # Filter by node_id for node 5 and node 7
    times_5 = [m[1] for m in metrics if m[0] == 5]
    latencies_5 = [m[2] for m in metrics if m[0] == 5]
    throughputs_5 = [m[3] for m in metrics if m[0] == 5]

    times_7 = [m[1] for m in metrics if m[0] == 7]
    latencies_7 = [m[2] for m in metrics if m[0] == 7]
    throughputs_7 = [m[3] for m in metrics if m[0] == 7]

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times_5, latencies_5, label='Latency UAV 5')
    plt.plot(times_7, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times_5, throughputs_5, label='Throughput UAV 5')
    plt.plot(times_7, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()
    
if metrics:
    plot_network_metrics(metrics)
else:
    print("No data was returned from the simulation.")
# Example usage:
# metrics = [(5, 1.0, 50, 100), (7, 1.0, 70, 90), (5, 2.0, 55, 95), (7, 2.0, 75, 85)]
# plot_network_metrics(metrics)

# %%
"""Pearson's Correlation"""

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data provided
data = [
    {'time': 0.001983642578125, 'node_id': 0, 'latency': 16, 'throughput': 71},
    {'time': 0.001983642578125, 'node_id': 1, 'latency': 41, 'throughput': 54},
    {'time': 0.001983642578125, 'node_id': 2, 'latency': 32, 'throughput': 76},
    {'time': 0.001983642578125, 'node_id': 3, 'latency': 7, 'throughput': 52},
    {'time': 0.001983642578125, 'node_id': 4, 'latency': 18, 'throughput': 53},
    {'time': 0.001983642578125, 'node_id': 5, 'latency': 17, 'throughput': 65},
    {'time': 0.001983642578125, 'node_id': 6, 'latency': 16, 'throughput': 84},
    {'time': 0.001983642578125, 'node_id': 7, 'latency': 40, 'throughput': 55},
    {'time': 0.001983642578125, 'node_id': 8, 'latency': 37, 'throughput': 68},
    {'time': 0.001983642578125, 'node_id': 9, 'latency': 39, 'throughput': 77},
    {'time': 0.001983642578125, 'node_id': 10, 'latency': 36, 'throughput': 86},
    {'time': 0.001983642578125, 'node_id': 11, 'latency': 39, 'throughput': 94},
    {'time': 5.015164613723755, 'node_id': 0, 'latency': 17, 'throughput': 78},
    # Assuming the rest of the data points are appended here in the same format...
]

# Converting data into a pandas DataFrame
df = pd.DataFrame(data)

# Calculating the correlation between latency and throughput
correlation_matrix = df[['latency', 'throughput']].corr()
print(correlation_matrix)


# Plotting a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
heatmap.set_title('Correlation Heatmap between Latency and Throughput', pad=12)
plt.show()

# %%
def plot_network_metrics_from_csv(file_path):
    # Load data from CSV
    df = pd.read_csv(file_path)
    
    # Filter data for specific nodes
    node_5_df = df[df['Node'] == 5]
    node_7_df = df[df['Node'] == 7]
    
    # Extract times, latencies, and throughputs
    times_5 = node_5_df['Time']
    latencies_5 = node_5_df['Latency']
    throughputs_5 = node_5_df['Throughput']

    times_7 = node_7_df['Time']
    latencies_7 = node_7_df['Latency']
    throughputs_7 = node_7_df['Throughput']

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times_5, latencies_5, label='Latency UAV 5')
    plt.plot(times_7, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times_5, throughputs_5, label='Throughput UAV 5')
    plt.plot(times_7, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
file_path = 'simulation_results\ddos_simulation_20240423_012712.csv'
plot_network_metrics_from_csv(file_path)

# %%
simulation.analyze_network(uav_network)
