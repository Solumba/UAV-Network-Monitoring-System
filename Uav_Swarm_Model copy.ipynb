# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import random
import numpy as np
import time
import csv
import os
import time
from datetime import datetime
from neo4j import GraphDatabase

# Neo4j configuration
URI = "neo4j://localhost:7687"
AUTH = ("neo4j", "Shady5000$")

# %%
class UAVNetworkSimulation:

    def __init__(self, uri, auth):
        self.driver = GraphDatabase.driver(uri, auth=auth)

    def close(self):
        self.driver.close()
    
    def create_initial_graph(self, num_uavs, connection_range, ground_station_pos, backbone_range):
        #Create undirected graph
        G = nx.Graph()

        # Define typical throughput and latency ranges (for example purposes)
        typical_throughput = (50, 100)  # Mbps
        typical_latency = (10, 50)     # Milliseconds
        typical_battery = (100,100) # %

        # Add UAV nodes with properties
        for i in range(num_uavs):
            throughput = random.randint(*typical_throughput)
            latency = random.randint(*typical_latency)
            battery = random.randint(*typical_battery)
            G.add_node(i, pos=(random.randint(0, 100), random.randint(0, 100)),
                       throughput=throughput, latency=latency, battery=battery)

        # Add The Backbone UAV
        backbone_uav_id = num_uavs
        G.add_node(backbone_uav_id, pos=(random.randint(0, 100), random.randint(0, 100)), is_backbone=True,
                       throughput=throughput, latency=latency, battery=battery)

        # Connect Backbone UAV to other UAVs Based on Euclidean Distance
        for i in range(num_uavs):
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        # Add and connect the Ground Station To The Backbone Only
        ground_station_id = num_uavs + 1
        G.add_node(ground_station_id, pos=ground_station_pos, is_ground_station=True, throughput=throughput, latency=latency, battery=battery)
        G.add_edge(backbone_uav_id, ground_station_id)

        # Add edges between UAVs within connection range
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        return G
    
    # Upload Current Graph To Neo4j
    def upload_to_neo4j(self, G):
        with self.driver.session() as session:
            # Clear existing data
            session.run("MATCH (n) DETACH DELETE n")

            # Add nodes
            for node in G.nodes:
                is_backbone = G.nodes[node].get('is_backbone', False)
                is_ground_station = G.nodes[node].get('is_ground_station', False)
                is_attack_node = G.nodes[node].get('is_attack_node', False)

                if is_backbone:
                    session.run(f"""
                        CREATE (b:BackboneUAV {{id: $id, pos: $pos, uavType: $uavType,
                            throughput: $throughput, latency: $latency, battery: $battery  + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "Backbone UAV", throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])
                elif is_ground_station:
                    session.run(f"""
                        CREATE (g:GroundStation {{id: $id, pos: $pos, gsName: $GS, battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], GS = "Ground Station", battery=G.nodes[node]['battery'])
                else:
                    session.run(f"""
                        CREATE (u:UAV {{id: $id, pos: $pos, uavType: $uavType, uavName: $uavName,
                            throughput: $throughput + 'mb/s', latency: $latency + 'ms', battery: $battery + '%'}})
                        """, id=node, pos=G.nodes[node]['pos'], uavType = "UAV", uavName = "UAV"  + str(node), throughput=G.nodes[node]['throughput'],
                        latency=G.nodes[node]['latency'], battery=G.nodes[node]['battery'])

            # Add relationships
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)


    def draw_graph(self, G):
        pos = nx.get_node_attributes(G, 'pos')

        # Prepare custom labels
        labels = {}
        for node in G.nodes:
            if G.nodes[node].get('is_backbone', False):
                labels[node] = 'Backbone UAV'
            elif G.nodes[node].get('is_ground_station', False):
                labels[node] = 'Ground Station'
            elif G.nodes[node].get('is_attack_node', False):
                labels[node] = 'Attack Node'
            else:
                labels[node] = f'UAV{node}'

        # Differentiate node types
        regular_nodes = [node for node in G.nodes if not G.nodes[node].get('is_backbone', False) and not G.nodes[node].get('is_ground_station', False)]
        backbone_nodes = [node for node in G.nodes if G.nodes[node].get('is_backbone', False)]
        ground_station_nodes = [node for node in G.nodes if G.nodes[node].get('is_ground_station', False)]
        attacking_nodes = [node for node in G.nodes if G.nodes[node].get('is_attack_node', False)]

        # Draw regular UAV nodes
        nx.draw_networkx_nodes(G, pos, nodelist=regular_nodes, node_color='green', node_size=300, label='UAV')
        
        # Draw backbone UAV node
        nx.draw_networkx_nodes(G, pos, nodelist=backbone_nodes, node_color='lightgreen', node_size=500, label='Backbone UAV')

        # Draw ground station node
        nx.draw_networkx_nodes(G, pos, nodelist=ground_station_nodes, node_color='lightblue', node_size=500, label='Ground Station')

        nx.draw_networkx_nodes(G, pos, nodelist=attacking_nodes, node_color='red', node_size=500, label='Attack Node')

        # Draw edges
        nx.draw_networkx_edges(G, pos, edge_color='gray')

        # Draw custom labels
        nx.draw_networkx_labels(G, pos, labels)

        plt.title("Multilayer UAV Network")
        plt.legend()
        plt.show()
        
    def update_uav_positions(self, G, move_range):
        """
        Update the positions of UAVs randomly within a given range.
        """
        for node in G.nodes:
            if 'is_backbone' not in G.nodes[node] and 'is_ground_station' not in G.nodes[node]:
                current_pos = G.nodes[node]['pos']
                new_pos = (current_pos[0] + random.uniform(-move_range, move_range), 
                           current_pos[1] + random.uniform(-move_range, move_range))
                G.nodes[node]['pos'] = new_pos
        return G

    def update_network_connections(self, G, connection_range, backbone_range):
        """
        Update the network connections based on new positions and connection range.
        """
        num_uavs = len(G.nodes) - 2  # Excluding backbone UAV and ground station
        backbone_uav_id = num_uavs

        # Update connections for regular UAVs
        for i in range(num_uavs):
            for j in range(i + 1, num_uavs):
                if G.has_edge(i, j):
                    G.remove_edge(i, j)
                pos_i = G.nodes[i]['pos']
                pos_j = G.nodes[j]['pos']
                distance = np.linalg.norm(np.array(pos_i) - np.array(pos_j))
                if distance <= connection_range:
                    G.add_edge(i, j, weight=distance)

        # Update connections for the Backbone UAV
        for i in range(num_uavs):
            if G.has_edge(i, backbone_uav_id):
                G.remove_edge(i, backbone_uav_id)
            pos_i = G.nodes[i]['pos']
            pos_backbone = G.nodes[backbone_uav_id]['pos']
            distance = np.linalg.norm(np.array(pos_i) - np.array(pos_backbone))
            if distance <= backbone_range:
                G.add_edge(i, backbone_uav_id, weight=distance)

        return G

    def update_neo4j_database(self, G):
        """
        Update the Neo4j database with the new positions and connections.
        """
        with self.driver.session() as session:
            # Update positions
            for node in G.nodes:
                pos = G.nodes[node]['pos']
                session.run("""
                    MATCH (n)
                    WHERE n.id = $id
                    SET n.pos = $pos
                    """, id=node, pos=pos)

            # Update relationships
            session.run("MATCH (n)-[r:COMMUNICATES_WITH]->() DELETE r")
            for source, target in G.edges:
                session.run("""
                    MATCH (a), (b)
                    WHERE a.id = $source AND b.id = $target
                    CREATE (a)-[:COMMUNICATES_WITH]->(b)
                    """, source=source, target=target)
    
    def generate_network_traffic(self, G, num_packets):
        """
        Generate network traffic considering the throughput of UAVs.
        """
        packets = []
        for _ in range(num_packets):
            source = random.randint(0, len(G.nodes) - 3)  # Exclude backbone and ground station
            target = random.randint(0, len(G.nodes) - 3)
            
            #Packet size should not exceed the throughput of the source UAV
            max_packet_size = G.nodes[source]['throughput']
            size = random.randint(1, max_packet_size)

            packets.append({'source': source, 'target': target, 'size': size})
        return packets
    
    def route_packets(self, G, packets):
        """
        Determine the path for each packet and calculate cumulative latency.
        """
        for packet in packets:
            source = packet['source']
            target = packet['target']
            if nx.has_path(G, source, target):
                path = nx.shortest_path(G, source, target)
                packet['path'] = path
                packet['delivered'] = True

                # Calculate cumulative latency
                total_latency = sum(G.nodes[node]['latency'] for node in path)
                packet['total_latency'] = total_latency
            else:
                packet['path'] = []
                packet['delivered'] = False
                packet['total_latency'] = None
        return packets


    def add_attack_node(self, G, target_ids, num_uavs, attack_node_pos=(random.randint(0, 100), random.randint(0, 100))):
        # Calculate a new ID for the attack node by taking the maximum current ID + 1
        attack_node_id = max(G.nodes()) + 1
        attk_battery = (100,100)
        battery = random.randint(*attk_battery)
        # Add the attack node with specified properties
        G.add_node(attack_node_id, pos=attack_node_pos, nodeName="Attack Node", is_attack_node=True, throughput=1000, latency=1, battery=battery)

        # Directly connect the attack node to the target node
        for target_id in target_ids:
            if target_id in G.nodes():
                G.add_edge(attack_node_id, target_id, weight=5)  # Weight can be adjusted or calculated based on actual metrics

        return attack_node_id

    def upload_attack_node_to_neo4j(self, G, attack_node_id, target_ids):
        with self.driver.session() as session:
            # Retrieve node data from the graph
            attack_node = G.nodes[attack_node_id]
            # Create the attack node in Neo4j
            session.run("""
                CREATE (a:AttackNode {
                    id: $id, 
                    pos: $pos,
                    nodeName: $nodeName,
                    throughput: $throughput, 
                    latency: $latency, 
                    battery: $battery, 
                    is_attack_node: $is_attack_node
                })
                """, id=attack_node_id, 
                    pos=str(attack_node['pos']),
                    nodeName=attack_node['nodeName'],
                    throughput=attack_node['throughput'], 
                    latency=attack_node['latency'], 
                    battery=attack_node['battery'], 
                    is_attack_node=True)

            # Create a relationship from the attack node to the target UAV
            for target_id in target_ids:
                if target_id in G.nodes():
                    session.run("""
                        MATCH (a:AttackNode {id: $attack_id}), (u:UAV {id: $target_id})
                        CREATE (a)-[:ATTACKS]->(u)
                        """, attack_id=attack_node_id, target_id=target_id)

    def update_network_metrics(self, G):
        for node in G.nodes():
            # Randomly increase latency by up to 10ms and decrease throughput by up to 10 Mbps
            G.nodes[node]['latency'] = max(1, G.nodes[node]['latency'] + random.randint(-5, 5))
            G.nodes[node]['throughput'] = max(1, G.nodes[node]['throughput'] + random.randint(-10, 10))

    def run_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets):
    
        #Run the simulation for a specified period of time.
        results = []    
        start_time = time.time()
        iteration = 0
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            
            # Update UAV positions
            self.update_uav_positions(G, move_range)

            # Update network connections
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G) 
            # Optional: Update Neo4j database and redraw the graph at each step
            # self.update_neo4j_database(G)
            # self.draw_graph(G)
            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)
             # Capture and record metrics for each node
            current_time = time.time() - start_time
            for node_id in G.nodes():
                results.append({
                    'time': current_time,
                    'node_id': node_id,
                    'latency': G.nodes[node_id]['latency'],
                    'throughput': G.nodes[node_id]['throughput']
                })
            print(results)
             # Log the routed packets information
            for i, packet in enumerate(routed_packets):
                print(f"  Packet {i}: Source: {packet['source']}, Target: {packet['target']}, "
                      f"Size: {packet['size']}, Delivered: {packet['delivered']}, "
                      f"Path: {packet['path']}, Total Latency: {packet['total_latency']}")

            # Wait for the next update
            time.sleep(update_interval)
            iteration += 1
        return results

    def simulate_ddos_attack(self, G, attack_node_id, target_ids, increase_factor, decrease_factor):
        for target_id in target_ids:
            if target_id in G.nodes():
                G.nodes[target_id]['latency'] = int(G.nodes[target_id]['latency'] * increase_factor)
                G.nodes[target_id]['throughput'] = int(G.nodes[target_id]['throughput'] * decrease_factor)
                G.nodes[target_id]['battery'] = int(G.nodes[target_id]['battery'] * decrease_factor)
                # Apply effects to neighboring nodes, ensuring integer operations
                for neighbor in G.neighbors(target_id):
                    G.nodes[neighbor]['latency'] = int(G.nodes[neighbor]['latency'] * (increase_factor - 0.1))
                    G.nodes[neighbor]['throughput'] = int(G.nodes[neighbor]['throughput'] * (decrease_factor + 0.1))
                    # G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))
                    if 'battery' in G.nodes[neighbor]:
                        G.nodes[neighbor]['battery'] = int(G.nodes[neighbor]['battery'] * (decrease_factor + 0.1))


    def run_ddos_simulation(self, G, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids):
        metrics = []  # List to store metrics over time
        start_time = time.time()
        iteration = 0
        
        # Define the directory and filename
        directory = "simulation_results"
        if not os.path.exists(directory):
            os.makedirs(directory)
        filename = f"{directory}/ddos_simulation_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
        
        while time.time() - start_time < total_time:
            print(f"Iteration {iteration}:")
            
            # Simulation updates
            self.update_uav_positions(G, move_range)
            self.update_network_connections(G, connection_range, backbone_range)
            self.update_network_metrics(G)
            
            # Trigger DDoS attack
            if iteration == 1:
                self.simulate_ddos_attack(G, attack_node_id, target_ids, 100.5, 0.5)
            
            # Traffic generation and routing
            packets = self.generate_network_traffic(G, num_packets)
            routed_packets = self.route_packets(G, packets)
            
            # Capture and log metrics
            current_metrics = [
                (node, time.time() - start_time, G.nodes[node]['latency'], G.nodes[node]['throughput'], G.nodes[node]['battery'])
                for node in G.nodes()
            ]
            metrics.extend(current_metrics)
            
            # Print packet info
            for i, packet in enumerate(routed_packets):
                print(f"Packet {i}: Source: {packet['source']}, Target: {packet['target']}, Size: {packet['size']}, Delivered: {packet['delivered']}, Path: {packet['path']}, Total Latency: {packet['total_latency']}")
            
            # Delay for next update
            time.sleep(update_interval)
            iteration += 1
        
        # Save metrics to CSV
        with open(filename, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(['Node', 'Time', 'Latency', 'Throughput', 'Battery'])
            writer.writerows(metrics)
        
        print(f"Metrics saved to {filename}")
        return metrics

    def plot_time_series(self, results):
        import matplotlib.pyplot as plt

        # Filter results for a specific node for clarity, e.g., node 0
        node_results = [res for res in results if res['node_id'] == 0]
        times = [res['time'] for res in node_results]
        latencies = [res['latency'] for res in node_results]
        throughputs = [res['throughput'] for res in node_results]

        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(times, latencies, marker='o', color='r')
        plt.title('Latency Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Latency (ms)')

        plt.subplot(1, 2, 2)
        plt.plot(times, throughputs, marker='o', color='b')
        plt.title('Throughput Over Time for Node 0')
        plt.xlabel('Time (s)')
        plt.ylabel('Throughput (Mbps)')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# Here we create the original graph and assign standard through put and latency values to each UAV. More nodes can be added to the network by parsing a new value to the "num_uavs" parameters below. Connections between nodes are based on node range and Euclidean distance.

# %%
"""Creating The Network First"""
# Simulation Parameters
num_uavs = 10
connection_range = 30
ground_station_pos = (50, 50)
backbone_range = 50
num_packets = 10

total_time = 60  # Total time to run the simulation in seconds
update_interval = 5  # Time interval between updates in seconds
move_range = 5

# Initialize Simulation
simulation = UAVNetworkSimulation(URI, AUTH)

# Create and Setup UAV Network
uav_network = simulation.create_initial_graph(num_uavs, connection_range, ground_station_pos, backbone_range)

# Upload to Neo4j
simulation.upload_to_neo4j(uav_network)

# Draw Initial Graph
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

# %% [markdown]
# We run our movement simulation code, in the process UAVs can make new communications as they are currently routing fictional packets. We log the results below immediately and generate data based on our routing logic. Perform descriptive statistics.

# %%
"""Routing Simulation"""
# Run the Simulation
results = simulation.run_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets)

# Update network connections
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# Update Neo4j Database with the new positions and connections
simulation.update_neo4j_database(uav_network)

# Now draw the graph to visualize the updated network
simulation.draw_graph(uav_network)

# Close Neo4j Connection
simulation.close()

simulation.plot_time_series(results)
# Out:
# Iteration 0:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}]
#   Packet 0: Source: 6, Target: 2, Size: 34, Delivered: True, Path: [6, 2], Total Latency: 40
#   Packet 1: Source: 4, Target: 4, Size: 45, Delivered: True, Path: [4], Total Latency: 20
#   Packet 2: Source: 2, Target: 2, Size: 84, Delivered: True, Path: [2], Total Latency: 32
#   Packet 3: Source: 7, Target: 4, Size: 29, Delivered: True, Path: [7, 6, 2, 5, 4], Total Latency: 130
#   Packet 4: Source: 7, Target: 7, Size: 24, Delivered: True, Path: [7], Total Latency: 26
#   Packet 5: Source: 2, Target: 7, Size: 83, Delivered: True, Path: [2, 6, 7], Total Latency: 66
#   Packet 6: Source: 5, Target: 7, Size: 6, Delivered: True, Path: [5, 2, 6, 7], Total Latency: 110
#   Packet 7: Source: 0, Target: 1, Size: 66, Delivered: True, Path: [0, 5, 1], Total Latency: 116
#   Packet 8: Source: 3, Target: 7, Size: 66, Delivered: True, Path: [3, 10, 2, 6, 7], Total Latency: 109
#   Packet 9: Source: 4, Target: 9, Size: 1, Delivered: True, Path: [4, 3, 9], Total Latency: 64
# Iteration 1:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}]
#   Packet 0: Source: 5, Target: 6, Size: 24, Delivered: True, Path: [5, 2, 6], Total Latency: 78
#   Packet 1: Source: 2, Target: 1, Size: 83, Delivered: True, Path: [2, 1], Total Latency: 73
#   Packet 2: Source: 1, Target: 8, Size: 54, Delivered: True, Path: [1, 2, 8], Total Latency: 106
#   Packet 3: Source: 4, Target: 7, Size: 88, Delivered: True, Path: [4, 5, 2, 6, 7], Total Latency: 123
#   Packet 4: Source: 5, Target: 3, Size: 21, Delivered: True, Path: [5, 0, 3], Total Latency: 101
#   Packet 5: Source: 0, Target: 2, Size: 58, Delivered: True, Path: [0, 5, 2], Total Latency: 94
#   Packet 6: Source: 4, Target: 3, Size: 93, Delivered: True, Path: [4, 3], Total Latency: 51
#   Packet 7: Source: 8, Target: 5, Size: 56, Delivered: True, Path: [8, 5], Total Latency: 74
#   Packet 8: Source: 7, Target: 8, Size: 18, Delivered: True, Path: [7, 6, 2, 8], Total Latency: 100
#   Packet 9: Source: 8, Target: 2, Size: 64, Delivered: True, Path: [8, 2], Total Latency: 62
# Iteration 2:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}]
#   Packet 0: Source: 3, Target: 1, Size: 28, Delivered: True, Path: [3, 10, 1], Total Latency: 88
#   Packet 1: Source: 6, Target: 6, Size: 20, Delivered: True, Path: [6], Total Latency: 10
#   Packet 2: Source: 5, Target: 2, Size: 2, Delivered: True, Path: [5, 2], Total Latency: 75
#   Packet 3: Source: 2, Target: 2, Size: 34, Delivered: True, Path: [2], Total Latency: 32
#   Packet 4: Source: 8, Target: 5, Size: 50, Delivered: True, Path: [8, 2, 5], Total Latency: 109
#   Packet 5: Source: 6, Target: 6, Size: 8, Delivered: True, Path: [6], Total Latency: 10
#   Packet 6: Source: 1, Target: 9, Size: 45, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 9, Target: 8, Size: 73, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 5, Target: 2, Size: 41, Delivered: True, Path: [5, 2], Total Latency: 75
#   Packet 9: Source: 1, Target: 3, Size: 33, Delivered: True, Path: [1, 10, 3], Total Latency: 88
# Iteration 3:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}]
#   Packet 0: Source: 0, Target: 9, Size: 88, Delivered: True, Path: [0, 4, 9], Total Latency: 44
#   Packet 1: Source: 8, Target: 0, Size: 56, Delivered: True, Path: [8, 4, 0], Total Latency: 63
#   Packet 2: Source: 2, Target: 1, Size: 72, Delivered: True, Path: [2, 1], Total Latency: 72
#   Packet 3: Source: 7, Target: 4, Size: 24, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 4, Target: 1, Size: 47, Delivered: True, Path: [4, 10, 1], Total Latency: 72
#   Packet 5: Source: 8, Target: 0, Size: 95, Delivered: True, Path: [8, 4, 0], Total Latency: 63
#   Packet 6: Source: 1, Target: 3, Size: 27, Delivered: True, Path: [1, 10, 3], Total Latency: 97
#   Packet 7: Source: 1, Target: 0, Size: 53, Delivered: True, Path: [1, 5, 0], Total Latency: 103
#   Packet 8: Source: 9, Target: 2, Size: 14, Delivered: True, Path: [9, 4, 10, 2], Total Latency: 72
#   Packet 9: Source: 6, Target: 3, Size: 44, Delivered: False, Path: [], Total Latency: None
# Iteration 4:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 3, Target: 5, Size: 42, Delivered: True, Path: [3, 10, 5], Total Latency: 109
#   Packet 1: Source: 6, Target: 0, Size: 41, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 3, Target: 0, Size: 31, Delivered: True, Path: [3, 0], Total Latency: 59
#   Packet 3: Source: 4, Target: 7, Size: 16, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 0, Target: 5, Size: 35, Delivered: True, Path: [0, 10, 5], Total Latency: 88
#   Packet 5: Source: 8, Target: 9, Size: 57, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 5, Target: 5, Size: 44, Delivered: True, Path: [5], Total Latency: 45
#   Packet 7: Source: 8, Target: 5, Size: 57, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 9, Target: 2, Size: 5, Delivered: True, Path: [9, 4, 10, 2], Total Latency: 68
#   Packet 9: Source: 0, Target: 6, Size: 61, Delivered: False, Path: [], Total Latency: None
# Iteration 5:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 2, Target: 6, Size: 61, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 7, Target: 1, Size: 26, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 6, Target: 4, Size: 5, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 5, Target: 1, Size: 23, Delivered: True, Path: [5, 1], Total Latency: 80
#   Packet 4: Source: 5, Target: 3, Size: 58, Delivered: True, Path: [5, 10, 3], Total Latency: 111
#   Packet 5: Source: 6, Target: 4, Size: 30, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 4, Target: 6, Size: 82, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 5, Target: 5, Size: 85, Delivered: True, Path: [5], Total Latency: 40
#   Packet 8: Source: 3, Target: 8, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 6, Target: 5, Size: 13, Delivered: False, Path: [], Total Latency: None
# Iteration 6:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 0, Target: 1, Size: 37, Delivered: True, Path: [0, 5, 1], Total Latency: 102
#   Packet 1: Source: 5, Target: 6, Size: 37, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 2, Target: 8, Size: 27, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 4, Target: 0, Size: 44, Delivered: True, Path: [4, 3, 0], Total Latency: 69
#   Packet 4: Source: 9, Target: 7, Size: 7, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 2, Target: 1, Size: 50, Delivered: True, Path: [2, 1], Total Latency: 59
#   Packet 6: Source: 8, Target: 7, Size: 6, Delivered: True, Path: [8, 7], Total Latency: 60
#   Packet 7: Source: 4, Target: 6, Size: 67, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 0, Target: 7, Size: 60, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 7, Target: 3, Size: 40, Delivered: False, Path: [], Total Latency: None
# Iteration 7:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 0, Target: 8, Size: 75, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 3, Target: 8, Size: 61, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 8, Target: 6, Size: 10, Delivered: True, Path: [8, 6], Total Latency: 48
#   Packet 3: Source: 4, Target: 1, Size: 61, Delivered: True, Path: [4, 3, 10, 1], Total Latency: 120
#   Packet 4: Source: 0, Target: 3, Size: 17, Delivered: True, Path: [0, 3], Total Latency: 50
#   Packet 5: Source: 1, Target: 0, Size: 4, Delivered: True, Path: [1, 5, 0], Total Latency: 98
#   Packet 6: Source: 7, Target: 6, Size: 23, Delivered: True, Path: [7, 6], Total Latency: 34
#   Packet 7: Source: 0, Target: 0, Size: 83, Delivered: True, Path: [0], Total Latency: 11
#   Packet 8: Source: 1, Target: 2, Size: 8, Delivered: True, Path: [1, 2], Total Latency: 61
#   Packet 9: Source: 2, Target: 3, Size: 41, Delivered: True, Path: [2, 10, 3], Total Latency: 84
# Iteration 8:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 3, Target: 7, Size: 13, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 7, Target: 4, Size: 41, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 2, Target: 1, Size: 59, Delivered: True, Path: [2, 1], Total Latency: 65
#   Packet 3: Source: 8, Target: 6, Size: 64, Delivered: True, Path: [8, 6], Total Latency: 57
#   Packet 4: Source: 4, Target: 0, Size: 20, Delivered: True, Path: [4, 3, 0], Total Latency: 66
#   Packet 5: Source: 7, Target: 3, Size: 45, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 9, Target: 4, Size: 31, Delivered: True, Path: [9, 4], Total Latency: 24
#   Packet 7: Source: 3, Target: 1, Size: 18, Delivered: True, Path: [3, 10, 1], Total Latency: 113
#   Packet 8: Source: 2, Target: 4, Size: 9, Delivered: True, Path: [2, 10, 3, 4], Total Latency: 97
#   Packet 9: Source: 4, Target: 2, Size: 64, Delivered: True, Path: [4, 3, 10, 2], Total Latency: 97
# Iteration 9:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 5, Target: 6, Size: 38, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 7, Target: 0, Size: 39, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 9, Target: 7, Size: 75, Delivered: False, Path: [], Total Latency: None
#   Packet 3: Source: 2, Target: 4, Size: 87, Delivered: True, Path: [2, 10, 4], Total Latency: 62
#   Packet 4: Source: 9, Target: 7, Size: 88, Delivered: False, Path: [], Total Latency: None
#   Packet 5: Source: 7, Target: 3, Size: 10, Delivered: False, Path: [], Total Latency: None
#   Packet 6: Source: 2, Target: 6, Size: 94, Delivered: False, Path: [], Total Latency: None
#   Packet 7: Source: 2, Target: 6, Size: 20, Delivered: False, Path: [], Total Latency: None
#   Packet 8: Source: 2, Target: 5, Size: 60, Delivered: True, Path: [2, 5], Total Latency: 49
#   Packet 9: Source: 2, Target: 7, Size: 20, Delivered: False, Path: [], Total Latency: None
# Iteration 10:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 2, Target: 6, Size: 4, Delivered: False, Path: [], Total Latency: None
#   Packet 1: Source: 4, Target: 1, Size: 33, Delivered: True, Path: [4, 3, 0, 1], Total Latency: 102
#   Packet 2: Source: 9, Target: 2, Size: 105, Delivered: True, Path: [9, 4, 3, 10, 2], Total Latency: 114
#   Packet 3: Source: 0, Target: 4, Size: 22, Delivered: True, Path: [0, 3, 4], Total Latency: 58
#   Packet 4: Source: 1, Target: 0, Size: 28, Delivered: True, Path: [1, 0], Total Latency: 53
#   Packet 5: Source: 9, Target: 5, Size: 43, Delivered: True, Path: [9, 4, 3, 0, 5], Total Latency: 109
#   Packet 6: Source: 8, Target: 6, Size: 88, Delivered: True, Path: [8, 6], Total Latency: 60
#   Packet 7: Source: 6, Target: 6, Size: 27, Delivered: True, Path: [6], Total Latency: 23
#   Packet 8: Source: 1, Target: 7, Size: 35, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 5, Target: 8, Size: 39, Delivered: False, Path: [], Total Latency: None
# Iteration 11:
# [{'time': 0.003620624542236328, 'node_id': 0, 'latency': 29, 'throughput': 93}, {'time': 0.003620624542236328, 'node_id': 1, 'latency': 43, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 2, 'latency': 32, 'throughput': 85}, {'time': 0.003620624542236328, 'node_id': 3, 'latency': 31, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 4, 'latency': 20, 'throughput': 94}, {'time': 0.003620624542236328, 'node_id': 5, 'latency': 44, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 6, 'latency': 8, 'throughput': 49}, {'time': 0.003620624542236328, 'node_id': 7, 'latency': 26, 'throughput': 47}, {'time': 0.003620624542236328, 'node_id': 8, 'latency': 37, 'throughput': 98}, {'time': 0.003620624542236328, 'node_id': 9, 'latency': 13, 'throughput': 69}, {'time': 0.003620624542236328, 'node_id': 10, 'latency': 12, 'throughput': 62}, {'time': 0.003620624542236328, 'node_id': 11, 'latency': 21, 'throughput': 50}, {'time': 5.014840126037598, 'node_id': 0, 'latency': 24, 'throughput': 85}, {'time': 5.014840126037598, 'node_id': 1, 'latency': 44, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 2, 'latency': 29, 'throughput': 95}, {'time': 5.014840126037598, 'node_id': 3, 'latency': 36, 'throughput': 68}, {'time': 5.014840126037598, 'node_id': 4, 'latency': 15, 'throughput': 97}, {'time': 5.014840126037598, 'node_id': 5, 'latency': 41, 'throughput': 71}, {'time': 5.014840126037598, 'node_id': 6, 'latency': 8, 'throughput': 51}, {'time': 5.014840126037598, 'node_id': 7, 'latency': 30, 'throughput': 38}, {'time': 5.014840126037598, 'node_id': 8, 'latency': 33, 'throughput': 96}, {'time': 5.014840126037598, 'node_id': 9, 'latency': 13, 'throughput': 79}, {'time': 5.014840126037598, 'node_id': 10, 'latency': 15, 'throughput': 72}, {'time': 5.014840126037598, 'node_id': 11, 'latency': 20, 'throughput': 49}, {'time': 10.030946731567383, 'node_id': 0, 'latency': 24, 'throughput': 88}, {'time': 10.030946731567383, 'node_id': 1, 'latency': 42, 'throughput': 62}, {'time': 10.030946731567383, 'node_id': 2, 'latency': 32, 'throughput': 90}, {'time': 10.030946731567383, 'node_id': 3, 'latency': 32, 'throughput': 66}, {'time': 10.030946731567383, 'node_id': 4, 'latency': 10, 'throughput': 92}, {'time': 10.030946731567383, 'node_id': 5, 'latency': 43, 'throughput': 73}, {'time': 10.030946731567383, 'node_id': 6, 'latency': 10, 'throughput': 43}, {'time': 10.030946731567383, 'node_id': 7, 'latency': 25, 'throughput': 44}, {'time': 10.030946731567383, 'node_id': 8, 'latency': 34, 'throughput': 89}, {'time': 10.030946731567383, 'node_id': 9, 'latency': 17, 'throughput': 85}, {'time': 10.030946731567383, 'node_id': 10, 'latency': 14, 'throughput': 68}, {'time': 10.030946731567383, 'node_id': 11, 'latency': 21, 'throughput': 54}, {'time': 15.038123607635498, 'node_id': 0, 'latency': 20, 'throughput': 88}, {'time': 15.038123607635498, 'node_id': 1, 'latency': 43, 'throughput': 60}, {'time': 15.038123607635498, 'node_id': 2, 'latency': 29, 'throughput': 87}, {'time': 15.038123607635498, 'node_id': 3, 'latency': 35, 'throughput': 63}, {'time': 15.038123607635498, 'node_id': 4, 'latency': 10, 'throughput': 101}, {'time': 15.038123607635498, 'node_id': 5, 'latency': 40, 'throughput': 80}, {'time': 15.038123607635498, 'node_id': 6, 'latency': 6, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 7, 'latency': 26, 'throughput': 48}, {'time': 15.038123607635498, 'node_id': 8, 'latency': 33, 'throughput': 97}, {'time': 15.038123607635498, 'node_id': 9, 'latency': 14, 'throughput': 84}, {'time': 15.038123607635498, 'node_id': 10, 'latency': 19, 'throughput': 67}, {'time': 15.038123607635498, 'node_id': 11, 'latency': 25, 'throughput': 45}, {'time': 20.046645402908325, 'node_id': 0, 'latency': 19, 'throughput': 83}, {'time': 20.046645402908325, 'node_id': 1, 'latency': 42, 'throughput': 50}, {'time': 20.046645402908325, 'node_id': 2, 'latency': 24, 'throughput': 91}, {'time': 20.046645402908325, 'node_id': 3, 'latency':  ...
#   Packet 0: Source: 4, Target: 1, Size: 61, Delivered: True, Path: [4, 3, 0, 1], Total Latency: 103
#   Packet 1: Source: 2, Target: 6, Size: 97, Delivered: False, Path: [], Total Latency: None
#   Packet 2: Source: 3, Target: 5, Size: 31, Delivered: True, Path: [3, 0, 5], Total Latency: 79
#   Packet 3: Source: 6, Target: 1, Size: 30, Delivered: False, Path: [], Total Latency: None
#   Packet 4: Source: 0, Target: 3, Size: 91, Delivered: True, Path: [0, 3], Total Latency: 41
#   Packet 5: Source: 3, Target: 0, Size: 28, Delivered: True, Path: [3, 0], Total Latency: 41
#   Packet 6: Source: 4, Target: 5, Size: 60, Delivered: True, Path: [4, 3, 0, 5], Total Latency: 94
#   Packet 7: Source: 5, Target: 4, Size: 14, Delivered: True, Path: [5, 0, 3, 4], Total Latency: 94
#   Packet 8: Source: 8, Target: 5, Size: 97, Delivered: False, Path: [], Total Latency: None
#   Packet 9: Source: 4, Target: 0, Size: 18, Delivered: True, Path: [4, 3, 0], Total Latency: 56
# C:\Users\Solomon\AppData\Local\Temp\ipykernel_4892\3893650115.py:182: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with self.driver.session() as session:

# %% [markdown]
# Adding The Attack Node.

# %%
#Add Attack Node
# Initialize the simulation object and create the initial UAV network
simulation = UAVNetworkSimulation(URI, AUTH)
uav_network = simulation.update_network_connections(uav_network, connection_range, backbone_range)

# # Upload the initial UAV network to Neo4j
simulation.upload_to_neo4j(uav_network)

# Target UAV ID for the DDoS attack
target_uav_ids = [5, 7] # Example: Target UAV ID that you want to attack

# Add the attack node and connect it to the target UAV
attack_node_id = simulation.add_attack_node(uav_network, target_uav_ids, num_uavs)
simulation.upload_attack_node_to_neo4j(uav_network, attack_node_id, target_uav_ids)

# Optionally, visualize the updated network to confirm the addition and connection of the attack node
simulation.draw_graph(uav_network)

# Close the Neo4j connection at the end of the session
simulation.close()

# %%
"""DDoS Simulation"""
# Initialize your network G here
target_nodes = [5, 7]  # Target node IDs that will be affected by the DDoS attack
# Assuming you have an attack node and some target nodes
attack_node_id = simulation.add_attack_node(uav_network, target_nodes, num_uavs)  # ID of your attack node

total_time = 120  # For example, run the simulation for 120 seconds
update_interval = 5
move_range = 10
connection_range = 30
backbone_range = 50
num_packets = 10
target_ids = [5, 7]  # Targeting nodes 5 and 7 for the DDoS attack

# Run the DDoS simulation
simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)
# Out:
# Iteration 0:
# Packet 0: Source: 6, Target: 0, Size: 9, Delivered: True, Path: [6, 0], Total Latency: 88
# Packet 1: Source: 2, Target: 7, Size: 32, Delivered: True, Path: [2, 7], Total Latency: 70
# Packet 2: Source: 4, Target: 1, Size: 8, Delivered: True, Path: [4, 8, 11, 1], Total Latency: 120
# Packet 3: Source: 2, Target: 1, Size: 10, Delivered: True, Path: [2, 1], Total Latency: 94
# Packet 4: Source: 3, Target: 2, Size: 40, Delivered: True, Path: [3, 4, 8, 11, 2], Total Latency: 178
# Packet 5: Source: 10, Target: 4, Size: 49, Delivered: True, Path: [10, 11, 8, 4], Total Latency: 95
# Packet 6: Source: 8, Target: 3, Size: 1, Delivered: True, Path: [8, 4, 3], Total Latency: 98
# Packet 7: Source: 4, Target: 1, Size: 51, Delivered: True, Path: [4, 8, 11, 1], Total Latency: 120
# Packet 8: Source: 5, Target: 5, Size: 58, Delivered: True, Path: [5], Total Latency: 66
# Packet 9: Source: 5, Target: 5, Size: 91, Delivered: True, Path: [5], Total Latency: 66
# Iteration 1:
# Packet 0: Source: 2, Target: 4, Size: 13, Delivered: True, Path: [2, 11, 6, 3, 4], Total Latency: 227825
# Packet 1: Source: 9, Target: 2, Size: 39, Delivered: True, Path: [9, 7, 2], Total Latency: 10142
# Packet 2: Source: 1, Target: 7, Size: 39, Delivered: True, Path: [1, 2, 7], Total Latency: 7669
# Packet 3: Source: 10, Target: 3, Size: 51, Delivered: True, Path: [10, 11, 6, 3], Total Latency: 221789
# Packet 4: Source: 10, Target: 4, Size: 55, Delivered: True, Path: [10, 11, 6, 3, 4], Total Latency: 221819
# Packet 5: Source: 9, Target: 0, Size: 55, Delivered: True, Path: [9, 11, 6, 0], Total Latency: 224285
# Packet 6: Source: 8, Target: 5, Size: 24, Delivered: True, Path: [8, 11, 5], Total Latency: 227846
# Packet 7: Source: 4, Target: 7, Size: 73, Delivered: True, Path: [4, 3, 6, 11, 7], Total Latency: 223409
# Packet 8: Source: 2, Target: 3, Size: 42, Delivered: True, Path: [2, 11, 6, 3], Total Latency: 227795
# Packet 9: Source: 7, Target: 8, Size: 7, Delivered: True, Path: [7, 11, 8], Total Latency: 223324
# Iteration 2:
# Packet 0: Source: 8, Target: 1, Size: 28, Delivered: True, Path: [8, 11, 1], Total Latency: 221748
# Packet 1: Source: 7, Target: 9, Size: 5, Delivered: True, Path: [7, 11, 9], Total Latency: 225800
# Packet 2: Source: 7, Target: 5, Size: 2, Delivered: True, Path: [7, 12, 5], Total Latency: 68179
# Packet 3: Source: 3, Target: 2, Size: 55, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 6, Target: 1, Size: 11, Delivered: True, Path: [6, 11, 1], Total Latency: 221773
# Packet 5: Source: 2, Target: 5, Size: 27, Delivered: True, Path: [2, 11, 5], Total Latency: 233827
# Packet 6: Source: 2, Target: 10, Size: 43, Delivered: True, Path: [2, 11, 10], Total Latency: 227723
# Packet 7: Source: 8, Target: 9, Size: 32, Delivered: True, Path: [8, 0, 9], Total Latency: 2577
# Packet 8: Source: 8, Target: 10, Size: 8, Delivered: True, Path: [8, 11, 10], Total Latency: 221735
# Packet 9: Source: 5, Target: 10, Size: 61, Delivered: True, Path: [5, 11, 10], Total Latency: 227828
# Iteration 3:
# Packet 0: Source: 0, Target: 4, Size: 80, Delivered: True, Path: [0, 8, 6, 4], Total Latency: 153
# Packet 1: Source: 3, Target: 7, Size: 30, Delivered: True, Path: [3, 4, 7], Total Latency: 1679
# Packet 2: Source: 2, Target: 7, Size: 40, Delivered: True, Path: [2, 7], Total Latency: 7633
# Packet 3: Source: 3, Target: 9, Size: 36, Delivered: True, Path: [3, 4, 6, 9], Total Latency: 2624
# Packet 4: Source: 3, Target: 3, Size: 31, Delivered: True, Path: [3], Total Latency: 33
# Packet 5: Source: 5, Target: 1, Size: 18, Delivered: True, Path: [5, 12, 7, 1], Total Latency: 68229
# Packet 6: Source: 1, Target: 8, Size: 1, Delivered: True, Path: [1, 11, 8], Total Latency: 221757
# Packet 7: Source: 10, Target: 7, Size: 12, Delivered: True, Path: [10, 11, 7], Total Latency: 223329
# Packet 8: Source: 10, Target: 10, Size: 14, Delivered: True, Path: [10], Total Latency: 26
# Packet 9: Source: 6, Target: 10, Size: 19, Delivered: True, Path: [6, 11, 10], Total Latency: 221765
# Iteration 4:
# Packet 0: Source: 0, Target: 4, Size: 10, Delivered: True, Path: [0, 11, 2, 4], Total Latency: 227778
# Packet 1: Source: 6, Target: 3, Size: 43, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 3, Target: 1, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 1, Target: 1, Size: 67, Delivered: True, Path: [1], Total Latency: 33
# Packet 4: Source: 10, Target: 10, Size: 33, Delivered: True, Path: [10], Total Latency: 23
# Packet 5: Source: 10, Target: 7, Size: 29, Delivered: True, Path: [10, 11, 7], Total Latency: 223321
# Packet 6: Source: 7, Target: 3, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 3, Target: 6, Size: 63, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 5, Target: 5, Size: 31, Delivered: True, Path: [5], Total Latency: 6131
# Packet 9: Source: 1, Target: 1, Size: 86, Delivered: True, Path: [1], Total Latency: 33
# Iteration 5:
# Packet 0: Source: 3, Target: 10, Size: 19, Delivered: True, Path: [3, 6, 11, 10], Total Latency: 221804
# Packet 1: Source: 0, Target: 4, Size: 56, Delivered: True, Path: [0, 11, 2, 4], Total Latency: 227773
# Packet 2: Source: 5, Target: 8, Size: 10, Delivered: True, Path: [5, 12, 7, 6, 8], Total Latency: 68281
# Packet 3: Source: 9, Target: 8, Size: 26, Delivered: True, Path: [9, 8], Total Latency: 2533
# Packet 4: Source: 8, Target: 8, Size: 35, Delivered: True, Path: [8], Total Latency: 22
# Packet 5: Source: 2, Target: 4, Size: 5, Delivered: True, Path: [2, 4], Total Latency: 6052
# Packet 6: Source: 9, Target: 1, Size: 50, Delivered: True, Path: [9, 11, 1], Total Latency: 224226
# Packet 7: Source: 2, Target: 0, Size: 25, Delivered: True, Path: [2, 11, 0], Total Latency: 227742
# Packet 8: Source: 3, Target: 2, Size: 52, Delivered: True, Path: [3, 4, 2], Total Latency: 6089
# Packet 9: Source: 2, Target: 4, Size: 12, Delivered: True, Path: [2, 4], Total Latency: 6052
# Iteration 6:
# Packet 0: Source: 0, Target: 7, Size: 43, Delivered: True, Path: [0, 11, 7], Total Latency: 223326
# Packet 1: Source: 1, Target: 2, Size: 60, Delivered: True, Path: [1, 2], Total Latency: 6050
# Packet 2: Source: 3, Target: 7, Size: 38, Delivered: True, Path: [3, 7], Total Latency: 1647
# Packet 3: Source: 6, Target: 6, Size: 15, Delivered: True, Path: [6], Total Latency: 64
# Packet 4: Source: 8, Target: 3, Size: 19, Delivered: True, Path: [8, 3], Total Latency: 57
# Packet 5: Source: 3, Target: 1, Size: 2, Delivered: True, Path: [3, 6, 1], Total Latency: 132
# Packet 6: Source: 8, Target: 2, Size: 28, Delivered: True, Path: [8, 3, 7, 2], Total Latency: 7686
# Packet 7: Source: 3, Target: 8, Size: 48, Delivered: True, Path: [3, 8], Total Latency: 57
# Packet 8: Source: 2, Target: 9, Size: 19, Delivered: True, Path: [2, 11, 9], Total Latency: 230207
# Packet 9: Source: 7, Target: 3, Size: 2, Delivered: True, Path: [7, 3], Total Latency: 1647
# Iteration 7:
# Packet 0: Source: 9, Target: 10, Size: 30, Delivered: True, Path: [9, 11, 10], Total Latency: 224219
# Packet 1: Source: 5, Target: 5, Size: 54, Delivered: True, Path: [5], Total Latency: 6128
# Packet 2: Source: 8, Target: 0, Size: 47, Delivered: True, Path: [8, 0], Total Latency: 51
# Packet 3: Source: 3, Target: 2, Size: 31, Delivered: True, Path: [3, 6, 2], Total Latency: 6115
# Packet 4: Source: 4, Target: 8, Size: 54, Delivered: True, Path: [4, 11, 0, 8], Total Latency: 221768
# Packet 5: Source: 3, Target: 4, Size: 44, Delivered: True, Path: [3, 4], Total Latency: 67
# Packet 6: Source: 6, Target: 2, Size: 53, Delivered: True, Path: [6, 2], Total Latency: 6081
# Packet 7: Source: 10, Target: 8, Size: 56, Delivered: True, Path: [10, 11, 0, 8], Total Latency: 221760
# Packet 8: Source: 2, Target: 9, Size: 12, Delivered: True, Path: [2, 6, 9], Total Latency: 8591
# Packet 9: Source: 2, Target: 6, Size: 13, Delivered: True, Path: [2, 6], Total Latency: 6081
# Iteration 8:
# Packet 0: Source: 9, Target: 3, Size: 12, Delivered: True, Path: [9, 6, 4, 3], Total Latency: 2649
# Packet 1: Source: 10, Target: 2, Size: 65, Delivered: True, Path: [10, 11, 2], Total Latency: 227726
# Packet 2: Source: 8, Target: 1, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 10, Target: 1, Size: 48, Delivered: True, Path: [10, 11, 1], Total Latency: 221753
# Packet 4: Source: 2, Target: 3, Size: 16, Delivered: True, Path: [2, 1, 4, 3], Total Latency: 6121
# Packet 5: Source: 3, Target: 6, Size: 13, Delivered: True, Path: [3, 4, 6], Total Latency: 137
# Packet 6: Source: 10, Target: 1, Size: 38, Delivered: True, Path: [10, 11, 1], Total Latency: 221753
# Packet 7: Source: 3, Target: 2, Size: 18, Delivered: True, Path: [3, 4, 1, 2], Total Latency: 6121
# Packet 8: Source: 8, Target: 10, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 0, Target: 2, Size: 72, Delivered: True, Path: [0, 11, 2], Total Latency: 227738
# Iteration 9:
# Packet 0: Source: 4, Target: 6, Size: 82, Delivered: True, Path: [4, 6], Total Latency: 101
# Packet 1: Source: 3, Target: 0, Size: 4, Delivered: True, Path: [3, 4, 11, 0], Total Latency: 221804
# Packet 2: Source: 1, Target: 7, Size: 54, Delivered: True, Path: [1, 2, 11, 7], Total Latency: 229352
# Packet 3: Source: 0, Target: 9, Size: 19, Delivered: True, Path: [0, 9], Total Latency: 2550
# Packet 4: Source: 2, Target: 3, Size: 19, Delivered: True, Path: [2, 4, 3], Total Latency: 6087
# Packet 5: Source: 9, Target: 0, Size: 19, Delivered: True, Path: [9, 0], Total Latency: 2550
# Packet 6: Source: 1, Target: 7, Size: 85, Delivered: True, Path: [1, 2, 11, 7], Total Latency: 229352
# Packet 7: Source: 1, Target: 9, Size: 33, Delivered: True, Path: [1, 2, 11, 9], Total Latency: 230247
# Packet 8: Source: 7, Target: 9, Size: 9, Delivered: True, Path: [7, 9], Total Latency: 4119
# Packet 9: Source: 8, Target: 3, Size: 49, Delivered: False, Path: [], Total Latency: None
# Iteration 10:
# Packet 0: Source: 8, Target: 5, Size: 33, Delivered: True, Path: [8, 9, 11, 5], Total Latency: 230346
# Packet 1: Source: 0, Target: 5, Size: 66, Delivered: True, Path: [0, 11, 5], Total Latency: 227860
# Packet 2: Source: 3, Target: 6, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 3, Target: 7, Size: 23, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 10, Target: 7, Size: 14, Delivered: True, Path: [10, 11, 7], Total Latency: 223321
# Packet 5: Source: 0, Target: 8, Size: 65, Delivered: True, Path: [0, 9, 8], Total Latency: 2570
# Packet 6: Source: 2, Target: 5, Size: 24, Delivered: True, Path: [2, 11, 5], Total Latency: 233829
# Packet 7: Source: 4, Target: 6, Size: 76, Delivered: True, Path: [4, 6], Total Latency: 104
# Packet 8: Source: 5, Target: 10, Size: 5, Delivered: True, Path: [5, 11, 10], Total Latency: 227842
# Packet 9: Source: 9, Target: 1, Size: 19, Delivered: True, Path: [9, 11, 1], Total Latency: 224235
# Iteration 11:
# Packet 0: Source: 0, Target: 10, Size: 24, Delivered: True, Path: [0, 11, 10], Total Latency: 221743
# Packet 1: Source: 3, Target: 1, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 5, Target: 8, Size: 23, Delivered: True, Path: [5, 11, 9, 8], Total Latency: 230342
# Packet 3: Source: 4, Target: 1, Size: 40, Delivered: True, Path: [4, 1], Total Latency: 83
# Packet 4: Source: 7, Target: 4, Size: 1, Delivered: True, Path: [7, 2, 4], Total Latency: 7657
# Packet 5: Source: 9, Target: 10, Size: 8, Delivered: True, Path: [9, 11, 10], Total Latency: 224216
# Packet 6: Source: 2, Target: 6, Size: 49, Delivered: True, Path: [2, 6], Total Latency: 6081
# Packet 7: Source: 7, Target: 9, Size: 3, Delivered: True, Path: [7, 0, 9], Total Latency: 4160
# Packet 8: Source: 8, Target: 10, Size: 50, Delivered: True, Path: [8, 9, 11, 10], Total Latency: 224238
# Packet 9: Source: 7, Target: 2, Size: 1, Delivered: True, Path: [7, 2], Total Latency: 7620
# Iteration 12:
# Packet 0: Source: 6, Target: 8, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 4, Target: 10, Size: 81, Delivered: True, Path: [4, 11, 10], Total Latency: 221747
# Packet 2: Source: 10, Target: 4, Size: 41, Delivered: True, Path: [10, 11, 4], Total Latency: 221747
# Packet 3: Source: 5, Target: 4, Size: 30, Delivered: True, Path: [5, 11, 4], Total Latency: 227850
# Packet 4: Source: 3, Target: 8, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 1, Target: 1, Size: 3, Delivered: True, Path: [1], Total Latency: 42
# Packet 6: Source: 9, Target: 3, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 10, Target: 4, Size: 4, Delivered: True, Path: [10, 11, 4], Total Latency: 221747
# Packet 8: Source: 9, Target: 6, Size: 9, Delivered: True, Path: [9, 11, 6], Total Latency: 224265
# Packet 9: Source: 0, Target: 2, Size: 74, Delivered: True, Path: [0, 7, 2], Total Latency: 7659
# Iteration 13:
# Packet 0: Source: 6, Target: 5, Size: 42, Delivered: True, Path: [6, 11, 5], Total Latency: 227876
# Packet 1: Source: 9, Target: 3, Size: 31, Delivered: True, Path: [9, 3], Total Latency: 2548
# Packet 2: Source: 6, Target: 1, Size: 52, Delivered: True, Path: [6, 1], Total Latency: 107
# Packet 3: Source: 3, Target: 8, Size: 7, Delivered: True, Path: [3, 8], Total Latency: 68
# Packet 4: Source: 6, Target: 4, Size: 47, Delivered: True, Path: [6, 4], Total Latency: 107
# Packet 5: Source: 4, Target: 7, Size: 1, Delivered: True, Path: [4, 11, 7], Total Latency: 223327
# Packet 6: Source: 6, Target: 4, Size: 14, Delivered: True, Path: [6, 4], Total Latency: 107
# Packet 7: Source: 9, Target: 2, Size: 10, Delivered: True, Path: [9, 11, 2], Total Latency: 230202
# Packet 8: Source: 6, Target: 1, Size: 23, Delivered: True, Path: [6, 1], Total Latency: 107
# Packet 9: Source: 4, Target: 2, Size: 67, Delivered: True, Path: [4, 2], Total Latency: 6051
# Iteration 14:
# Packet 0: Source: 4, Target: 10, Size: 40, Delivered: True, Path: [4, 11, 10], Total Latency: 221758
# Packet 1: Source: 8, Target: 0, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 9, Target: 5, Size: 13, Delivered: True, Path: [9, 11, 5], Total Latency: 230315
# Packet 3: Source: 8, Target: 7, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 7, Target: 1, Size: 2, Delivered: True, Path: [7, 4, 6, 1], Total Latency: 1764
# Packet 5: Source: 8, Target: 6, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 0, Target: 0, Size: 7, Delivered: True, Path: [0], Total Latency: 41
# Packet 7: Source: 8, Target: 10, Size: 10, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 6, Target: 3, Size: 59, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 5, Target: 2, Size: 3, Delivered: True, Path: [5, 11, 2], Total Latency: 233821
# Iteration 15:
# Packet 0: Source: 4, Target: 2, Size: 9, Delivered: True, Path: [4, 2], Total Latency: 6047
# Packet 1: Source: 7, Target: 9, Size: 1, Delivered: True, Path: [7, 9], Total Latency: 4098
# Packet 2: Source: 6, Target: 9, Size: 36, Delivered: True, Path: [6, 7, 9], Total Latency: 4166
# Packet 3: Source: 0, Target: 9, Size: 66, Delivered: True, Path: [0, 11, 9], Total Latency: 224231
# Packet 4: Source: 9, Target: 8, Size: 73, Delivered: True, Path: [9, 8], Total Latency: 2527
# Packet 5: Source: 7, Target: 5, Size: 1, Delivered: True, Path: [7, 12, 5], Total Latency: 68182
# Packet 6: Source: 6, Target: 6, Size: 1, Delivered: True, Path: [6], Total Latency: 68
# Packet 7: Source: 7, Target: 5, Size: 1, Delivered: True, Path: [7, 12, 5], Total Latency: 68182
# Packet 8: Source: 4, Target: 7, Size: 17, Delivered: True, Path: [4, 7], Total Latency: 1646
# Packet 9: Source: 10, Target: 8, Size: 31, Delivered: True, Path: [10, 11, 9, 8], Total Latency: 224250
# Iteration 16:
# Packet 0: Source: 4, Target: 2, Size: 47, Delivered: True, Path: [4, 2], Total Latency: 6048
# Packet 1: Source: 6, Target: 9, Size: 12, Delivered: True, Path: [6, 7, 9], Total Latency: 4156
# Packet 2: Source: 3, Target: 7, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 10, Target: 10, Size: 37, Delivered: True, Path: [10], Total Latency: 33
# Packet 4: Source: 6, Target: 4, Size: 30, Delivered: True, Path: [6, 4], Total Latency: 110
# Packet 5: Source: 3, Target: 5, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 1, Target: 8, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 5, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 7, Target: 5, Size: 2, Delivered: True, Path: [7, 12, 5], Total Latency: 68179
# Packet 9: Source: 5, Target: 4, Size: 24, Delivered: True, Path: [5, 12, 7, 2, 4], Total Latency: 74227
# Iteration 17:
# Packet 0: Source: 6, Target: 0, Size: 49, Delivered: True, Path: [6, 11, 0], Total Latency: 221802
# Packet 1: Source: 4, Target: 8, Size: 53, Delivered: True, Path: [4, 11, 7, 9, 8], Total Latency: 225870
# Packet 2: Source: 1, Target: 4, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 2, Size: 1, Delivered: True, Path: [7, 11, 2], Total Latency: 229295
# Packet 4: Source: 10, Target: 1, Size: 66, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 10, Target: 5, Size: 46, Delivered: True, Path: [10, 11, 7, 12, 5], Total Latency: 289916
# Packet 6: Source: 1, Target: 5, Size: 28, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 9, Target: 4, Size: 91, Delivered: True, Path: [9, 7, 11, 4], Total Latency: 225836
# Packet 8: Source: 7, Target: 10, Size: 4, Delivered: True, Path: [7, 11, 10], Total Latency: 223330
# Packet 9: Source: 5, Target: 10, Size: 8, Delivered: True, Path: [5, 12, 7, 11, 10], Total Latency: 289916
# Iteration 18:
# Packet 0: Source: 1, Target: 2, Size: 56, Delivered: True, Path: [1, 2], Total Latency: 6044
# Packet 1: Source: 1, Target: 2, Size: 32, Delivered: True, Path: [1, 2], Total Latency: 6044
# Packet 2: Source: 8, Target: 3, Size: 5, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 9, Target: 8, Size: 89, Delivered: True, Path: [9, 8], Total Latency: 2529
# Packet 4: Source: 4, Target: 0, Size: 83, Delivered: True, Path: [4, 2, 11, 0], Total Latency: 227785
# Packet 5: Source: 10, Target: 9, Size: 11, Delivered: True, Path: [10, 11, 7, 9], Total Latency: 225829
# Packet 6: Source: 10, Target: 9, Size: 1, Delivered: True, Path: [10, 11, 7, 9], Total Latency: 225829
# Packet 7: Source: 4, Target: 0, Size: 15, Delivered: True, Path: [4, 2, 11, 0], Total Latency: 227785
# Packet 8: Source: 3, Target: 4, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 3, Target: 5, Size: 11, Delivered: False, Path: [], Total Latency: None
# Iteration 19:
# Packet 0: Source: 0, Target: 7, Size: 47, Delivered: True, Path: [0, 11, 7], Total Latency: 223335
# Packet 1: Source: 10, Target: 2, Size: 36, Delivered: True, Path: [10, 11, 2], Total Latency: 227740
# Packet 2: Source: 3, Target: 6, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 9, Target: 9, Size: 20, Delivered: True, Path: [9], Total Latency: 2498
# Packet 4: Source: 5, Target: 8, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 5, Target: 9, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 7, Target: 0, Size: 1, Delivered: True, Path: [7, 11, 0], Total Latency: 223335
# Packet 7: Source: 9, Target: 9, Size: 89, Delivered: True, Path: [9], Total Latency: 2498
# Packet 8: Source: 8, Target: 3, Size: 17, Delivered: True, Path: [8, 3], Total Latency: 78
# Packet 9: Source: 4, Target: 1, Size: 10, Delivered: True, Path: [4, 1], Total Latency: 86
# Iteration 20:
# Packet 0: Source: 8, Target: 6, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 6, Target: 1, Size: 29, Delivered: True, Path: [6, 4, 1], Total Latency: 149
# Packet 2: Source: 4, Target: 1, Size: 15, Delivered: True, Path: [4, 1], Total Latency: 79
# Packet 3: Source: 4, Target: 1, Size: 21, Delivered: True, Path: [4, 1], Total Latency: 79
# Packet 4: Source: 9, Target: 10, Size: 25, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 6, Target: 5, Size: 17, Delivered: True, Path: [6, 7, 12, 5], Total Latency: 68251
# Packet 6: Source: 0, Target: 9, Size: 101, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 6, Target: 8, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 4, Target: 9, Size: 73, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 7, Target: 1, Size: 1, Delivered: True, Path: [7, 4, 1], Total Latency: 1679
# Iteration 21:
# Packet 0: Source: 5, Target: 1, Size: 6, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 0, Size: 1, Delivered: True, Path: [7, 11, 0], Total Latency: 223352
# Packet 2: Source: 10, Target: 6, Size: 46, Delivered: True, Path: [10, 11, 6], Total Latency: 221800
# Packet 3: Source: 9, Target: 5, Size: 63, Delivered: True, Path: [9, 3, 7, 12, 5], Total Latency: 70747
# Packet 4: Source: 10, Target: 6, Size: 47, Delivered: True, Path: [10, 11, 6], Total Latency: 221800
# Packet 5: Source: 4, Target: 1, Size: 67, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 7, Target: 3, Size: 1, Delivered: True, Path: [7, 3], Total Latency: 1661
# Packet 7: Source: 1, Target: 1, Size: 28, Delivered: True, Path: [1], Total Latency: 37
# Packet 8: Source: 2, Target: 3, Size: 43, Delivered: True, Path: [2, 7, 3], Total Latency: 7672
# Packet 9: Source: 7, Target: 5, Size: 1, Delivered: True, Path: [7, 12, 5], Total Latency: 68189
# Iteration 22:
# Packet 0: Source: 8, Target: 3, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 8, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 9, Target: 5, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 6, Size: 2, Delivered: True, Path: [7, 6], Total Latency: 1670
# Packet 4: Source: 3, Target: 6, Size: 5, Delivered: True, Path: [3, 6], Total Latency: 118
# Packet 5: Source: 10, Target: 4, Size: 23, Delivered: True, Path: [10, 11, 4], Total Latency: 221766
# Packet 6: Source: 1, Target: 1, Size: 43, Delivered: True, Path: [1], Total Latency: 32
# Packet 7: Source: 7, Target: 9, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 2, Target: 9, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 5, Target: 0, Size: 19, Delivered: True, Path: [5, 11, 0], Total Latency: 227870
# Iteration 23:
# Packet 0: Source: 10, Target: 5, Size: 24, Delivered: True, Path: [10, 11, 5], Total Latency: 227863
# Packet 1: Source: 9, Target: 1, Size: 94, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 9, Target: 4, Size: 45, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 6, Size: 40, Delivered: True, Path: [0, 11, 4, 6], Total Latency: 221837
# Packet 4: Source: 7, Target: 5, Size: 2, Delivered: True, Path: [7, 12, 5], Total Latency: 68186
# Packet 5: Source: 5, Target: 7, Size: 7, Delivered: True, Path: [5, 12, 7], Total Latency: 68186
# Packet 6: Source: 4, Target: 9, Size: 3, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 5, Target: 5, Size: 22, Delivered: True, Path: [5], Total Latency: 6133
# Packet 8: Source: 9, Target: 9, Size: 77, Delivered: True, Path: [9], Total Latency: 2494
# Packet 9: Source: 2, Target: 4, Size: 27, Delivered: False, Path: [], Total Latency: None
# Metrics saved to simulation_results/ddos_simulation_20240422_232613.csv
# [(0, 0.002004861831665039, 35, 98, 100),
#  (1, 0.002004861831665039, 38, 83, 100),
#  (2, 0.002004861831665039, 56, 67, 100),
#  (3, 0.002004861831665039, 40, 56, 100),
#  (4, 0.002004861831665039, 25, 88, 100),
#  (5, 0.002004861831665039, 66, 131, 100),
#  (6, 0.002004861831665039, 53, 25, 100),
#  (7, 0.002004861831665039, 14, 29, 100),
#  (8, 0.002004861831665039, 33, 44, 100),
#  (9, 0.002004861831665039, 27, 107, 100),
#  (10, 0.002004861831665039, 13, 57, 100),
#  (11, 0.002004861831665039, 24, 38, 100),
#  (12, 0.002004861831665039, 1, 1007, 100),
#  (0, 5.0158607959747314, 39, 92, 100),
#  (1, 5.0158607959747314, 37, 93, 100),
#  (2, 5.0158607959747314, 6024, 42, 60),
#  (3, 5.0158607959747314, 35, 60, 100),
#  (4, 5.0158607959747314, 30, 87, 100),
#  (5, 5.0158607959747314, 6130, 68, 50),
#  (6, 5.0158607959747314, 53, 30, 100),
#  (7, 5.0158607959747314, 1608, 15, 50),
#  (8, 5.0158607959747314, 33, 38, 100),
#  (9, 5.0158607959747314, 2510, 70, 60),
#  (10, 5.0158607959747314, 18, 55, 100),
#  (11, 5.0158607959747314, 221683, 12, 36),
#  (12, 5.0158607959747314, 60440, 360, 36),
#  (0, 10.031179904937744, 39, 97, 100),
#  (1, 10.031179904937744, 34, 92, 100),
#  (2, 10.031179904937744, 6020, 43, 60),
#  (3, 10.031179904937744, 31, 58, 100),
#  (4, 10.031179904937744, 32, 93, 100),
#  (5, 10.031179904937744, 6125, 70, 50),
#  (6, 10.031179904937744, 57, 40, 100),
#  (7, 10.031179904937744, 1612, 6, 50),
#  (8, 10.031179904937744, 32, 47, 100),
#  (9, 10.031179904937744, 2506, 61, 60),
#  (10, 10.031179904937744, 21, 62, 100),
#  (11, 10.031179904937744, 221682, 3, 36),
#  (12, 10.031179904937744, 60442, 365, 36),
#  (0, 15.046132802963257, 39, 93, 100),
#  (1, 15.046132802963257, 38, 96, 100),
#  (2, 15.046132802963257, 6017, 43, 60),
#  (3, 15.046132802963257, 33, 68, 100),
#  (4, 15.046132802963257, 30, 98, 100),
#  (5, 15.046132802963257, 6129, 63, 50),
#  (6, 15.046132802963257, 52, 48, 100),
#  (7, 15.046132802963257, 1616, 5, 50),
#  (8, 15.046132802963257, 32, 55, 100),
#  (9, 15.046132802963257, 2509, 58, 60),
#  (10, 15.046132802963257, 26, 57, 100),
#  (11, 15.046132802963257, 221687, 1, 36),
#  (12, 15.046132802963257, 60446, 355, 36),
#  (0, 20.058852910995483, 39, 92, 100),
#  (1, 20.058852910995483, 33, 98, 100),
#  (2, 20.058852910995483, 6022, 48, 60),
#  (3, 20.058852910995483, 34, 73, 100),
#  (4, 20.058852910995483, 35, 93, 100),
#  (5, 20.058852910995483, 6131, 65, 50),
#  (6, 20.058852910995483, 55, 45, 100),
#  (7, 20.058852910995483, 1616, 1, 50),
#  (8, 20.058852910995483, 27, 48, 100),
#  (9, 20.058852910995483, 2513, 62, 60),
#  (10, 20.058852910995483, 23, 62, 100),
#  (11, 20.058852910995483, 221682, 1, 36),
#  (12, 20.058852910995483, 60447, 359, 36),
#  (0, 25.064667463302612, 36, 87, 100),
#  (1, 25.064667463302612, 30, 104, 100),
#  (2, 25.064667463302612, 6021, 44, 60),
#  (3, 25.064667463302612, 37, 68, 100),
#  (4, 25.064667463302612, 31, 86, 100),
#  (5, 25.064667463302612, 6133, 65, 50),
#  (6, 25.064667463302612, 60, 38, 100),
#  (7, 25.064667463302612, 1616, 9, 50),
#  (8, 25.064667463302612, 22, 46, 100),
#  (9, 25.064667463302612, 2511, 68, 60),
#  (10, 25.064667463302612, 22, 71, 100),
#  (11, 25.064667463302612, 221685, 4, 36),
#  (12, 25.064667463302612, 60450, 356, 36),
#  (0, 30.076656341552734, 33, 81, 100),
#  (1, 30.076656341552734, 33, 103, 100),
#  (2, 30.076656341552734, 6017, 35, 60),
#  (3, 30.076656341552734, 35, 60, 100),
#  (4, 30.076656341552734, 32, 96, 100),
#  (5, 30.076656341552734, 6129, 67, 50),
#  (6, 30.076656341552734, 64, 48, 100),
#  (7, 30.076656341552734, 1612, 19, 50),
#  (8, 30.076656341552734, 22, 41, 100),
#  (9, 30.076656341552734, 2509, 59, 60),
#  (10, 30.076656341552734, 25, 64, 100),
#  (11, 30.076656341552734, 221681, 2, 36),
#  (12, 30.076656341552734, 60453, 365, 36),
#  (0, 35.09227967262268, 34, 71, 100),
#  (1, 35.09227967262268, 36, 96, 100),
#  (2, 35.09227967262268, 6015, 35, 60),
#  (3, 35.09227967262268, 34, 57, 100),
#  (4, 35.09227967262268, 33, 96, 100),
#  (5, 35.09227967262268, 6128, 68, 50),
#  (6, 35.09227967262268, 66, 56, 100),
#  (7, 35.09227967262268, 1611, 10, 50),
#  (8, 35.09227967262268, 17, 50, 100),
#  (9, 35.09227967262268, 2510, 66, 60),
#  (10, 35.09227967262268, 25, 57, 100),
#  (11, 35.09227967262268, 221684, 1, 36),
#  (12, 35.09227967262268, 60457, 374, 36),
#  (0, 40.105851888656616, 39, 78, 100),
#  (1, 40.105851888656616, 37, 93, 100),
#  (2, 40.105851888656616, 6010, 34, 60),
#  (3, 40.105851888656616, 36, 49, 100),
#  (4, 40.105851888656616, 38, 102, 100),
#  (5, 40.105851888656616, 6130, 60, 50),
#  (6, 40.105851888656616, 63, 64, 100),
#  (7, 40.105851888656616, 1612, 12, 50),
#  (8, 40.105851888656616, 18, 46, 100),
#  (9, 40.105851888656616, 2512, 69, 60),
#  (10, 40.105851888656616, 27, 65, 100),
#  (11, 40.105851888656616, 221689, 10, 36),
#  (12, 40.105851888656616, 60461, 380, 36),
#  (0, 45.11727023124695, 43, 82, 100),
#  (1, 45.11727023124695, 40, 96, 100),
#  (2, 45.11727023124695, 6013, 42, 60),
#  (3, 45.11727023124695, 37, 40, 100),
#  (4, 45.11727023124695, 37, 98, 100),
#  (5, 45.11727023124695, 6132, 54, 50),
#  (6, 45.11727023124695, 64, 61, 100),
#  (7, 45.11727023124695, 1612, 9, 50),
#  (8, 45.11727023124695, 18, 55, 100),
#  (9, 45.11727023124695, 2507, 71, 60),
#  (10, 45.11727023124695, 28, 59, 100),
#  (11, 45.11727023124695, 221687, 16, 36),
#  (12, 45.11727023124695, 60465, 388, 36),
#  (0, 50.13472557067871, 42, 79, 100),
#  (1, 50.13472557067871, 41, 87, 100),
#  (2, 50.13472557067871, 6011, 41, 60),
#  (3, 50.13472557067871, 39, 32, 100),
#  (4, 50.13472557067871, 37, 93, 100),
#  (5, 50.13472557067871, 6130, 48, 50),
#  (6, 50.13472557067871, 67, 61, 100),
#  (7, 50.13472557067871, 1609, 8, 50),
#  (8, 50.13472557067871, 22, 51, 100),
#  (9, 50.13472557067871, 2506, 73, 60),
#  (10, 50.13472557067871, 24, 55, 100),
#  (11, 50.13472557067871, 221688, 22, 36),
#  (12, 50.13472557067871, 60462, 386, 36),
#  (0, 55.14101433753967, 38, 85, 100),
#  (1, 55.14101433753967, 46, 89, 100),
#  (2, 55.14101433753967, 6009, 51, 60),
#  (3, 55.14101433753967, 44, 24, 100),
#  (4, 55.14101433753967, 37, 89, 100),
#  (5, 55.14101433753967, 6126, 44, 50),
#  (6, 55.14101433753967, 72, 61, 100),
#  (7, 55.14101433753967, 1611, 3, 50),
#  (8, 55.14101433753967, 22, 52, 100),
#  (9, 55.14101433753967, 2511, 83, 60),
#  (10, 55.14101433753967, 22, 58, 100),
#  (11, 55.14101433753967, 221683, 16, 36),
#  (12, 55.14101433753967, 60457, 391, 36),
#  (0, 60.160146713256836, 39, 84, 100),
#  (1, 60.160146713256836, 42, 86, 100),
#  (2, 60.160146713256836, 6014, 54, 60),
#  (3, 60.160146713256836, 45, 26, 100),
#  (4, 60.160146713256836, 36, 87, 100),
#  (5, 60.160146713256836, 6126, 36, 50),
#  (6, 60.160146713256836, 71, 62, 100),
#  (7, 60.160146713256836, 1606, 1, 50),
#  (8, 60.160146713256836, 21, 48, 100),
#  (9, 60.160146713256836, 2506, 76, 60),
#  (10, 60.160146713256836, 23, 59, 100),
#  (11, 60.160146713256836, 221688, 15, 36),
#  (12, 60.160146713256836, 60456, 381, 36),
#  (0, 65.16783142089844, 38, 92, 100),
#  (1, 65.16783142089844, 39, 87, 100),
#  (2, 65.16783142089844, 6012, 57, 60),
#  (3, 65.16783142089844, 44, 32, 100),
#  (4, 65.16783142089844, 39, 84, 100),
#  (5, 65.16783142089844, 6122, 38, 50),
#  (6, 65.16783142089844, 68, 54, 100),
#  (7, 65.16783142089844, 1602, 6, 50),
#  (8, 65.16783142089844, 24, 55, 100),
#  (9, 65.16783142089844, 2504, 78, 60),
#  (10, 65.16783142089844, 25, 50, 100),
#  (11, 65.16783142089844, 221686, 8, 36),
#  (12, 65.16783142089844, 60461, 385, 36),
#  (0, 70.17729473114014, 41, 102, 100),
#  (1, 70.17729473114014, 44, 96, 100),
#  (2, 70.17729473114014, 6007, 59, 60),
#  (3, 70.17729473114014, 49, 29, 100),
#  (4, 70.17729473114014, 42, 94, 100),
#  (5, 70.17729473114014, 6124, 40, 50),
#  (6, 70.17729473114014, 73, 62, 100),
#  (7, 70.17729473114014, 1605, 3, 50),
#  (8, 70.17729473114014, 27, 62, 100),
#  (9, 70.17729473114014, 2501, 84, 60),
#  (10, 70.17729473114014, 26, 56, 100),
#  (11, 70.17729473114014, 221690, 3, 36),
#  (12, 70.17729473114014, 60464, 387, 36),
#  (0, 75.19722819328308, 42, 92, 100),
#  (1, 75.19722819328308, 42, 93, 100),
#  (2, 75.19722819328308, 6002, 67, 60),
#  (3, 75.19722819328308, 47, 32, 100),
#  (4, 75.19722819328308, 45, 102, 100),
#  (5, 75.19722819328308, 6119, 39, 50),
#  (6, 75.19722819328308, 68, 57, 100),
#  (7, 75.19722819328308, 1601, 1, 50),
#  (8, 75.19722819328308, 30, 59, 100),
#  (9, 75.19722819328308, 2497, 88, 60),
#  (10, 75.19722819328308, 31, 63, 100),
#  (11, 75.19722819328308, 221692, 13, 36),
#  (12, 75.19722819328308, 60462, 383, 36),
#  (0, 80.20648455619812, 40, 96, 100),
#  (1, 80.20648455619812, 46, 91, 100),
#  (2, 80.20648455619812, 6002, 70, 60),
#  (3, 80.20648455619812, 46, 23, 100),
#  (4, 80.20648455619812, 46, 98, 100),
#  (5, 80.20648455619812, 6117, 35, 50),
#  (6, 80.20648455619812, 64, 56, 100),
#  (7, 80.20648455619812, 1596, 9, 50),
#  (8, 80.20648455619812, 31, 49, 100),
#  (9, 80.20648455619812, 2496, 95, 60),
#  (10, 80.20648455619812, 33, 66, 100),
#  (11, 80.20648455619812, 221695, 9, 36),
#  (12, 80.20648455619812, 60466, 379, 36),
#  (0, 85.21711158752441, 42, 95, 100),
#  (1, 85.21711158752441, 42, 85, 100),
#  (2, 85.21711158752441, 6003, 73, 60),
#  (3, 85.21711158752441, 50, 27, 100),
#  (4, 85.21711158752441, 49, 96, 100),
#  (5, 85.21711158752441, 6122, 35, 50),
#  (6, 85.21711158752441, 68, 60, 100),
#  (7, 85.21711158752441, 1600, 7, 50),
#  (8, 85.21711158752441, 34, 59, 100),
#  (9, 85.21711158752441, 2495, 91, 60),
#  (10, 85.21711158752441, 38, 67, 100),
#  (11, 85.21711158752441, 221692, 5, 36),
#  (12, 85.21711158752441, 60464, 379, 36),
#  (0, 90.22479319572449, 44, 102, 100),
#  (1, 90.22479319572449, 40, 90, 100),
#  (2, 90.22479319572449, 6004, 74, 60),
#  (3, 90.22479319572449, 51, 17, 100),
#  (4, 90.22479319572449, 44, 96, 100),
#  (5, 90.22479319572449, 6118, 37, 50),
#  (6, 90.22479319572449, 71, 55, 100),
#  (7, 90.22479319572449, 1600, 6, 50),
#  (8, 90.22479319572449, 32, 56, 100),
#  (9, 90.22479319572449, 2497, 98, 60),
#  (10, 90.22479319572449, 39, 65, 100),
#  (11, 90.22479319572449, 221693, 14, 36),
#  (12, 90.22479319572449, 60462, 387, 36),
#  (0, 95.24290633201599, 46, 107, 100),
#  (1, 95.24290633201599, 40, 97, 100),
#  (2, 95.24290633201599, 6008, 66, 60),
#  (3, 95.24290633201599, 49, 11, 100),
#  (4, 95.24290633201599, 46, 91, 100),
#  (5, 95.24290633201599, 6123, 35, 50),
#  (6, 95.24290633201599, 70, 60, 100),
#  (7, 95.24290633201599, 1598, 9, 50),
#  (8, 95.24290633201599, 29, 48, 100),
#  (9, 95.24290633201599, 2498, 99, 60),
#  (10, 95.24290633201599, 41, 56, 100),
#  (11, 95.24290633201599, 221691, 15, 36),
#  (12, 95.24290633201599, 60457, 377, 36),
#  (0, 100.25337886810303, 49, 103, 100),
#  (1, 100.25337886810303, 36, 106, 100),
#  (2, 100.25337886810303, 6011, 70, 60),
#  (3, 100.25337886810303, 52, 15, 100),
#  (4, 100.25337886810303, 43, 88, 100),
#  (5, 100.25337886810303, 6125, 34, 50),
#  (6, 100.25337886810303, 70, 50, 100),
#  (7, 100.25337886810303, 1600, 3, 50),
#  (8, 100.25337886810303, 30, 44, 100),
#  (9, 100.25337886810303, 2501, 102, 60),
#  (10, 100.25337886810303, 38, 64, 100),
#  (11, 100.25337886810303, 221694, 12, 36),
#  (12, 100.25337886810303, 60456, 379, 36),
#  (0, 105.2631413936615, 49, 100, 100),
#  (1, 105.2631413936615, 37, 99, 100),
#  (2, 105.2631413936615, 6011, 70, 60),
#  (3, 105.2631413936615, 56, 20, 100),
#  (4, 105.2631413936615, 38, 87, 100),
#  (5, 105.2631413936615, 6125, 25, 50),
#  (6, 105.2631413936615, 68, 52, 100),
#  (7, 105.2631413936615, 1605, 1, 50),
#  (8, 105.2631413936615, 34, 54, 100),
#  (9, 105.2631413936615, 2502, 102, 60),
#  (10, 105.2631413936615, 34, 55, 100),
#  (11, 105.2631413936615, 221698, 11, 36),
#  (12, 105.2631413936615, 60459, 372, 36),
#  (0, 110.2650203704834, 44, 96, 100),
#  (1, 110.2650203704834, 32, 107, 100),
#  (2, 110.2650203704834, 6015, 71, 60),
#  (3, 110.2650203704834, 53, 13, 100),
#  (4, 110.2650203704834, 33, 92, 100),
#  (5, 110.2650203704834, 6130, 22, 50),
#  (6, 110.2650203704834, 65, 61, 100),
#  (7, 110.2650203704834, 1605, 9, 50),
#  (8, 110.2650203704834, 37, 55, 100),
#  (9, 110.2650203704834, 2498, 104, 60),
#  (10, 110.2650203704834, 37, 47, 100),
#  (11, 110.2650203704834, 221696, 4, 36),
#  (12, 110.2650203704834, 60454, 366, 36),
#  (0, 115.26992511749268, 44, 104, 100),
#  (1, 115.26992511749268, 36, 102, 100),
#  (2, 115.26992511749268, 6016, 74, 60),
#  (3, 115.26992511749268, 58, 12, 100),
#  (4, 115.26992511749268, 34, 89, 100),
#  (5, 115.26992511749268, 6133, 25, 50),
#  (6, 115.26992511749268, 64, 64, 100),
#  (7, 115.26992511749268, 1600, 8, 50),
#  (8, 115.26992511749268, 42, 59, 100),
#  (9, 115.26992511749268, 2494, 94, 60),
#  (10, 115.26992511749268, 35, 43, 100),
#  (11, 115.26992511749268, 221695, 1, 36),
#  (12, 115.26992511749268, 60453, 374, 36)]

# %% [markdown]
# Descriptive Statistics, Performing Correlation Analysis On the Dataset and plotting correlation matrix.

# %%
import matplotlib.pyplot as plt
metrics = simulation.run_ddos_simulation(uav_network, total_time, update_interval, move_range, connection_range, backbone_range, num_packets, attack_node_id, target_ids)

def plot_network_metrics(metrics):
    # Assuming metrics is a list of tuples (node_id, time, latency, throughput, battery)
    # Filter by node_id for node 5 and node 7
    times_5 = [m[1] for m in metrics if m[0] == 5]
    latencies_5 = [m[2] for m in metrics if m[0] == 5]
    throughputs_5 = [m[3] for m in metrics if m[0] == 5]

    times_7 = [m[1] for m in metrics if m[0] == 7]
    latencies_7 = [m[2] for m in metrics if m[0] == 7]
    throughputs_7 = [m[3] for m in metrics if m[0] == 7]

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times_5, latencies_5, label='Latency UAV 5')
    plt.plot(times_7, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times_5, throughputs_5, label='Throughput UAV 5')
    plt.plot(times_7, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()
    
if metrics:
    plot_network_metrics(metrics)
else:
    print("No data was returned from the simulation.")
# Example usage:
# metrics = [(5, 1.0, 50, 100), (7, 1.0, 70, 90), (5, 2.0, 55, 95), (7, 2.0, 75, 85)]
# plot_network_metrics(metrics)
# Out:
# Iteration 0:
# Packet 0: Source: 7, Target: 2, Size: 36, Delivered: True, Path: [7, 8, 2], Total Latency: 81
# Packet 1: Source: 0, Target: 7, Size: 16, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 3, Target: 8, Size: 8, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 5, Target: 1, Size: 41, Delivered: True, Path: [5, 1], Total Latency: 94
# Packet 4: Source: 9, Target: 8, Size: 111, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 2, Target: 3, Size: 86, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 6, Target: 6, Size: 51, Delivered: True, Path: [6], Total Latency: 20
# Packet 7: Source: 4, Target: 5, Size: 91, Delivered: True, Path: [4, 3, 0, 5], Total Latency: 99
# Packet 8: Source: 7, Target: 9, Size: 2, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 0, Target: 6, Size: 23, Delivered: False, Path: [], Total Latency: None
# Iteration 1:
# Packet 0: Source: 4, Target: 8, Size: 57, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 1, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 2, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 7, Target: 0, Size: 4, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 9, Target: 2, Size: 74, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 4, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 4, Target: 9, Size: 95, Delivered: True, Path: [4, 9], Total Latency: 14
# Packet 7: Source: 6, Target: 2, Size: 12, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 4, Target: 4, Size: 81, Delivered: True, Path: [4], Total Latency: 9
# Packet 9: Source: 2, Target: 0, Size: 36, Delivered: False, Path: [], Total Latency: None
# Iteration 2:
# Packet 0: Source: 5, Target: 4, Size: 41, Delivered: True, Path: [5, 10, 3, 4], Total Latency: 7579
# Packet 1: Source: 8, Target: 1, Size: 61, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 3, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 0, Size: 42, Delivered: True, Path: [0], Total Latency: 1103
# Packet 4: Source: 4, Target: 5, Size: 75, Delivered: True, Path: [4, 3, 10, 5], Total Latency: 7579
# Packet 5: Source: 6, Target: 0, Size: 22, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 2, Target: 3, Size: 74, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 2, Target: 0, Size: 28, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 6, Target: 4, Size: 18, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 9, Target: 7, Size: 24, Delivered: False, Path: [], Total Latency: None
# Iteration 3:
# Packet 0: Source: 2, Target: 8, Size: 39, Delivered: True, Path: [2, 8], Total Latency: 4329
# Packet 1: Source: 7, Target: 1, Size: 18, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 5, Target: 2, Size: 26, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 4, Target: 0, Size: 6, Delivered: True, Path: [4, 10, 0], Total Latency: 4127
# Packet 4: Source: 2, Target: 8, Size: 37, Delivered: True, Path: [2, 8], Total Latency: 4329
# Packet 5: Source: 3, Target: 3, Size: 30, Delivered: True, Path: [3], Total Latency: 43
# Packet 6: Source: 9, Target: 9, Size: 98, Delivered: True, Path: [9], Total Latency: 3
# Packet 7: Source: 4, Target: 8, Size: 51, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 2, Size: 15, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 1, Target: 2, Size: 27, Delivered: False, Path: [], Total Latency: None
# Iteration 4:
# Packet 0: Source: 0, Target: 1, Size: 53, Delivered: True, Path: [0, 1], Total Latency: 6320
# Packet 1: Source: 5, Target: 4, Size: 11, Delivered: True, Path: [5, 10, 4], Total Latency: 7536
# Packet 2: Source: 3, Target: 3, Size: 17, Delivered: True, Path: [3], Total Latency: 45
# Packet 3: Source: 6, Target: 0, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 4, Size: 16, Delivered: True, Path: [0, 10, 4], Total Latency: 4119
# Packet 5: Source: 6, Target: 1, Size: 19, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 3, Target: 1, Size: 34, Delivered: True, Path: [3, 10, 1], Total Latency: 8280
# Packet 7: Source: 6, Target: 2, Size: 47, Delivered: True, Path: [6, 2], Total Latency: 1617
# Packet 8: Source: 7, Target: 3, Size: 31, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 4, Target: 1, Size: 41, Delivered: True, Path: [4, 10, 1], Total Latency: 8239
# Iteration 5:
# Packet 0: Source: 8, Target: 4, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 6, Target: 1, Size: 29, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 8, Target: 7, Size: 38, Delivered: True, Path: [8, 7], Total Latency: 6624
# Packet 3: Source: 2, Target: 8, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 0, Target: 2, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 3, Size: 24, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 5, Target: 9, Size: 17, Delivered: True, Path: [5, 10, 3, 9], Total Latency: 7590
# Packet 7: Source: 9, Target: 8, Size: 69, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 2, Target: 5, Size: 64, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 1, Target: 3, Size: 8, Delivered: True, Path: [1, 10, 3], Total Latency: 8290
# Iteration 6:
# Packet 0: Source: 5, Target: 1, Size: 8, Delivered: True, Path: [5, 1], Total Latency: 9737
# Packet 1: Source: 2, Target: 0, Size: 46, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 2, Target: 7, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 0, Size: 31, Delivered: True, Path: [0], Total Latency: 1101
# Packet 4: Source: 2, Target: 5, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 7, Target: 8, Size: 44, Delivered: True, Path: [7, 8], Total Latency: 6630
# Packet 6: Source: 1, Target: 6, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 3, Target: 7, Size: 58, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 2, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 9, Target: 9, Size: 22, Delivered: True, Path: [9], Total Latency: 7
# Iteration 7:
# Packet 0: Source: 0, Target: 0, Size: 18, Delivered: True, Path: [0], Total Latency: 1096
# Packet 1: Source: 3, Target: 7, Size: 23, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 1, Target: 4, Size: 31, Delivered: True, Path: [1, 10, 4], Total Latency: 8235
# Packet 3: Source: 3, Target: 1, Size: 12, Delivered: True, Path: [3, 10, 1], Total Latency: 8278
# Packet 4: Source: 9, Target: 8, Size: 80, Delivered: False, Path: [], Total Latency: None
# Packet 5: Source: 4, Target: 9, Size: 116, Delivered: True, Path: [4, 9], Total Latency: 11
# Packet 6: Source: 4, Target: 1, Size: 90, Delivered: True, Path: [4, 10, 1], Total Latency: 8235
# Packet 7: Source: 3, Target: 8, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 1, Target: 4, Size: 13, Delivered: True, Path: [1, 10, 4], Total Latency: 8235
# Packet 9: Source: 4, Target: 1, Size: 104, Delivered: True, Path: [4, 10, 1], Total Latency: 8235
# Iteration 8:
# Packet 0: Source: 0, Target: 1, Size: 25, Delivered: True, Path: [0, 1], Total Latency: 6317
# Packet 1: Source: 0, Target: 0, Size: 25, Delivered: True, Path: [0], Total Latency: 1093
# Packet 2: Source: 3, Target: 3, Size: 18, Delivered: True, Path: [3], Total Latency: 42
# Packet 3: Source: 6, Target: 6, Size: 10, Delivered: True, Path: [6], Total Latency: 1592
# Packet 4: Source: 3, Target: 2, Size: 32, Delivered: True, Path: [3, 10, 5, 2], Total Latency: 7576
# Packet 5: Source: 7, Target: 6, Size: 14, Delivered: True, Path: [7, 8, 6], Total Latency: 8221
# Packet 6: Source: 2, Target: 7, Size: 21, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 7, Target: 3, Size: 18, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 7, Target: 3, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 2, Target: 8, Size: 33, Delivered: False, Path: [], Total Latency: None
# Iteration 9:
# Packet 0: Source: 8, Target: 9, Size: 9, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 9, Target: 7, Size: 104, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 1, Size: 42, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 0, Target: 6, Size: 20, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 4, Target: 4, Size: 98, Delivered: True, Path: [4], Total Latency: 1
# Packet 5: Source: 2, Target: 1, Size: 53, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 4, Target: 8, Size: 61, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 1, Target: 6, Size: 13, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 3, Target: 2, Size: 38, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 6, Target: 5, Size: 31, Delivered: False, Path: [], Total Latency: None
# Iteration 10:
# Packet 0: Source: 5, Target: 7, Size: 32, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 8, Target: 1, Size: 37, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 9, Target: 0, Size: 90, Delivered: True, Path: [9, 4, 10, 0], Total Latency: 4117
# Packet 3: Source: 9, Target: 7, Size: 26, Delivered: False, Path: [], Total Latency: None
# Packet 4: Source: 9, Target: 3, Size: 83, Delivered: True, Path: [9, 3], Total Latency: 49
# Packet 5: Source: 6, Target: 2, Size: 11, Delivered: False, Path: [], Total Latency: None
# Packet 6: Source: 0, Target: 6, Size: 33, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 7, Target: 4, Size: 35, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 0, Target: 9, Size: 38, Delivered: True, Path: [0, 10, 4, 9], Total Latency: 4117
# Packet 9: Source: 1, Target: 9, Size: 16, Delivered: True, Path: [1, 10, 4, 9], Total Latency: 8248
# Iteration 11:
# Packet 0: Source: 9, Target: 6, Size: 14, Delivered: False, Path: [], Total Latency: None
# Packet 1: Source: 7, Target: 0, Size: 1, Delivered: False, Path: [], Total Latency: None
# Packet 2: Source: 7, Target: 2, Size: 36, Delivered: False, Path: [], Total Latency: None
# Packet 3: Source: 4, Target: 9, Size: 53, Delivered: True, Path: [4, 9], Total Latency: 14
# Packet 4: Source: 5, Target: 3, Size: 21, Delivered: True, Path: [5, 10, 4, 3], Total Latency: 7557
# Packet 5: Source: 0, Target: 3, Size: 55, Delivered: True, Path: [0, 10, 4, 3], Total Latency: 4142
# Packet 6: Source: 2, Target: 6, Size: 7, Delivered: False, Path: [], Total Latency: None
# Packet 7: Source: 0, Target: 7, Size: 59, Delivered: False, Path: [], Total Latency: None
# Packet 8: Source: 1, Target: 8, Size: 34, Delivered: False, Path: [], Total Latency: None
# Packet 9: Source: 1, Target: 6, Size: 16, Delivered: False, Path: [], Total Latency: None
# Metrics saved to simulation_results/ddos_simulation_20240423_020547.csv

# %%
"""Pearson's Correlation"""

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Data provided
data = [
    {'time': 0.001983642578125, 'node_id': 0, 'latency': 16, 'throughput': 71},
    {'time': 0.001983642578125, 'node_id': 1, 'latency': 41, 'throughput': 54},
    {'time': 0.001983642578125, 'node_id': 2, 'latency': 32, 'throughput': 76},
    {'time': 0.001983642578125, 'node_id': 3, 'latency': 7, 'throughput': 52},
    {'time': 0.001983642578125, 'node_id': 4, 'latency': 18, 'throughput': 53},
    {'time': 0.001983642578125, 'node_id': 5, 'latency': 17, 'throughput': 65},
    {'time': 0.001983642578125, 'node_id': 6, 'latency': 16, 'throughput': 84},
    {'time': 0.001983642578125, 'node_id': 7, 'latency': 40, 'throughput': 55},
    {'time': 0.001983642578125, 'node_id': 8, 'latency': 37, 'throughput': 68},
    {'time': 0.001983642578125, 'node_id': 9, 'latency': 39, 'throughput': 77},
    {'time': 0.001983642578125, 'node_id': 10, 'latency': 36, 'throughput': 86},
    {'time': 0.001983642578125, 'node_id': 11, 'latency': 39, 'throughput': 94},
    {'time': 5.015164613723755, 'node_id': 0, 'latency': 17, 'throughput': 78},
    # Assuming the rest of the data points are appended here in the same format...
]

# Converting data into a pandas DataFrame
df = pd.DataFrame(data)

# Calculating the correlation between latency and throughput
correlation_matrix = df[['latency', 'throughput']].corr()
print(correlation_matrix)


# Plotting a heatmap of the correlation matrix
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
heatmap.set_title('Correlation Heatmap between Latency and Throughput', pad=12)
plt.show()
# Out:
#              latency  throughput
# latency     1.000000    0.209531
# throughput  0.209531    1.000000

# %%
def plot_network_metrics_from_csv(file_path):
    # Load data from CSV
    df = pd.read_csv(file_path)
    
    # Filter data for specific nodes
    node_5_df = df[df['Node'] == 5]
    node_7_df = df[df['Node'] == 7]
    
    # Extract times, latencies, and throughputs
    times_5 = node_5_df['Time']
    latencies_5 = node_5_df['Latency']
    throughputs_5 = node_5_df['Throughput']

    times_7 = node_7_df['Time']
    latencies_7 = node_7_df['Latency']
    throughputs_7 = node_7_df['Throughput']

    plt.figure(figsize=(12, 6))
    
    plt.subplot(2, 1, 1)
    plt.plot(times_5, latencies_5, label='Latency UAV 5')
    plt.plot(times_7, latencies_7, label='Latency UAV 7')
    plt.title('Latency over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Latency (ms)')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.plot(times_5, throughputs_5, label='Throughput UAV 5')
    plt.plot(times_7, throughputs_7, label='Throughput UAV 7')
    plt.title('Throughput over Time')
    plt.xlabel('Time (s)')
    plt.ylabel('Throughput (Mbps)')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage:
file_path = 'simulation_results\ddos_simulation_20240423_012712.csv'
plot_network_metrics_from_csv(file_path)
